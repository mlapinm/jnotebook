# %% [markdown]
# [b360 ”рок Java 350:  ак обычную строку поместить в пул](#b360-”рок-Java-350:- ак-обычную-строку-поместить-в-пул)
# [b361 ”рок Java 351: –азмещение обектов вне хипа](#b361-”рок-Java-351:-–азмещение-обектов-вне-хипа)
# [b362 ”рок Java 352: –асспределение нагрузки](#b362-”рок-Java-352:-–асспределение-нагрузки)
# [b363 ”рок Java 353: Immutable коллекции](#b363-”рок-Java-353:-Immutable-коллекции)
# [b364 ”рок Java 354: ¬ысоконагруженна¤ архитектура](#b364-”рок-Java-354:-¬ысоконагруженна¤-архитектура)
# [b365 ”рок Java 355: Ўардинг и репликаци¤](#b365-”рок-Java-355:-Ўардинг-и-репликаци¤)
# [b366 ”рок Java 356: —оздание индексов в базе данных](#b366-”рок-Java-356:-—оздание-индексов-в-базе-данных)
# [b367 ”рок Java 357: ѕочему синхронизаци¤ это плохо](#b367-”рок-Java-357:-ѕочему-синхронизаци¤-это-плохо)
# [b368 ”рок Java 358: GRASP паттерны](#b368-”рок-Java-358:-GRASP-паттерны)
# [b369 ”рок Java 359: Cap теорема](#b369-”рок-Java-359:-Cap-теорема)
# [b370 ”рок Java 360: Externalizer](#b370-”рок-Java-360:-Externalizer)
# [b371 ”рок Java 361: Imutable классы](#b371-”рок-Java-361:-Imutable-классы)
# [b372 ”рок Java 362:  ак обнаружить DeadLock](#b372-”рок-Java-362:- ак-обнаружить-DeadLock)
# [b373 ”рок Java 363: ThreadLocal](#b373-”рок-Java-363:-ThreadLocal)
# [b374 ”рок Java 364:  ак изучить Indellij idea](#b374-”рок-Java-364:- ак-изучить-Indellij-idea)
# [b375 ”рок Java 365: Best practice](#b375-”рок-Java-365:-Best-practice)
# [b376 ”рок Java 366: Best practice 2: Static factory](#b376-”рок-Java-366:-Best-practice-2:-Static-factory)
# [b377 ”рок Java 367: Best practice 3: Singleton](#b377-”рок-Java-367:-Best-practice-3:-Singleton)
# [b378 ”рок Java 368: Best practice 4:  Unnecesary objects](#b378-”рок-Java-368:-Best-practice-4:--Unnecesary-objects)
# [b379 ”рок Java 369: Best practice 5: ѕочему нельз¤ использовать finalize?](#b379-”рок-Java-369:-Best-practice-5:-ѕочему-нельз¤-использовать-finalize?)
# [b380 ”рок Java 370: Best practice 6: ѕереопределение equals](#b380-”рок-Java-370:-Best-practice-6:-ѕереопределение-equals)
# [b381 ”рок Java 371: Best practice 7: ѕереопределение HashCode](#b381-”рок-Java-371:-Best-practice-7:-ѕереопределение-HashCode)
# [b382 ”рок Java 372: Best practice 8: ѕереопределение clone](#b382-”рок-Java-372:-Best-practice-8:-ѕереопределение-clone)
# [b383 ”рок Java 373: Best practice 9: ToString](#b383-”рок-Java-373:-Best-practice-9:-ToString)
# [b384 ”рок Java 374: Best practice 10: ћинимизируйте accessability](#b384-”рок-Java-374:-Best-practice-10:-ћинимизируйте-accessability)
# [b385 ”рок Java 375: Best practice 11:  ак создавать immutable классы](#b385-”рок-Java-375:-Best-practice-11:- ак-создавать-immutable-классы)
# [b386 ”рок Java 376: Best practice 12: „ем композици¤ лучше наследовани¤?](#b386-”рок-Java-376:-Best-practice-12:-„ем-композици¤-лучше-наследовани¤?)
# [b387 ”рок Java 377: Best practice 13: ƒизайн класса дл¤ наследовани¤](#b387-”рок-Java-377:-Best-practice-13:-ƒизайн-класса-дл¤-наследовани¤)
# [b388 ”рок Java 378: Best practice 14: „ем интерфейсы лучше абстрактных классов?](#b388-”рок-Java-378:-Best-practice-14:-„ем-интерфейсы-лучше-абстрактных-классов?)
# [b389 ”рок Java 379: Best practice 15: Ќе используйте row типы](#b389-”рок-Java-379:-Best-practice-15:-Ќе-используйте-row-типы)
# [b390 ”рок Java 380: Best practice 16: SuppressWarnings](#b390-”рок-Java-380:-Best-practice-16:-SuppressWarnings)
# [b391 ”рок Java 381: Best practice 17: „ем List лучше массивов?](#b391-”рок-Java-381:-Best-practice-17:-„ем-List-лучше-массивов?)
# [b392 ”рок Java 382: Best practice 18: Wild cards](#b392-”рок-Java-382:-Best-practice-18:-Wild-cards)
# [b393 ”рок Java 383: Best practice 19: „ем Enum лучше констант](#b393-”рок-Java-383:-Best-practice-19:-„ем-Enum-лучше-констант)
# [b394 ”рок Java 384: Best practice 20: ѕочему нужно использовать @Override](#b394-”рок-Java-384:-Best-practice-20:-ѕочему-нужно-использовать-@Override)
# [b395 ”рок Java 385: Best practice 21: Immutable objects](#b395-”рок-Java-385:-Best-practice-21:-Immutable-objects)
# [b396 ”рок Java 386: Best practice 22: ¬алидаци¤ параметров](#b396-”рок-Java-386:-Best-practice-22:-¬алидаци¤-параметров)
# [b397 ”рок Java 387: Best practice 23: —оздание сигнатуры метод](#b397-”рок-Java-387:-Best-practice-23:-—оздание-сигнатуры-метод)
# [b398 ”рок Java 388: Best practice 24: Overloading](#b398-”рок-Java-388:-Best-practice-24:-Overloading)
# [b399 ”рок Java 389: Best practice 25: ¬озвращение коллекций методам](#b399-”рок-Java-389:-Best-practice-25:-¬озвращение-коллекций-методам)
# [b400 ”рок Java 390: Best practice 26: ћинимизаци¤ скоупа и циклы](#b400-”рок-Java-390:-Best-practice-26:-ћинимизаци¤-скоупа-и-циклы)
# [b401 ”рок Java 391: Best practice 27: ѕочему нельз¤ использовать float и double дл¤ точных вычислений?](#b401-”рок-Java-391:-Best-practice-27:-ѕочему-нельз¤-использовать-float-и-double-дл¤-точных-вычислений?)
# [b402 ”рок Java 392: Best practice 28: ѕочему нужно использовать примитивы вместо оберток?](#b402-”рок-Java-392:-Best-practice-28:-ѕочему-нужно-использовать-примитивы-вместо-оберток?)
# [b403 ”рок Java 393: Best practice 29: ѕочему нужно обращатьс¤ к объектам через интерфейс?](#b403-”рок-Java-393:-Best-practice-29:-ѕочему-нужно-обращатьс¤-к-объектам-через-интерфейс?)
# [b404 ”рок Java 394: Best practice 30: Ќе оптимизируйте](#b404-”рок-Java-394:-Best-practice-30:-Ќе-оптимизируйте)
# [b405 ”рок Java 395: Best practice 31:  акой вид исключений использовать?](#b405-”рок-Java-395:-Best-practice-31:- акой-вид-исключений-использовать?)
# [b406 ”рок Java 396: Best practice 32: »спользуйте стандартные исключени¤](#b406-”рок-Java-396:-Best-practice-32:-»спользуйте-стандартные-исключени¤)
# [b407 ”рок Java 397: Best practice 33: јтомарность исключений](#b407-”рок-Java-397:-Best-practice-33:-јтомарность-исключений)
# [b408 ”рок Java 398: Best practice 34: –абота с исключени¤ми](#b408-”рок-Java-398:-Best-practice-34:-–абота-с-исключени¤ми)
# [b409 ”рок Java 399: Best practice 35: —инхронизируйте доступ к мутабельной информации](#b409-”рок-Java-399:-Best-practice-35:-—инхронизируйте-доступ-к-мутабельной-информации)
# [b410 ”рок Java 400: Best practice 36: ¬ызов "Alien" методов из синхронизированного контекста](#b410-”рок-Java-400:-Best-practice-36:-¬ызов-"Alien"-методов-из-синхронизированного-контекста)
# [b411 ”рок Java 401: Best practice 37: »спользование wait и notify](#b411-”рок-Java-401:-Best-practice-37:-»спользование-wait-и-notify)
# [b412 ”рок Java 402: Best practice 38: ƒокументируйте потокобезопасность ¬аших методов](#b412-”рок-Java-402:-Best-practice-38:-ƒокументируйте-потокобезопасность-¬аших-методов)
# [b413 ”рок Java 403: Best practice 39: –абота с многопоточностью](#b413-”рок-Java-403:-Best-practice-39:-–абота-с-многопоточностью)
# [b414 ”рок Java 404: Best practice 40: —ериализаци¤](#b414-”рок-Java-404:-Best-practice-40:-—ериализаци¤)
# [b415 ”рок Java 405:  онец!!!](#b415-”рок-Java-405:- онец!!!)

# %% [markdown]
# #### b360 ”рок Java 350:  ак обычную строку поместить в пул
# #### b361 ”рок Java 351: –азмещение обектов вне хипа
# #### b362 ”рок Java 352: –асспределение нагрузки
# #### b363 ”рок Java 353: Immutable коллекции
# #### b364 ”рок Java 354: ¬ысоконагруженна¤ архитектура
# #### b365 ”рок Java 355: Ўардинг и репликаци¤
# #### b366 ”рок Java 356: —оздание индексов в базе данных
# #### b367 ”рок Java 357: ѕочему синхронизаци¤ это плохо
# #### b368 ”рок Java 358: GRASP паттерны
# #### b369 ”рок Java 359: Cap теорема
# #### b370 ”рок Java 360: Externalizer
# #### b371 ”рок Java 361: Imutable классы
# #### b372 ”рок Java 362:  ак обнаружить DeadLock
# #### b373 ”рок Java 363: ThreadLocal
# #### b374 ”рок Java 364:  ак изучить Indellij idea
# #### b375 ”рок Java 365: Best practice
# #### b376 ”рок Java 366: Best practice 2: Static factory
# #### b377 ”рок Java 367: Best practice 3: Singleton
# #### b378 ”рок Java 368: Best practice 4:  Unnecesary objects
# #### b379 ”рок Java 369: Best practice 5: ѕочему нельз¤ использовать finalize?
# #### b380 ”рок Java 370: Best practice 6: ѕереопределение equals
# #### b381 ”рок Java 371: Best practice 7: ѕереопределение HashCode
# #### b382 ”рок Java 372: Best practice 8: ѕереопределение clone
# #### b383 ”рок Java 373: Best practice 9: ToString
# #### b384 ”рок Java 374: Best practice 10: ћинимизируйте accessability
# #### b385 ”рок Java 375: Best practice 11:  ак создавать immutable классы
# #### b386 ”рок Java 376: Best practice 12: „ем композици¤ лучше наследовани¤?
# #### b387 ”рок Java 377: Best practice 13: ƒизайн класса дл¤ наследовани¤
# #### b388 ”рок Java 378: Best practice 14: „ем интерфейсы лучше абстрактных классов?
# #### b389 ”рок Java 379: Best practice 15: Ќе используйте row типы
# #### b390 ”рок Java 380: Best practice 16: SuppressWarnings
# #### b391 ”рок Java 381: Best practice 17: „ем List лучше массивов?
# #### b392 ”рок Java 382: Best practice 18: Wild cards
# #### b393 ”рок Java 383: Best practice 19: „ем Enum лучше констант
# #### b394 ”рок Java 384: Best practice 20: ѕочему нужно использовать @Override
# #### b395 ”рок Java 385: Best practice 21: Immutable objects
# #### b396 ”рок Java 386: Best practice 22: ¬алидаци¤ параметров
# #### b397 ”рок Java 387: Best practice 23: —оздание сигнатуры метод
# #### b398 ”рок Java 388: Best practice 24: Overloading
# #### b399 ”рок Java 389: Best practice 25: ¬озвращение коллекций методам
# #### b400 ”рок Java 390: Best practice 26: ћинимизаци¤ скоупа и циклы
# #### b401 ”рок Java 391: Best practice 27: ѕочему нельз¤ использовать float и double дл¤ точных вычислений?
# #### b402 ”рок Java 392: Best practice 28: ѕочему нужно использовать примитивы вместо оберток?
# #### b403 ”рок Java 393: Best practice 29: ѕочему нужно обращатьс¤ к объектам через интерфейс?
# #### b404 ”рок Java 394: Best practice 30: Ќе оптимизируйте
# #### b405 ”рок Java 395: Best practice 31:  акой вид исключений использовать?
# #### b406 ”рок Java 396: Best practice 32: »спользуйте стандартные исключени¤
# #### b407 ”рок Java 397: Best practice 33: јтомарность исключений
# #### b408 ”рок Java 398: Best practice 34: –абота с исключени¤ми
# #### b409 ”рок Java 399: Best practice 35: —инхронизируйте доступ к мутабельной информации
# #### b410 ”рок Java 400: Best practice 36: ¬ызов "Alien" методов из синхронизированного контекста
# #### b411 ”рок Java 401: Best practice 37: »спользование wait и notify
# #### b412 ”рок Java 402: Best practice 38: ƒокументируйте потокобезопасность ¬аших методов
# #### b413 ”рок Java 403: Best practice 39: –абота с многопоточностью
# #### b414 ”рок Java 404: Best practice 40: —ериализаци¤
# #### b415 ”рок Java 405:  онец!!!

# %% [markdown]
# []()
# []()
# []()
# []()
# []()
# ```
#
# ```

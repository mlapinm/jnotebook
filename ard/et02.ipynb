# %% [markdown]
# [STM8s Arduino-like library for IAR](#STM8s-Arduino-like-library-for-IAR)
# [PlatformIO или прощай, Arduino IDE](#PlatformIO-или-прощай,-Arduino-IDE)
# [Знакомство с BBC micro:bit](#Знакомство-с-BBC-micro:bit)
# [DFRobot Boson Starter Kit для BBC mico:bit](#DFRobot-Boson-Starter-Kit-для-BBC-mico:bit)
# []()

# %% [markdown]
# #### STM8s Arduino-like library for IAR

# %% [markdown]
# stm8s103f2 - 16MHz, 8k flash, 1k ram

# %% [markdown]
# swim protocol for programming
# st-link v2 - swim, std (ssd)
# usb ort мост
# b4 i2c b5 led i2c open draine (открытый коллектор) push pull - нет
# d1 используется в swim

# %% [markdown]
# www.stm.com
# DS610 - Product specifications
# RM0016 - Reference Manual
# PM0044 - Programming Manual
# ES0102 - Errata(опечатки) Sheet

# %% [markdown]
# iar.com
# stm8
# download software 8k limitation code
# Kikstart - пожизненная лицензия с 8k lim code

# %% [markdown]
# st.com
# st-link/v2  find
# STSW-LINK009 - Tools & software - driver Win7,...

# %% [markdown]
# iar
# Tools Options

# %% [markdown]
# Arduino.projtempl
# IAR Systems\Embedded Workbench 7.3\stm8\config\template\project
#
# `Project` `Create New Project` `STM8 Series` `Arduino`
#
# STM8\Test Test.ewp
# [rb]Test-Debug
# Options for node "Test"
# Target - STM8S103F3P - General
# ST-LINK - Debugger
#
# ST-Link Options Bytes AFR0 Alternate Active
# c5,c6,c7 - Timer 2 ch1, Timer 1 ch1, Timer1 ch2

# %% [markdown]
# #### PlatformIO или прощай, Arduino IDE

# %% [markdown]
# [PlatformIO или прощай, Arduino IDE](https://www.youtube.com/watch?v=OGCyKncOyNU&list=PLZKvhpfgHOpkSCHcIPr_KZdjdsqOKe-Hn&index=5)
# [wi-fi-modul-esp-01](https://3d-diy.ru/wiki/arduino-moduli/wi-fi-modul-esp-01/)
# [Sonoff 4CH Pro (4-Канальный RF Выключатель)](https://sonoff.ru/catalog/wifi-rele/sonoff-4ch-pro-4-kanalnyy-rf-vyklyuchatel)
# []()
# []()
# []()
# https://platformio.org/

# %% [markdown]
# https://code.visualstudio.com/
# VSCodeUserSetup-x64-1.41.0.exe
# C:\Users\argon\AppData\Local\Programs\Microsoft VS Code
# Visual Studio Code
# File Preferences Extensions
# `platformio` - searching
# install  reload
#
# Setting Telemetry  [] []

# %% [markdown]
# ##### Автоматический запуск монитора
# `Setting` `Extension` `Platformio configuration`
# `[v]` - force apload and monitor

# %% [markdown]
# `View` `Open View...` `Pio Home` `Open`
# `Platforms` `Embedded`
# `Atmel AVR` - Arduino uno mega
# `Install` -
# `Atmel SAM` - Due
# `Espressif 32` -
# `Espressif 8266` - 1.7.3
# `ST STM32` - CMSIS,SPL(standPriphLib)
# `Intel ARC32` -
# `Microchip PIC32` -
# `Nordic nRF51` - BBC microbit (ARM)
# `TI MSP430` -
# `` -
# `` -

# %% [markdown]
# `Libraries` -
# `pubsubclient` -

# %% [markdown]
# Home New Project
# `Blink` - Name
# `Arduino Uno` - Board
# `WeMos D1 R2 & mini (WEMOS)` - Board
# `Arduino` - Framework
# `[v]` - Use Default Location
# C:\Users\argon\Documents\PlatformIO\Projects\Blink\src\main.cpp
# `Finish` -
# platformio.ini
# [env:uno]
# ```
# platform = atmelavr
# board = uno
# framework = arduino
# upload_speed = 115200
# monitor_speed = 115200
# ```
# `upload_speed = 115200` -
# `v` - build
# `->` - run
# `terminal` -
# `Platform IO task` - Platform IO update
# `` -
# Force Upload And Monitor
# Force 'Upload and Monitor' task for `platformio-ide.upload` command
# `` -
# `` -

# %% [markdown]
# `` -
# `` -

# %% [markdown]
# #### Знакомство с BBC micro:bit

# %% [markdown]
# [Знакомство с BBC micro:bit](https://www.youtube.com/watch?v=72uBcRfkagw&list=PLZKvhpfgHOpmtN-an_jauNwgLh-Y8WX7X)
# [https://makecode.microbit.org/](https://makecode.microbit.org/)
# []()

# %% [markdown]
# #### DFRobot Boson Starter Kit для BBC mico:bit

# %% [markdown]
# [https://www.dfrobot.com/](https://www.dfrobot.com/)
# [micro:bit](https://www.dfrobot.com/category-257.html)
# []()
# []()

# %% [markdown]
# ![img-2019-12-22-18-49-24.png](attachment:img-2019-12-22-18-49-24.png)

# %% [markdown]
# #### 9.Корпоративная сеть на MikroTik. VLAN
# [9.Корпоративная сеть на MikroTik. VLAN](https://www.youtube.com/watch?v=SVP6-4mv260&list=PLcDkQ2Au8aVN822_loH42xLuagyBkOUqg&index=9)
# ```
# Switch1
# Mikrotik ether0
# gate1    ether1
# winxp    ether2
# cloud    ether7 192.168.56.1
#
#
#
# Microtik
# System
# Reset Configuration
# [v] No Default Configuration
# [v] Do not Backup
# Reset configuration
# ```

# %% [markdown]
# ![img-2019-11-22-11-42-06.png](attachment:img-2019-11-22-11-42-06.png)

# %% [markdown]
# ****
# ```
# winxp 192.168.56.10/24
#
# ping 192.168.56.1
#
# gate-1
# system-config-network-tui
#
# /etc/init.d/network restart
# ifconfig
# ping 192.168.56.1
# ping 192.168.56.10
# ```

# %% [markdown]
# ##### switch1 configure
#
# Port   | VLAN  | Type | EtherType
#  -------------|------------|------------|----------
# 0 | 1 | dot1q |
# 1 | 11 | access |
# 2 | 10 | access |
# 3 | 56 | access |

# %% [markdown]
# ##### Microtik Interfaces New Interface
# Name   | VLAN ID | Interface | Comment
#  -------------|------------|------------|----------
# vlan56 | 56 | ether5 | SysAdmin Vlan
# vlan10 | 10 | ether5 | Users Vlan
# vlan11 | 11 | ether5 | Server Vlan

# %% [markdown]
# ##### IP Addresses
# Address   | Network | Interface |
#  -------------|------------|------------|----------
# 192.168.10.1/24 | 192.168.10.0 | vlan10 |
# 192.168.11.1/24 | 192.168.11.0 | vlan11 |
# 192.168.56.2/24 | 192.168.56.0 | vlan56 |

# %% [markdown]
# ##### DHCP

# %% [markdown]
# winxp
# ping 192.168.56.1
# **Cloud1 Admin cmd**
# route add 192.168.10.0 MASK 255.255.255.0 192.168.56.2
# ```
# ```

# %% [markdown]
# ****
# ```
# ```

# %% [markdown]
# ****
# ```
# ```

# %% [markdown]
# ****
# ```
# ```

# %% [markdown]
# ****
# ```
# ```

# %% [markdown]
# ****
# ```
# ```

# %% [markdown]
# ****
# ```
# ```

# %% [markdown]
# []()
# []()
# []()
# []()
# []()
# ```
#
# ```

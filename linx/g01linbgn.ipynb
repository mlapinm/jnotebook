# %% [markdown]
# [1. Введение](#1.-Введение)
# [2. Установка CentOS в VirtualBox](#2.-Установка-CentOS-в-VirtualBox)
# [3. Файловая система и основные команды](#3.-Файловая-система-и-основные-команды)
# [4. Настройка сети](#4.-Настройка-сети)
# [5. Заведение пользователей](#5.-Заведение-пользователей)
# [6. Установка пакетов](#6.-Установка-пакетов)
# [7. Межсетевой экран](#7.-Межсетевой-экран)
# [8. DHCP сервер](#8.-DHCP-сервер)
# [9. Заключение](#9.-Заключение)

# %% [markdown]
# #### 1. Введение

# %% [markdown]
# Цель курса:
# Изучение основ администрирования операционных систем Linux. Курс в большей степени практический и
# содержит минимальное количество теории.
# Структура курса
# Базовый курс Расширенный курс
# Для кого этот курс:
# - для системных администраторов
# - для сетевых инженеров

# %% [markdown]
# Kernel space -ядро, которое непосредственно взаимодействует с устройствами в системе, обслуживаетих и производит настройку.
# User space – пространство приложений.
# Ядро Linux
# • разработку начал Линус Линус Торвальдс  в 1991 году
# • поддерживает  многозадачность, динамические библиотеки, виртуальную память, отложенную загрузку, большинство сетевых протоколов и производительную систему управления памятью
# • распространяется  по лицензии  GNU GPL , т.е. свободно
# • подробнее про  ядро Linux – [здесь](https://ru.wikipedia.org/wiki/Ядро_Linux) .
# GNU General Public – лицензии на свободное программное обеспечение.
# Цель GNU GPL — предоставить пользователю права копировать, модифицировать и распространять  (в том числе на коммерческой основе) программы, а также гарантировать, что и пользователи всех производных  программ получат вышеперечисленные права.

# %% [markdown]
# 1. Безопасность
# 2. Производительность
# 3. Надежность
# 4. Масштабируемость
# 5. Аппаратная совместимость
# 6. Не требуется импортозамещение
# 7. Зарплата Linux администраторов выше, чем у обычных администраторов

# %% [markdown]
# ##### Что можно сделать с помощью Linux?
# 1. Настроить программный маршрутизатор/ шлюз
# доступа в Интернет с функциями межсетевого экрана
# и DHCP сервера
# 2. Ограничить доступ пользователей к сети Интернет
# с помощью proxy сервера
# 3. Организовать почтовый сервер для
# корпоративной почты
# 4. Создать веб сервер для корпоративного сайта и
# внутренних веб ресурсов
# 5. Настроить первичный и вторичный DNS сервера
# 6. Развернуть файловый сервер
# 7. Собирать резервные копии с остальных серверов
# 8. Развернуть сервер логирования для сбора
# событий с других серверов

# %% [markdown]
# #### 2. Установка CentOS в VirtualBox

# %% [markdown]
# CentOSS – производный от RedHatRedHat. дистрибутив.
# Срок поддержки версий составляет 10 лет.
# CentOS-7-x86_64-Minimal-1511.iso
# Dec-2015

# %% [markdown]
# Виртуальная машина (ВМ) – программная среда, эмулирующая аппаратную платформу.
# Подробнее про виртуальные машины [здесь](https://ru.wikipedia.org/wiki/Виртуальная_машина).
# ПО для работы с ВМ:
# -Oracle VirtualBox(скачать [тут](https://www.virtualbox.org/wiki/Downloads) )
# -VMWare Workstation
# -Microsoft Virtual PC Microsoft Virtual PCMicrosoft Virtual PCMicrosoft Virtual PC

# %% [markdown]
# Дополнительные ссылки
# 1. [Аппаратная виртуализация](https://ru.wikipedia.org/wiki/Аппаратная_виртуализация)
# 2. [Сайт CentOS](https://www.centos.org/)
# 3. [Дистрибутив CentOS](https://www.centos.org/download/)
# 4. Дистрибутивы для скачивания через [torrent](http://isoredirect.centos.org/centos/7/isos/x86_64/)
# 5. Информация Device [ссылка1](https://ru.wikipedia.org/wiki/Btrfs)  и [ссылка2](https://ru.wikipedia.org/wiki/LVM)
# 6. [Информация kdump](https://en.wikipedia.org/wiki/Kdump_(Linux))

# %% [markdown]
# #### 3. Файловая система и основные команды
# /bin/boot/dev/etc/home/lost+found/lib/media/mnt/opt/proc/root/run/sbin/srv/sys/tmp
# /-корневой каталог, в котором располагаются все остальные каталоги
# /bin– здесь хранятся основные утилиты ОС
# /etc– хранятся файлы конфигураций
# /home – здесь расположены домашние каталоги созданных пользователей
# /root – домашний каталог администратора
# /varvar – хранится постоянно меняющаяся информация, например, логи
# Подробнее о назначении каждого каталога можно прочитать  [здесь](http://www.linux-info.ru/struktura.html) и [здесь](http://rus-linux.net/MyLDP/file-sys/fhs-struktura-katalogov-linux.html) .
# О командах  для работы в для работы в  Linux и их назначении можно прочитать  можно прочитать [здесь](http://itshaman.ru/articles/7/komandy-linux).

# %% [markdown]
# Дополнительные ссылки:
# 1. [Редактор vi](https://ru.wikipedia.org/wiki/Vi)
# 2. [Справочник по редактору Справочник по редакторуvi](http://rsusu1.rnd.runnet.ru/unix/ucomm/vi.html)

# %% [markdown]
# #### 4. Настройка сети

# %% [markdown]
# SSH – сетевой протокол, позволяющий производить удаленное управление операционной системой.
# Чтобы подключиться по  SSH нужно:
# В ОС Linux ввести команду ssh <адрес_сервера> -l<имя_пользователя>
# Пример : ssh 192.168.10.10 –l vasya
# В ОС Windows: воспользоваться специализированной утилитой Пример : Putty (скачать можно скачать можно скачать можно скачать можно [тут](https://www.chiark.greenend.org.uk/~sgtatham/putty/latest.html))
# Чтобы копировать файлы по по SCP :
# Утилита WinSCP (скачать можно [тут](https://winscp.net/eng/download.php) )

# %% [markdown]
# Дополнительные ссылки
# 1. [Курс молодого бойца (видеоуроки по сетям)](https://www.youtube.com/watch?list=PLcDkQ2Au8aVNYsqGsxRQxYyQijILa94T9&v=voGkaUXFw-I)
# 2. [Параметры настройки сетевого интерфейса](http://linux.mixed-spb.ru/network/centos-tcpip.php)

# %% [markdown]
# #### 5. Заведение пользователей

# %% [markdown]
# Для обеспечения первоначальной безопасности системы необходимо решить две задачи:
# 1. Создать нового пользователя
# 2. Закрыть удаленный доступ для пользователя root

# %% [markdown]
# Типы пользователей:
# -владелец файла
# -другие пользователи, которые входят в группу владельца
# -все остальные
# Два способа задать права на файл:  символьный и числовой.

# %% [markdown]
# 777 или rwxrwxrwx – всем разрешено все
# 755 или rwxr -xr -x– у администратора все права, у остальных на чтение и выполнение у администратора все права, остальных на чтение и выполнениеПодробнее про права можно прочитать [здесь](https://ru.wikipedia.org/wiki/Chmod).

# %% [markdown]
# Задача:
# Доступ к папке /backup должен быть только у администраторов ( root и netskills).
#
# Решение:
# 1. Сменить владельца /backup  с root на netskills
# 2. Права для первых двух типов пользователей выставить7 или rwxrwx
# 3. Для последнего типа пользователей выставить права 0 или ---
# 4. Права на папку /backup: 770 или rwxrwx ---
#
# [sudo](https://white55.ru/sudo.html)

# %% [markdown]
# #### 6. Установка пакетов

# %% [markdown]
# Как установить ПО в  Linux?
# 1. Поставить пакет (в CentOS – rpm пакеты)
# 2. Собрать ПО из исходников и установить
#
# Пакетный менеджер  – ПО, позволяющее управлять процессом установки, настройки, обновления и удаления программ.
# В CentOS  используется пакетный менеджер yum .
# Репозитории – специальные сервера -хранилища, откуда можно скачивать пакеты.
# Подробнее про пакетные менеджеры можно прочитать  [здесь](https://ru.wikipedia.org/wiki/Система_управления_пакетами) и [здесь](http://rus-linux.net/kos.php?name=/papers/fedora8/yum_howto.html).
# Подробнее про репозитории можно узнать [отсюда](https://help.ubuntu.ru/wiki/репозиторий), [отсюда](https://centos.name/?page/additionalresources/repositories), [отсюда](http://i-leon.ru/obnovlenie_centos_i_dobavlenie_repozitoriev/) и еще [отсюда](https://howtoit.ru/linux/centos/item/15-podklyuchenie-repozitoriev-centos-6-epel-rpmforge-remi.html).
#
# Настройка proxy в системе
# Для  того, чтобы настроить интернет для всей системы через proxy сервер, нужно задать переменную окружения http_proxy с нужными параметрами.
# Пример команды: export http_proxy ”http://login:password@proxy.mynet.ru:8080”.
# Логин и пароль указывать не нужно, если у вас нет авторизации на proxy сервере. После двоеточия нужно указать порт, на котором работает нужно указать порт, на котором работает proxy сервер (обычно это 3128 или 8080 ).
# Обратите внимание, что эта переменная окружения будет доступна только до перезагрузки системы. Чтобы она сохранилась, нужно эту команду написать в файл  bashrc , расположенный в вашей домашней директории, например, /home/netskills.
#
# 1. [Документация по текстовому редактору nano](https://www.nano-editor.org/dist/v2.5/nano.html)
# 2. [Файловые менеджеры](https://ru.wikipedia.org/wiki/Файловый_менеджер) и [midnight commander](https://ru.wikipedia.org/wiki/Midnight_Commander)

# %% [markdown]
# #### 7. Межсетевой экран

# %% [markdown]
# 1. Доступ в Интернет организуется через NAT
# 2. Пользователи подключены через proxy сервер
# 3. Корпоративная почта организована на своем почтовом сервере MAIL
# 4. Корпоративный сайт и внутренние веб ресурсы расположены на веб сервере WWW
# 5. В сети функционирует программный шлюз FW, представляющий собой сервер с ОС Linux, на котором расположен DHCP сервер
# 6. В сети так же есть первичный и вторичный DNS сервера
# 7. В качестве сетевого хранилища используется файловый сервер File Server
# 8. На сервер Backup собираются резервные копии со всех остальных серверов
# 9. Различные события с серверов собираются на сервер логирования Syslog
#
# DMZ – сегмент серверов, которые будут доступны как из внутренней сети, так и из внешней.
# Сервера – сегмент серверов, которые работают только во внутренней сети
# Пользователи – это пользователи
#
# Адреса сетей
# Сегмент DMZ (фиолетовая сеть) – 192.168.250.0/24
# Сегмент серверов (оранжевая сеть) – 192.168.251.0/24
# Сегмент пользователей (розовая сеть) – 192.168.252.0/24
# Адреса сетевых интерфейсов шлюза в каждом сегменте
# Сегмент DMZ (фиолетовая сеть) – 192.168.250.1
# Сегмент серверов (оранжевая сеть) – 192.168.251.1
# Сегмент пользователей (розовая сеть) – 192.168.252.1

# %% [markdown]
# (NAT– это механизм, позволяющий преобразовывать это механизм, позволяющий преобразовывать ip адреса транзитных пакетов.
# Подробнее про NAT можно прочитать [здесь](https://ru.wikipedia.org/wiki/NAT) , или посмотреть  видеоурок видеоурок видеоурок , посвященный этой теме.
# Netfilter– межсетевой экран в Linux.
# Для управления им используется утилита iptables.
#
# Правило — состоит из критерия, действия и счетчика.
# Критерий — логическое выражение, в котором указываются свойства пакета или соединения.
# Действие — что нужно сделать с пакетом или соединением, если они подпадают под критерий правила.
# Счетчик — ведет учет количества пакетов, которые попали под критерий данного правила.

# %% [markdown]
# Цепочка — упорядоченная последовательность правил.  Цепочки можно разделить на пользовательские и базовые.
# Базовая цепочка — цепочка, создаваемая по умолчанию при инициализации таблицы.
# Пользовательская цепочка  — цепочка, созданная пользователем.
# Таблица — совокупность базовых и пользовательских цепочек, объединенных общим функциональным назначением.
#
# Правило 1КритерийДействиеСчетчик

# %% [markdown]
# Таблицы
# raw— пакет проходит данную таблицу до передачи системе определения состояний.
# mangle — содержит правила модификации (обычно полей заголовка) IP пакетов.
# natnatnat— предназначена для подмены адреса отправителя или получателя.
# filter  — основная таблица, используется по умолчанию если название таблицы не указано. Используется для фильтрации пакетов.
# Цепочки
# PREROUTING— для изначальной обработки для изначальной обработки входящих  пакетов
# INPUT — для входящих пакетов, адресованных непосредственно  локальному компьютеру
# FORWARD — для для проходящих(маршрутизируемых) пакетов
# OUTPUT — для пакетов создаваемых локальным компьютером (исходящих)
# POSTROUTING— для окончательной обработки  исходящих пакетов
# Также можно создавать и уничтожать собственные цепочки при помощи утилитыiptables.

# %% [markdown]
# Механизм определения состояний (state machine , connection tracking , conntrack) -позволяетопределить определить  какому соединению принадлежит пакет.
# Типы состояний:
# NEW – новое соединениее
# ESTABLISHED – уже установленное соединение
# RELATED – дополнительное к уже существующему соединению
# INVALID - другое соединение

# %% [markdown]
# ![img-2019-11-22-16-17-56.png](attachment:img-2019-11-22-16-17-56.png)

# %% [markdown]
# ![img-2019-11-22-16-11-10.png](attachment:img-2019-11-22-16-11-10.png)

# %% [markdown]
# ![img-2019-11-22-16-10-52.png](attachment:img-2019-11-22-16-10-52.png)

# %% [markdown]
# Дополнительные ссылки
# 1. [Утилита nmcli](https://linoxide.com/linux-command/nmcli-tool-red-hat-centos-7/)
# 2. [Курс молодого бойца. Настройка NAT](https://www.youtube.com/watch?v=6d2kvuWuyI0&index=13&list=PLcDkQ2Au8aVNYsqGsxRQxYyQijILa94T9)
# 3. [Chkconfig и service](https://habr.com/ru/company/infobox/blog/241237/)

# %% [markdown]
# #### 8. DHCP сервер

# %% [markdown]
# DHCP – это сетевой протокол, который позволяет компьютерам автоматически получать ip адреса.
# Подробнее про DHCP можно прочитать [здесь](https://ru.wikipedia.org/wiki/DHCP) или посмотреть [видеокурс по сетям](https://www.youtube.com/watch?v=voGkaUXFw-I&list=PLcDkQ2Au8aVNYsqGsxRQxYyQijILa94T9).

# %% [markdown]
# Дополнительные ссылки
# 1. Параметры настройки DHCP сервера:[ссылка 1](http://tdkare.ru/sysadmin/index.php/Dhcpd.conf), [ссылка 2](http://www.bender.kz/index.php/servera/5-server-dhcp-na-baze-centos-7)

# %% [markdown]
# #### 9. Заключение

# %% [markdown]
# Что нужно реализовать: Схема сети
# 1. Настроить программный маршрутизатор/ шлюз доступа в Интернет с функциями межсетевого экрана и DHCP сервера
# 2. Ограничить доступ пользователей к сети Интернет с помощью proxy сервера
# 3. Организовать почтовый сервер для корпоративной почты
# 4. Создать веб сервер для корпоративного сайта и внутренних веб ресурсов
# 5. Настроить первичный и вторичный DNS сервера
# 6. Развернуть файловый сервер
# 7. Собирать резервные копии с остальных серверов
# 8. Развернуть сервер логирования для сбора событий с других серверов

# %% [markdown]
# #### 1. Введение
# #### 2. Установка CentOS в VirtualBox
# #### 3. Файловая система и основные команды
# #### 4. Настройка сети
# #### 5. Заведение пользователей
# #### 6. Установка пакетов
# #### 7. Межсетевой экран
# #### 8. DHCP сервер
# #### 9. Заключение

# %% [markdown]
# [youtube 1.Linux для начинающих. Введение](https://www.youtube.com/watch?v=k4AKMLS2Ac8&list=PLcDkQ2Au8aVNMLee8b3RN1QXX0ZBZOYJV)
# []()
# []()
# []()
# []()
# []()
# []()

# %% [markdown]
# []()
# []()
# []()
# []()
# []()
# ```
#
# ```

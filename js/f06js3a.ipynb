# %% [markdown]
# * [Основы jQuery](#Основы-jQuery)
# * [Темы курса](#Темы-курса)
# * [Введение в jQuery](#Введение-в-jQuery)
# * [Темы модуля](#Темы-модуля)
# * [Текстовые редакторы](#Текстовые-редакторы)
# * [Javascript-консоли](#Javascript-консоли)
# * [Javascript-консоль Google Chrome](#Javascript-консоль-Google-Chrome)
# * [Где живет jQuery](#Где-живет-jQuery)
# * [Google CDN](#Google-CDN)
# * [API jQuery](#API-jQuery)
# * [Основа jQuery](#Основа-jQuery)
# * [Выборка](#Выборка)
# * [Работа с выборкой](#Работа-с-выборкой)
# * [Фильтрация](#Фильтрация)
# * [Методы фильтрации](#Методы-фильтрации)
# * [Семейные отношения](#Семейные-отношения)
# * [Семейная выборка - I](#Семейная-выборка---I)
# * [Семейная выборка - II](#Семейная-выборка---II)
# * [Дополнительная выборка](#Дополнительная-выборка)
# * [Работа с атрибутами элементов](#Работа-с-атрибутами-элементов)
# * [Работа с элементами веб-формы](#Работа-с-элементами-веб-формы)
# * [Лабораторная работа - 1](#Лабораторная-работа---1)
# * [События и манипулящии с элементами](#События-и-манипулящии-с-элементами)
# * [Темы модуля](#Темы-модуля)
# * [События jQuery  ](#События-jQuery--)
# * [Обработка событий  ](#Обработка-событий--)
# * [Полезные команды](#Полезные-команды)
# * [Пространства имен событий](#Пространства-имен-событий)
# * [Множественные события](#Множественные-события)
# * [Объект Event ](#Объект-Event-)
# * [Использование параметров](#Использование-параметров)
# * [Отмена действий](#Отмена-действий)
# * [Лабораторная работа - 2.1](#Лабораторная-работа---2.1)
# * [Добавление элементов ](#Добавление-элементов-)
# * [Метод map()](#Метод-map())
# * [Манипуляции с элементами ](#Манипуляции-с-элементами-)
# * [Делегирование событий](#Делегирование-событий)
# * [Лабораторная работа - 2.2](#Лабораторная-работа---2.2)
# * [Анимация в jQuery](#Анимация-в-jQuery)
# * [Темы модуля](#Темы-модуля)
# * [Базовые эффекты](#Базовые-эффекты)
# * [Управление эффектами](#Управление-эффектами)
# * [Лабораторная работа - 3.1](#Лабораторная-работа---3.1)
# * [Метод animate()  ](#Метод-animate()--)
# * [Исследование анимации  ](#Исследование-анимации--)
# * [Лабораторная работа - 3.2](#Лабораторная-работа---3.2)
# * [Полезный метод grep()](#Полезный-метод-grep)
# * [Практическая работа с jQuery](#Практическая-работа-с-jQuery)
# * [Создание кода плавного показа картинок  ](#Создание-кода-плавного-показа-картинок--)
# * [Использование шаблона](#Использование-шаблона)
# * [Шаблонизатор Handlebars](#Шаблонизатор-Handlebars)
# * [Использование  Handlebars](#Использование--Handlebars)

# %% [markdown]
# rtetradJS3a jQuery

# %% [markdown]
# ##### Основы jQuery
# ##### Темы курса
# ##### Введение в jQuery
# ##### Темы модуля
# ##### Текстовые редакторы
# ##### Javascript-консоли
# ##### Javascript-консоль Google Chrome
# ```
# F 12 (Открыть консоль)
# Ctrl + L (Очистить консоль)
# Enter (Выполнить команду)
# Стрелки Down/Up (Перемещение по строкам)
# Стрелка Right (Выбор подсказки)
# Полный экран
# Помощь и настройки
# ```
# ##### Где живет jQuery
# http://jquery.com
# ##### Google CDN
# https://developers.google.com/speed/libraries/
# ##### API jQuery
# http://api.jquery.com
# ##### Основа jQuery

# %% [markdown]
# ```
# jQuery(селектор).действие(параметры);
# jQuery(селектор);
# $(селектор);
# $(document).ready();
# $(function(){});
# ```

# %% [markdown]
# ##### Выборка
# ```
# $('li');
# $('ul li');
# $('#box');
# $('.person');
#  x = $(document.body.children[0]);
# $('li', x);
# ```
# ##### Работа с выборкой
# ```
# $('p').css('font-size');
# $('p').css('color', 'green');
# $('p').addClass('myClass');
# $('p').addClass('one two');
# $('p').removeClass('myClass');
# $('p').toggleClass('myClass');
# ```
# ##### Фильтрация

# %% [markdown]
# ```
# $('li:first-child').addClass('class');
# :first
# :last-child
# :last
# :even
# :odd
# ```

# %% [markdown]
# ##### Методы фильтрации
# ```
# Тестирование выборки
# $('li').is('.class');
# $('li').is(':visible');
# $('li').is(':contains("Text")');
# $('li').filter('.class');
# $('li').has('span');
# $('li').not('.class');
# ```

# %% [markdown]
# ##### Семейные отношения
# ```
# <ul>(parent для всех LI)
# <li>(child для UL)
# <span>(descendant для UL)
# <i>Foo</i>
# </span>
# </li>
# <li>Bar</li>(sibling для LI)
# </ul>(ancrstor для всех внутренних)
# ```
# ##### Семейная выборка - I

# %% [markdown]
# ```
# \$('ul').children('li');
# \$('ul').find('li');
# \$('ul').children('li').eq(1);
# \$('ul').children('li').eq(1).text('?');
# \$('ul').children('li').eq(1).html('?');
# \$('ul').children('li').eq(1).next();
# \$('ul').children('li').eq(1).prev();
# ```
# ##### Семейная выборка - II

# %% [markdown]
# ```
# $('li').first().siblings();
# $('li').parent();
# $('li').parent('ul');
# $('li').parents();
# $('li').closest();
# ```
# ##### Дополнительная выборка

# %% [markdown]
# ```
# Функция в качестве аргумента
# $('li').html(function(index, value){
# return 'NEW' + value;
# });
# ```
# ```
# Добавление выборки
# .add('ul');
# .andSelf();
# ```

# %% [markdown]
# ##### Работа с атрибутами элементов
# ```
# $('form').attr('method', 'get');
# $('form').attr('action',
# function(index, value){
# return value + '?param=1';
# });
# ```
# ##### Работа с элементами веб-формы
# ```
# $('input[type="text"]').val('Text');
# $('input[type="text"]').val();
# $('select').val('5');
# $('input[type="text"]').each(
# function(index, element){
# return value + '?param=1';
# });
# ```
# ##### Лабораторная работа - 1
# labs\lab-1.html
# ##### События и манипулящии с элементами
# ##### Темы модуля
# ##### События jQuery
# ```
# click .click()
# keydown .keydown()
# keypress .keypress()
# keyup .keyup()
# mouseover .mouseover()
# mouseout .mouseout()
# mouseenter .mouseenter()
# mouseleave .mouseleave()
# scroll .scroll()
# focus .focus()
# blur .blur()
# resize .resize()
# ```
# ##### Обработка событий
# ```
# $('li').click(function(event){
# console.log($(this).text());
# });
# $('li').on('click', function(event){
# console.log($(this).text());
# });
# ```
# ##### Полезные команды
# ```
# Анимационные методы
# .hide();
# .show();
# .toggle();
# Методы исполнения событий
# .click();
# .trigger('click');
# .off('click')ж
# ```
# ##### Пространства имен событий
# ```
# .on('click.foo', …);
# .on('click.bar', …);
# .trigger('click.foo');
# .off('click.foo');
# ```
# ##### Множественные события
# ```
# .on('mouseenter mouseleave', …);
# .on('resize.foo scroll.bar', …);
# ```
# ##### Объект Event
# ```
# .type
# .which
# .target
# .currentTarget
# .pageX
# .pageY
# .namespace
# .timeStamp
# ```
# ##### Использование параметров
# ```
# .on('click', {val:'x', param:25},
# function(event){
# console.log(event.data.param);
# });
# ```
# ##### Отмена действий
# ```
# Действия по умолчанию
# $('a').on('click', function(event){
# event.preventDefault();
# });
# Всплытия пузырька
# $('*').on('click', function(event){
# event.stopPropagation();
# });
# ```
# ##### Лабораторная работа - 2.1
# labs\lab-2-1.html
# ##### Добавление элементов
# ```
# $('div').append('Какая-то строка');
# .prepend();
# .after();
# .before();
# $('<p>Абзац</p>').appendTo('div');
# .prependTo();
# .insertAfter();
# .insertBefore();
# ```
# ##### Метод map()
# ```
#  h3 = $('h3').map(function(i, o){
# return $(o).text();
# });
# $('ul').text(
# $.map(h3, function(o, i){
# return '<li>'+h3[i]+'</li>';
# }).join()
# );
# ```
# ##### Манипуляции с элементами
# ```
# Копирование
# $('li').clone();
# Удаление
# $('ul li').first().remove();
# Вырезание
# $('ul li').first().detach();
# Замена
# $('ul li').first().replaceWith('…');
# ```
# ##### Делегирование событий
# ```
# $('dl').on('click', 'dt', function(){
# });
# $('<dt>New dt</dt>').appendTo('dl');
# ```
# ##### Лабораторная работа - 2.2
# labs\lab-2-2.html

# %% [markdown]
# ##### Анимация в jQuery
# ##### Темы модуля
# ##### Базовые эффекты
# ```
# .slideUp(2000);
# .slideDown('slow');
# .slideToggle('fast');
# .fadeIn();
# .fadeOut();
# .fadeToggle();
# ```
# ##### Управление эффектами
# ```
# $.fx.speeds._default = 2000;
# $.fx.speeds.mySpeed = 5000;
# .slideDown('mySpeed');
# .delay(2000);
# .stop();
# ```
# ##### Лабораторная работа - 3.1
# labs\lab-3-1.html
# ##### Метод animate()
# ```
# $('p').animate({
# 'font-size': '+=5',
# 'width': '+=200'
# });
# $('p').animate({
# 'font-size': '+=5',
# 'width': '+=200'
# }, 500, 'swing', function(){});
# ```
# ##### Исследование анимации
# ```
# $('p').animate(
# {'font-size': '+=5'},
# {'duration': 500,
# complete: function(){},
# stop: function(){}
# }
# );
# queue: true
# 'height': 'toggle'
# 'opacity': 'toggle'
# ```

# %% [markdown]
# ##### Лабораторная работа - 3.2
# labs\lab-3-2.html
# ##### Полезный метод grep

# %% [markdown]
# ```
# myArray = [1, 2, 3, 4, 5, 6, 7];
# $.grep(myArray, function(val, key){
# return val > 3;
# });
# Базовые эффекты
# Управление эффектами
# Метод animate()
# Исследование анимации
# Полезный метод grep()
# ```

# %% [markdown]
# ##### Практическая работа с jQuery
# ##### Создание кода плавного показа картинок
# ```
# Картинки должны плавно прокручиваться
# Кнопка "Вперед": прокрутка влево
# Кнопка "Назад": прокрутка вправо
# ```
# ##### Использование шаблона
# ```
# <script id="myTemplate" type="text/template">
# <div class="book">
# <h1>{{title}}</h1>
# </div>
# </script>
#  template = $('#myTemplate').html();
#  tmp = template.replace(/{{title}}/, 'jQuery');
# $(document.body).append(tmp);
# ```
# ##### Шаблонизатор Handlebars
# http://handlebars.com
# ##### Использование  Handlebars
# ```
# <script id="myTemplate" type=" text/x-handlebarstemplate">
# <div class="book">
# <h1>{{title}}</h1>
# </div>
# </script>
#  template = $('#myTemplate').html();
#  tmp = Handlebars.complie(template);
# $(document.body).append(tmp(title));
# ```

# %% [markdown]
# Q:\02progr\01web\[Специалист] JavaScript. Уровень 3а

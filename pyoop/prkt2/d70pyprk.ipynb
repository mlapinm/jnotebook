# %% [markdown]
# [py070 применение простых регулярных выражений](#py070-применение-простых-регулярных-выражений)
# [py071 Питон обслуживание клавиатуры](#py071-Питон-обслуживание-клавиатуры)
# [py072 Простое наследование классов ttk](#py072-Простое-наследование-классов-ttk)
# [py073 Простейший текстовый редактор](#py073-Простейший-текстовый-редактор)
# [py074 программа на Python для исследования Atmega8](#py074-программа-на-Python-для-исследования-Atmega8)
# [py075 DBSN формирование записи](#py075-DBSN-формирование-записи)
# [py076 DBSN - структура записи](#py076-DBSN---структура-записи)
# [py077 DBSN структура записи реального документа](#py077-DBSN-структура-записи-реального-документа)
# [py078 DBSN заполняем запись данными документа](#py078-DBSN-заполняем-запись-данными-документа)
# [py079 Сравнение питонов 2 и 3](#py079-Сравнение-питонов-2-и-3)

# %% [markdown]
# #### py070 применение простых регулярных выражений

# %%
# %%writefile alg1.htm
# Out:
# UsageError: %%writefile is a cell magic, but the cell body is empty.

# %%
# %%writefile alg12.htm
# <html>
#
# <head>
# <meta http-equiv=Content-Type content="text/html; charset=windows-1251">
# <meta name=Generator content="Microsoft Word 11 (filtered)">
# <title>Тест для проверки остаточных знаний </title>
#
# </head>
#
# <body lang=RU>
#
# <div class=Section1>
#
# <p class=MsoNormal align=center style='text-align:center'><b>Тест для проверки
# остаточных знаний </b></p>
#
# <p class=MsoNormal align=center style='text-align:center'><b>по дисциплине
# «Алгебра и геометрия»</b></p>
#
# <p class=MsoNormal align=center style='text-align:center'><b>для студентов
# направлений «Программная инженерия» (профиль «Разработка
# программно-информационных систем»),</b></p>
#
# <p class=MsoNormal align=center style='text-align:center'><b>«Педагогическое
# образование» (профиль «Информатика и информационные технологии в образовании»)</b></p>
#
# <p class=MsoNormal align=center style='text-align:center'>&nbsp;</p>
#
# <p class=MsoNormal style='text-align:justify;text-indent:27.0pt'><b><i>Семестр
# изучения: </i></b><i>1, 2.</i></p>
#
# <p class=MsoNormal style='text-align:justify;text-indent:27.0pt'><b><i>Дата
# составления: </i></b><i>20.12.2018<b> </b></i></p>
#
# <p class=MsoNormal style='text-align:justify;text-indent:27.0pt'><b><i>Разработчик:
# </i></b><i>ст. преподаватель кафедры информатики и программной инженерии Е.С.
# Гарбузняк<b>  </b></i></p>
#
# <p class=MsoNormal style='text-indent:1.0cm;background:white'><b><i>Время
# прохождения теста: </i></b><i>90 мин</i></p>
#
# <p class=MsoNormal style='text-align:justify;text-indent:27.0pt'>&nbsp;</p>
#
# <p class=MsoNormal align=center style='text-align:center;background:white'><b><span
# lang=EN-US style='text-transform:uppercase'>I</span><span style='text-transform:
# uppercase'> вариант</span></b></p>
#
# <p class=MsoNormal style='background:white'>&nbsp;</p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section2>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>1.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><span style='color:black'>Квадратная матрица, у которой только элементы
# главной диагонали отличны от нуля, называется:</span></p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section3>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>a)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>нулевой;    </p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>b)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>единичной;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>c)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>диагональной;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>d)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </span>нет
# правильного ответа.</p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section4>
#
# <p class=MsoNormal style='text-align:justify;text-indent:1.0cm'>&nbsp;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>2.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><span style='color:black'>Ранг матрицы размера </span><i><span
# lang=EN-US style='color:black'>n</span><span style='color:black'>&times;</span></i><i><span
# lang=EN-US style='color:black'>n</span><span lang=EN-US style='color:black'> </span></i><span
# style='color:black'>равен:</span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>a)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><i><span lang=EN-US style='color:black'>n</span></i><span
# style='color:black'>;</span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>b)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><i><span lang=EN-US style='color:black'>n – 1</span></i><span
# style='color:black'>;</span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>c)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><i><span lang=EN-US style='color:black'>n – 1</span></i><span
# lang=EN-US style='color:black'>,</span><span style='color:black'> если матрица
# вырождена;</span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>d)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </span><span
# style='color:black'>указанных условий недостаточно для определения ранга
# матрицы.</span></p>
#
# <p class=MsoNormal style='text-align:justify;text-indent:1.0cm'><span
# style='color:black'>&nbsp;</span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>3.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><span style='color:black;background:white'>Элемент&nbsp;&nbsp;</span><img
# width=24 height=27 src="alg1.files/image001.gif"><span style='color:black;
# background:white'>обратной матрицы <i>A<sup>-1</sup></i>&nbsp;&nbsp;(в случае
# существования) вычисляется по формуле</span><span style='color:black'>:</span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>a)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><img width=123 height=41 src="alg1.files/image002.gif">,<span
# style='color:black;background:white'> где <i>M<sub>ij</sub></i></span><sub><span
# style='font-size:10.0pt'> </span></sub><span style='font-size:10.0pt'> –</span>
# минор элемента <i><span lang=EN-US>a</span><sub><span style='color:black;
# background:white'>ij</span></sub></i><sub><span style='font-size:10.0pt'> </span></sub>матрицы
# <i>А</i>;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>b)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><img width=125 height=41 src="alg1.files/image003.gif">,<span
# style='color:black;background:white'> где <i>M<sub>ji</sub></i></span><sub><span
# style='font-size:10.0pt'> </span></sub><span style='font-size:10.0pt'> –</span>
# минор элемента <i><span lang=EN-US>a</span><sub><span style='color:black;
# background:white'>ji</span></sub></i><sub><span style='font-size:10.0pt'> </span></sub>матрицы
# <i>А</i>;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>c)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><img width=24 height=47 src="alg1.files/image004.gif">,<span
# style='color:black;background:white'> где </span><i><span lang=EN-US>a</span><sub><span
# style='color:black;background:white'>ij</span></sub></i><sub><span
# style='font-size:10.0pt'> </span></sub><span style='font-size:10.0pt'> –</span>
# элемент матрицы <i>А</i>;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>d)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </span><img
# width=79 height=49 src="alg1.files/image005.gif">,<span style='color:black;
# background:white'> где </span><i><span lang=EN-US>a</span><sub><span
# style='color:black;background:white'>ij</span></sub></i><sub><span
# style='font-size:10.0pt'> </span></sub><span style='font-size:10.0pt'> –</span>
# элемент матрицы <i>А</i>.</p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section5></div>
#
# <b><span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span></b>
#
# <div class=Section6>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>4.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><span style='color:black'>Если </span><img width=59 height=23
# src="alg1.files/image006.gif"><span style='color:black'>, то:</span></p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section7>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>a)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><img width=44 height=46 src="alg1.files/image007.gif"><span
# style='color:black'>;</span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>b)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><img width=59 height=23 src="alg1.files/image008.gif"><span
# style='color:black'>;</span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>c)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><img width=59 height=23 src="alg1.files/image009.gif"><span
# style='color:black'>;</span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>d)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </span><img
# width=72 height=23 src="alg1.files/image010.gif"><span style='color:black'>.</span></p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section8></div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section9>
#
# <p class=MsoNormal style='text-indent:1.0cm'>&nbsp;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>5.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><span style='color:black'>При решении системы </span><img width=85
# height=48 src="alg1.files/image011.gif"><i> </i><span style='color:black'>по
# формулам Крамера:</span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>a)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><img width=241 height=48 src="alg1.files/image012.gif"><span
# style='color:black'>;</span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>b)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><img width=241 height=48 src="alg1.files/image013.gif"><span
# style='color:black'>;</span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>c)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><img width=218 height=48 src="alg1.files/image014.gif"><span
# style='color:black'>;</span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>d)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </span><img
# width=241 height=48 src="alg1.files/image015.gif"><span style='color:black'>.</span></p>
#
# <p class=MsoNormal style='text-indent:1.0cm'>&nbsp;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>6.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><span style='color:black'>Система однородных линейных уравнений с <i>n</i>
# неизвестными и матрицей <i>А</i> имеет ____ линейно независимых решений.</span></p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section10>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>a)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><i><span style='color:black'>n – RgA</span></i><span style='color:black'>;</span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>b)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><i><span style='color:black'>n + RgA</span></i><span style='color:black'>;</span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>c)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><i><span style='color:black'>n</span></i><span style='color:black'>;</span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>d)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </span><i><span
# style='color:black'>RgA – n</span></i><span style='color:black'>.</span></p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section11></div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman";color:black'><br
# clear=all style='page-break-before:auto'>
# </span>
#
# <div class=Section12>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>7.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><span style='color:black'>Косинус угла между векторами </span><img
# width=27 height=21 src="alg1.files/image016.gif"><i> </i>и <img width=28
# height=23 src="alg1.files/image017.gif">, если <img width=68 height=21
# src="alg1.files/image018.gif"><i> </i><img width=69 height=21
# src="alg1.files/image019.gif"> <img width=67 height=21
# src="alg1.files/image020.gif"><span style='color:black'>, равен:</span></p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section13>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>a)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>1;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>b)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>–1;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>c)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>0;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>d)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </span>0,5;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>e)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>нет правильного ответа.</p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section14>
#
# <p class=MsoNormal style='text-align:justify;text-indent:1.0cm'>&nbsp;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>8.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>Параметр <i>&#946;</i>, при котором компланарны векторы <img width=73
# height=21 src="alg1.files/image021.gif"><span style='color:black;background:
# white'>, </span><img width=77 height=26 src="alg1.files/image022.gif"><span
# style='color:black;background:white'>и&nbsp;</span><img width=70 height=26
# src="alg1.files/image023.gif">, равен:</p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section15>
#
# <p class=MsoNormalCxSpFirst style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>a)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><img width=27 height=39 src="alg1.files/image024.gif">;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>b)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>   <img width=16 height=38 src="alg1.files/image025.gif">;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>c)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>    1;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>d)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>   <img width=18 height=42 src="alg1.files/image026.gif">;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>e)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>   <img width=16 height=41 src="alg1.files/image027.gif">.</p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section16>
#
# <p class=MsoNormalCxSpMiddle style='text-align:justify;text-indent:1.0cm'>&nbsp;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm;
# background:white'>9.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><span style='color:black;background:white'>Пусть векторы&nbsp;</span><img
# width=14 height=17 src="alg1.files/image028.gif">и&nbsp;<img width=13
# height=23 src="alg1.files/image029.gif"><span style='color:black;background:
# white'>&nbsp;заданы координатами&nbsp;</span><img width=14 height=17
# src="alg1.files/image028.gif"><span style='color:black;background:white'>= (<i>a<sub>x</sub>,
# a<sub>y</sub>, a<sub>z</sub></i>) и&nbsp;</span><img width=13 height=23
# src="alg1.files/image029.gif"><span style='color:black;background:white'>&nbsp;=
# (<i>b<sub>x</sub>, b<sub>y</sub>, b<sub>z</sub></i>). Тогда </span><img
# width=37 height=21 src="alg1.files/image030.gif"><span style='color:black;
# background:white'>&nbsp;вычисляется по формуле</span><span style='color:black'>:</span></p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section17>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>a)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><img width=73 height=67 src="alg1.files/image031.jpg">;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>b)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><img width=75 height=63 src="alg1.files/image032.jpg">;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>c)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><img width=73 height=65 src="alg1.files/image033.jpg">;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>d)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><img width=80 height=71 src="alg1.files/image034.jpg">.</p>
#
# <p class=MsoNormalCxSpLast style='text-align:justify;text-indent:1.0cm'>&nbsp;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>10.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp; </span><span
# style='color:black'>Векторы </span><img width=80 height=21
# src="alg1.files/image035.gif">,<i> </i><img width=80 height=24
# src="alg1.files/image036.gif">, <img width=79 height=21
# src="alg1.files/image037.gif"><span style='color:black'> являются:</span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>a)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>линейно зависимыми;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>b)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>линейно независимыми;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>c)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>компланарными;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>d)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </span>базисом
# в четырехмерном пространстве.</p>
#
# <p class=MsoNormal style='text-align:justify;text-indent:1.0cm'>&nbsp;</p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section18>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>11.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp; </span><span
# style='color:black'>Преобразование в случае, когда матрица линейного
# преобразования вырожденная, является:</span></p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section19>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm;
# line-height:13.2pt;background:white'>a)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><span style='color:black'>вырожденным;</span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm;
# line-height:13.2pt;background:white'>b)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><span style='color:black'>невырожденным;</span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm;
# line-height:13.2pt;background:white'>c)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><span style='color:black'>сопряженным.</span></p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section20>
#
# <p class=MsoNormal style='text-indent:1.0cm'>&nbsp;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm;
# background:white'>12.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;
# </span>Для любых двух элементов <img width=14 height=17
# src="alg1.files/image028.gif">&nbsp;и&nbsp;<img width=14 height=21
# src="alg1.files/image038.gif">&nbsp;произвольного евклидова пространства
# справедливо неравенство <img width=103 height=24 src="alg1.files/image039.gif">,
# называемое неравенством:</p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section21>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>a)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>Миньковского;    </p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>b)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>Вронского;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>c)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>Коши-Буняковского;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>d)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </span>Евклида.</p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section22>
#
# <p class=MsoNormal style='text-align:justify;text-indent:1.0cm'>&nbsp;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-indent:1.0cm;background:white'>13.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp; </span>Матрица <i>А</i>,
# удовлетворяющая условиям <i>АА<sup>Т</sup> = А<sup>Т</sup>А = Е</i>,
# называется:</p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section23>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>a)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>ортонормированной;    </p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>b)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>ортогональной;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>c)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>евклидовой.</p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section24></div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section25>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>14.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp; </span><span
# style='color:black'>Кривую второго порядка определяет уравнение: </span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>a)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><i><span lang=EN-US>ax + by + c = 0,</span></i><i><span lang=EN-US
# style='font-size:10.0pt'>  </span></i><img width=77 height=21
# src="alg1.files/image040.gif"><span style='color:black'>;</span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>b)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><i><span lang=EN-US>ax + by + cz + d =0,  </span></i><img width=108
# height=21 src="alg1.files/image041.gif"><span style='color:black'>;</span></p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>c)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><img width=242 height=23 src="alg1.files/image042.gif">, <img width=119
# height=24 src="alg1.files/image043.gif">;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>d)<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; </span><img
# width=416 height=23 src="alg1.files/image044.gif"><i><span style='font-size:
# 10.0pt'>,</span></i><img width=107 height=23 src="alg1.files/image045.gif"></p>
#
# <p class=MsoNormal style='text-indent:1.0cm'>&nbsp;</p>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>15.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp; </span>Условие
# перпендикулярности двух прямых <i>y = k<sub>1</sub></i><i><span lang=EN-US>x</span>
# + </i><i><span lang=EN-US>b</span><sub>1</sub></i> и <i>y = k<sub>2</sub></i><i><span
# lang=EN-US>x</span> + </i><i><span lang=EN-US>b</span><sub>2</sub></i>:</p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section26>
#
# <p class=MsoNormalCxSpFirst style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>a)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><i><span lang=EN-US>k<sub>1</sub> = </span>–</i><i><span lang=EN-US> k<sub>2
# </sub> </span></i><span lang=EN-US>и<i>  b<sub>1</sub> = b<sub>2</sub></i></span><sub>;</sub></p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>b)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><i><span lang=EN-US>k<sub>1</sub>&#8729;k<sub>2</sub> = – 1</span></i>;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>c)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><i><span lang=EN-US>k<sub>1</sub> = k<sub>2</sub></span></i><sub>;</sub></p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>d)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><i><span lang=EN-US>b<sub>1</sub> = b<sub>2</sub></span></i><sub>;</sub></p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>e)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><i><span lang=EN-US>k<sub>1</sub>&#8729;k<sub>2</sub> = 1</span></i>.</p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section27>
#
# <p class=MsoNormalCxSpMiddle style='text-align:justify;text-indent:1.0cm'>&nbsp;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>16.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;
# </span>Расстояние от точки <i>M<sub>0</sub>(</i><i><span lang=EN-US>x</span><sub>0</sub>,
# y<sub>0</sub>,<sub> </sub></i><i><span lang=EN-US>z</span><sub>0</sub>)</i> до
# плоскости <i>Ax + By + Cz + D = 0</i> вычисляется по формуле:</p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section28>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>a)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><sub><img width=109 height=43 src="alg1.files/image046.gif"></sub> ;  </p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>b)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><sub><img width=135 height=46 src="alg1.files/image047.gif"></sub> ;   </p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>c)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><sub><img width=159 height=46 src="alg1.files/image048.gif"></sub> ;   </p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>d)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><sub><img width=133 height=43 src="alg1.files/image049.gif"></sub> ;   </p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>e)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><i><span lang=EN-US>d</span></i> = <sub><img width=106 height=44
# src="alg1.files/image050.gif"></sub>.</p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section29></div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman";color:red'><br
# clear=all style='page-break-before:auto'>
# </span>
#
# <div class=Section30>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>17.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp; </span>Уравнениями
# асимптот гиперболы  <sub><img width=69 height=42 src="alg1.files/image051.gif"></sub> являются:</p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section31>
#
# <p class=MsoNormalCxSpFirst style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>a)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><sub><img width=56 height=38 src="alg1.files/image052.gif"></sub>;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>b)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><sub><img width=56 height=38 src="alg1.files/image053.gif"></sub>;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>c)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><sub><img width=50 height=18 src="alg1.files/image054.gif"></sub>;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>d)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><sub><img width=50 height=18 src="alg1.files/image055.gif"></sub>;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>e)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span><sub><img width=43 height=18 src="alg1.files/image056.gif"></sub>.</p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section32>
#
# <p class=MsoNormalCxSpMiddle style='text-align:justify;text-indent:1.0cm'>&nbsp;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>18.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;
# </span>Значение эксцентриситета окружности равно:</p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section33>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>a)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>0;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>b)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>1;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>c)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>-1;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>d)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>&lt;1;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>e)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>&gt;1<span lang=EN-US>.</span></p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section34></div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:auto'>
# </span>
#
# <div class=Section35>
#
# <p class=MsoNormal style='margin-left:0cm;text-align:justify;text-indent:1.0cm'>19.<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp; </span>Уравнение <sub><img
# width=97 height=42 src="alg1.files/image057.gif"></sub> определяет в
# пространстве:</p>
#
# <p class=MsoNormalCxSpFirst style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>a)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>конус;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>b)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>однополостный гиперболоид;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>c)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>двуполостный гиперболоид;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>d)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>эллиптический параболоид;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>e)<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span>две пересекающиеся плоскости.</p>
#
# <p class=MsoNormalCxSpMiddle style='text-align:justify;text-indent:1.0cm'>&nbsp;</p>
#
# <p class=MsoNormalCxSpMiddle style='margin-left:0cm;text-align:justify;
# text-indent:1.0cm'>20.<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;
# </span>Поверхность, изображённая на рисунке, определяется уравнением:</p>
#
# <p class=MsoNormalCxSpMiddle style='text-align:justify;text-indent:1.0cm'><img
# width=173 height=167 src="alg1.files/image058.gif"></p>
#
# </div>
#
# <span style='font-size:12.0pt;font-family:"Times New Roman"'><br clear=all
# style='page-break-before:always'>
# </span>
#
# <div class=Section36>
#
# <p class=MsoNormal>&nbsp;</p>
#
# </div>
#
# </body>
#
# </html>
# Out:
# Overwriting alg12.htm

# %%
# %%writefile prep.py
# coding: utf-8
# вспомогательные функции для формирования тестов
import re
import codecs

# записать текст в файл
def write_text( fil_name, text ):
    fh = codecs.open( fil_name, 'w','utf-8' )
    fh.write(text)
    fh.close( )

# прочитать текст из файла    
def read_text(fil_name ):
    fh = codecs.open( fil_name ,'r','cp1251')
    text = fh.read( )
    fh.close( )
    return text

# удалить непарный тэг     
def cut_tag( tag, text ):
    st = "<" + tag + "[^>]*?>"
    rex = re.compile( st )
    return re.sub( rex, "", text)

# очистить параметры тэгв
def clear_tagparams( tag, text ):
    st = "<" + tag + "[^>]*?>"
    rex = re.compile( st )
    return re.sub( rex, "<" + tag + ">" , text)

# удалить тэг и его завершение
def cut_tagpair( tag, text ):
    st = "<" + tag + "[^>]*?>"
    rex = re.compile( st )
    text = re.sub( rex, "", text)
    rex = re.compile( r"<\/"+tag+">" )
    return re.sub( rex, "", text)

# удалить полностью тэг с содержимым до завершающего включительно
def cut_fulltag( tag, text ):
    st = "<" + tag + r"[\s\S]*?<\/" + tag + ">"
    rex = re.compile( st )
    return re.sub( rex, "", text)

# извлечь содержимое тега
def get_tagcontent(tag, text):
    st = "<"+tag+"[^>]*?>([\s\S]*?)<\/"+tag+">"
    rex = re.compile(st)
    res = re.search( rex, text)
    return res.group(1)
            
# очистить группы неразрывных пробелов
def clear_nbsp( text ):
    rex = re.compile( "(&nbsp;)+" )
    return re.sub( rex, " ", text)

# очистить группы пустых строк
def clear_eol( text ):
    rex = re.compile( "[\n\r]+" )
    return re.sub( rex, "\n", text)
# Out:
# Overwriting prep.py

# %%
#coding: cp1251
import re
import prep

#--функци¤ обработки одного блока вопросов    
def make_form( quest_num, ls_questdelim, ls_quest ):
    quest = ls_quest[ quest_num ]
    quest_delim = ls_questdelim[quest_num -1]
    
    rex_answ = re.compile("<p>\S\)")
    ls_answdelim = re.findall(rex_answ, quest)
    ls_answ = re.split(rex_answ, quest)
    
    quest_head = quest_delim + ls_answ[0].strip()
    form = '\n<FORM NAME ="f'+ str(quest_num) + '" class = "answers"> ' + quest_head
    for answ_num in range(1, len(ls_answ)):
        answ_delim = ls_answdelim[ answ_num-1 ]
        answ = ls_answ[answ_num ].strip()
        form += '\n    '+ answ_delim + '<INPUT TYPE="radio" NAME="rd1" value = '
        form += str(answ_num) +'>'+answ
    form += '\n</FORM>'
    form +='\n<hr color = blue align = center width = 50%>\n'
    return form
    
#-- прочитать исходный файл
# fil_name = input('input file name:')
fil_name = 'alg1.htm'
text = prep.read_text(fil_name)

#-- удалить весь тэг style с содержимым в заголовке
head = prep.get_tagcontent('head', text)
head = prep.cut_fulltag('style', head)

#-- удалить все неразрывные пробелы из body
text = prep.get_tagcontent('body', text)
text = prep.clear_nbsp( text)

#-- удалить все парные тэги span div
text = prep.cut_tagpair('span', text)
text = prep.cut_tagpair('div', text)

#-- удалить непарные тэги
text = prep.cut_tag('br', text)

#-- стереть параметры в тэге р
text = prep.clear_tagparams('p', text)

#-- стереть лишние концы строк
text = prep.clear_eol( text)

#-- сформировать список заданий
rex_quest = re.compile("<p>\d+\.")
ls_questdelim = re.findall(rex_quest, text)
ls_quest = re.split(rex_quest, text)

#-- сформировать новое body
text = ls_quest[ 0 ]
for form_num in range(1, len(ls_quest)):
    form =  make_form( form_num, ls_questdelim, ls_quest )
    text += form

#--дописать подвал страницы
footer ='''
\n<script src="test_calc.js"></script>

<p></p>
   <FORM NAME ="formrez">
      <P  ALIGN = CENTER >
      <INPUT TYPE="text" NAME="test_res" id="test_res" SIZE=80 VALUE=" " style="font-size:20px">
      <br>     
      <INPUT TYPE="button" VALUE="–езультат" onClick="CalcMark();" style="font-size:20px">
   </FORM>\n
'''
text += footer

#--сформировать полный результат
new_page = "<html><head>" + head +"</head>"
new_page +="<body> "+ text +"</body></html>"

#--записать результат в файл htm 
prep.write_text( "res"+fil_name, new_page)

# %% [markdown]
# #### py071 Питон обслуживание клавиатуры
# #### py072 Простое наследование классов ttk

# %%
#coding: utf8
##-- abgttk0.pyw for some graph classes 
##-- ver 1.0 by A.B.Glazov

#-- подключить библиотеки
from tkinter import *
from tkinter import ttk
from tkinter.font import Font
from tkinter import filedialog as tkFileDialog

#-- упрощенные классы виджетов 

##-- кнопка с наборои параметров
class Buttongrid(  ttk.Button):
    def __init__( self, panel, row_num, col_num, btn_text, btn_width = 10, btn_fnc = ""):
        ttk.Button.__init__(self, panel, text = btn_text, width = btn_width)
        self.grid(row = row_num, column = col_num, sticky=E+N, pady = 5 , padx = 5)
        if btn_fnc != "":
            self.bind("<Button-1>", btn_fnc)

##-- поле ввода с меткой
class Labelentry(ttk.Entry):
    def __init__( self, panel, row_num, col_num, lab_text = "",
                  ent_width = 10,  init_val = "",
                  fnc_return = "", col_span = 1 ):
        self.var = StringVar()
        ttk.Entry.__init__( self, panel,  width = ent_width, textvariable = self.var, font = dFont)
        self.var.set(init_val)
        if  fnc_return  !=  "":
            self.bind('<Return>', fnc_return)

        if len(lab_text) > 0:
            self.lab = ttk.Label( panel, text=lab_text , font = dFont )
            self.lab.grid( row = row_num, column = col_num, sticky = E , padx = 5)
        self.grid(row = row_num, column = col_num + 1, columnspan = col_span, sticky=W, pady = 5, padx=5 )

    def  get(self):
        return  self.var.get()

    def  set( self, new_text ):
        self.var.set(new_text)

##-- раскрывающийся список с меткой
class Labelcombobox(ttk.Combobox):
    def __init__( self, panel, row_num, col_num, lab_text = "",  cbx_width = 20, cbx_height = 6, lst_values = [1,2,3], fnc_sel = 0, row_span = 1, col_span = 1):
        if len(lab_text) > 0:
            self.lab = ttk.Label( panel, text=lab_text , font = dFont )
            self.lab.grid( row = row_num, column = col_num, sticky = E , padx = 5, columnspan = col_span)

        ttk.Combobox.__init__( self, panel, values = lst_values, height=cbx_height, width = cbx_width, font = dFont)
        self.set(lst_values[0])   
        self.grid(row = row_num, column = col_num + 1, sticky = W, pady = 5, padx = 5)
        if fnc_sel != 0:
            self.bind("<<ComboboxSelected>>", fnc_sel)

    def  get_index(self):
        try:
            return  self.current()
        except:
            return -1

    def  set_index(self, index):
        try:
            self.current( index )
            return index 
        except:
            return  -1

    def load(self, file_name):
        if len(file_name) >=1:
            self["values"]=[]
            fhn = open(file_name )
            self["values"] = fhn.readlines()
            fhn.close()
            self.set(self["values"][0])
         

##-- список с меткой
class Labellistbox(Listbox):
    def __init__( self, panel, row_num, col_num, lab_text = "",  lbx_width = 20, lbx_height = 6, lst_values = [1,2,3], fnc_dbl = 0, row_span = 1, col_span = 1):
        self.panel = ttk.Frame(panel )

        Listbox.__init__( self, self.panel, width = lbx_width, height=lbx_height, font = dFont)

        if len(lab_text) > 0:
            self.lab = ttk.Label( panel, text=lab_text , font = dFont )
            self.lab.grid( row = row_num, column = col_num, sticky = W , padx = 5, columnspan = col_span)
        self.panel.grid(row = row_num+1, column = col_num, sticky = W , padx = 5, columnspan = col_span, pady = 5)

        for str_lbx in lst_values:
            Listbox.insert(self, END, str_lbx)

        self.pack(side="left", fill="y")
        self.scbr = Scrollbar(self.panel, orient="vertical")
        self.scbr.pack(side="right", fill="y")

        self.scbr.config(command=self.yview)
        self.config(yscrollcommand=self.scbr.set)

        if fnc_dbl != 0:
            self.bind('<Double-Button-1>', fnc_dbl)

    def  append( self, new_text ):
        Listbox.insert(self, END, new_text )
        
            
    def  get(self):
        try:
            return Listbox.get(self, self.curselection()[0])
        except:
            return ""

    def  get_index(self):
        try:
            return  self.curselection()[0]
        except:
            return -1

    def  set_index(self, index):
        try:
            #self.selection_clear()
            self.select_clear(0, "end")
            self.selection_set( index )
            self.see(index)
            self.activate(index)
            self.selection_anchor(index)
            return index 
        except:
            return  -1

    def  clear(self):
        Listbox.delete(self, 0, END)
    
    def  insert( self, new_text ):
        sel_num = self.get_index()
        if sel_num >= 0:
            Listbox.insert(self, sel_num, new_text )
        else:
            Listbox.insert(self, END, new_text )
            
    def  delete(self):
        sel_num = self.get_index()
        if sel_num >= 0:
            Listbox.delete( self, sel_num )

    def save(self, file_name):
        if len(file_name) >=1:
            fhn = open(file_name, "w")
            lst = list(Listbox.get(self, 0, END))
            lst.append("")
            fhn.write('\n'.join(lst))
            fhn.close()
            
    def load(self, file_name):
        if len(file_name) >=1:
            fhn = open(file_name )
            lst_values = fhn.readlines()
            fhn.close()

            Listbox.delete(self, 0, END)
            for str_loc in lst_values:
                Listbox.insert(self, END, str_loc.strip())
    
#-- настройки оформления
root = Tk()
clr_root = '#FF33FF'
root['bg'] = clr_root
stl = ttk.Style()
dFont = Font(family="helvetica", size=14)
stl.configure('.', font=dFont, background=clr_root, foreground= "black")
stl.configure('TLabel', foreground = 'black', sticky=E,  padx = 10)
stl.configure('TEntry', padx= 5, pady= 5, sticky = W, font=dFont)
stl.configure('TButton', padx= 5, pady= 5, sticky = W, font=dFont)
stl.configure('TCombobox', padx= 5, pady= 5, sticky = W, width = 10, font=dFont)


#-- заголовок
ttk.Label(root, text = 'Простое наследование ttk классов ' ).grid(row = 0, column = 0, columnspan = 4) 

#-- левый листбокс 
def fnc_lbxdblleft(ev):
    edt_str.set(  lbx_left.get() )

lbx_left = Labellistbox( root, 1,0, u"левый список строк:", 
                30, 16, [], 
                fnc_lbxdblleft, 6, 2 )

#-- правый листбокс 
def fnc_lbxdblright(ev):
    edt_str.set(  lbx_right.get() )

lbx_right = Labellistbox( root, 1,2, u"правый список строк:", 
                30, 16, ['aaa','bbb','ccc'], 
                fnc_lbxdblright, 6, 2 )

#-- кнопка очистки левого списка
def fnc_clearleft(event):
    lbx_left.clear()

btn_clearleft = Buttongrid( root, 7, 1, u'очистить', 10, fnc_clearleft)

#-- кнопка очистки правого списка
def fnc_clearright(event):
    lbx_right.clear()

btn_clearright = Buttongrid( root, 7, 3, u'очистить', 10, fnc_clearright)

#-- выпадающий списрк новой строки
def fnc_cbxstr(event):
    edt_str.set( cbx_str.get() )
    
cbx_str = Labelcombobox( root, 8, 0, u'выбрать',
                22, 6, ['aaa','bbb','ccc'],
                fnc_cbxstr)
cbx_str.load("1.txt")

#-- поле ввода новой строки
def fnc_edtstr(event):
    lbx_left.append( edt_str.get())

edt_str = Labelentry( root, 9, 0, u'строка:',
                24,'begin',
                fnc_edtstr )

#-- кнопка добавки в левый список
def fnc_addleft(event):
    lbx_left.append( edt_str.get() )

btn_addleft = Buttongrid( root, 10, 1, u'добавить', 10, fnc_addleft)

#-- кнопка добавки в правый список
def fnc_addright(event):
    lbx_right.append( edt_str.get() )

btn_addright = Buttongrid( root, 8, 2, u'добавить', 10, fnc_addright)

#-- кнопка вставки в правый список
def fnc_insertright(event):
    lbx_right.insert( edt_str.get() )

btn_insertright = Buttongrid( root, 8, 3, u'вставить', 10, fnc_insertright)

#-- кнопка удалить из правого списка
def fnc_deleteright(event):
    lbx_right.delete( )

btn_deletetright = Buttongrid( root, 7, 2, u'удалить', 10, fnc_deleteright)

#-- кнопка загрузки правого списка из файла
def fnc_loadright(event):
    file_name = tkFileDialog.Open(root, filetypes = [('*.txt files', '.txt')]).show()
    if file_name != '':
        lbx_right.load( file_name )

btn_loadright = Buttongrid( root, 9, 2, u'загрузить', 10, fnc_loadright)

#-- кнопка записи правого списка в файл
def fnc_saveright(event):
    file_name = tkFileDialog.SaveAs(root, filetypes = [('*.txt files', '.txt')]).show()
    if file_name != '':
        lbx_right.save(file_name)

btn_saveright = Buttongrid( root, 9, 3, u'сохранить', 10, fnc_saveright)


#-- запустить окно программы
root.mainloop()

# %% [markdown]
# #### py073 Простейший текстовый редактор

# %%
# coding:utf8
##-- edittext.py for using some graph classes

#-- подключить библиотеки 
from tkinter import *
from tkinter import ttk
from tkinter.font import Font
from tkinter import filedialog as tkFileDialog
import re
import os
from abgttk2 import *

#-- настройки оформления
root= Tk()
clr_root ='#FF33FF'
root['bg']=clr_root
stl=ttk.Style()
dFont=Font(family="helvetica", size=14)
stl.configure('.', font=dFont, background=clr_root,foreground="black")
stl.configure('TLabel', foreground='black', sticky=E, padx=10,font=dFont)
stl.configure('TEntry', padx=5,pady=5,sticky=W, font=dFont)
stl.configure('TButton', padx=5,pady=5,sticky=W, font=dFont)
stl.configure('TComboBox', padx=5,pady=5,sticky=W,width=10, font=dFont)
stl.configure('Tlistbox', padx=5,pady=5,font=dFont)

file_name=""

#-- главное меню
menubar = Menu(root)              
##-- блок меню Файл 
filemenu =  Menu(menubar, tearoff=0)
##-- пункт меню открыть файл
def open_file():
    global file_name
    file_name= tkFileDialog.Open(root,filetypes=[('*.txt files','.txt')]).show()
    if file_name !='':
        text_win.load(file_name)
        filemenu.add_command(label="Open", command=open_file)
        
##-- пункт меню сохранить файл
def save_file():
    global file_name
    if file_name !='':
        text_win.save(file_name)
        filemenu.add_command(label="Save", command= save_file)

##-- пункт меню сохранить файл под другим именем
def save_as():
    global file_name
    file_name= tkFileDialog.SaveAs(root,filetypes=[('*.txt files','.txt')]).show()
    if file_name !='':
        text_win.save(file_name)
    filemenu.add_command(label="Save As", command= save_as)

##-- разделитель
filemenu.add_separator()

##-- пункт меню завершения работы
filemenu.add_command(label="Exit", command= root.destroy)

##-- добавить меню Файл
menubar.add_cascade(label="File", menu=filemenu)
              
##-- блок меню редактирования 
editmenu=Menu(menubar, tearoff=0)

##-- пункт меню вырезать
def cut_part():
    text_win.event_genterate('<<Cut>>')
editmenu.add_command(label="Cut", command=cut_part)

##-- пункт меню скопировать
def copy_part():
    text_win.event_genterate('<<Copy>>')
editmenu.add_command(label="Copy", command=copy_part)

##-- пункт меню вставить
def paste_part():
    text_win.event_genterate('<<Paste>>')
editmenu.add_command(label="Paste", command=paste_part)

##-- добаветь меню редактирования 
editmenu.add_cascade(label="Edit", menu=editmenu)
              
##-- блок меню описания 
helpmenu = Menu(menubar, tearoff=0)
def show_about():
    showinfo(u"редактор", u"простой пример для демонстрации \n возможности библиотеки abgttk.py")
helpmenu.add_command(label="Help", command=helpmenu)

##-- добавить меню описания 
helpmenu.add_cascade(label="Edit", menu=editmenu)

##-- отдельный пункт выхода              
menubar.add_command(label="Exit", command= root.destroy)

##-- вывести меню на форме              
root.config(menu=menubar)

#-- собственно текстовое поле редактора
text_win = Labeltext(root,0,0,"",80,26)
text_win["font"]= dFont

#-- запустить окно программы
root.mainloop()

# %%
# %%writefile abgttk2.py
#codint: utf8
#abgttk.py

#-- подключить библиотеки
from tkinter import *
from tkinter import ttk
#import ttk
#-- упрощенные классы виджетов

#-- кнопка с набором параметров
class Buttongrid(ttk.Button):
    def __init__(self, panel, row_num, col_num, btn_text, btn_width =10, btn_fnc="", row_span=1, col_span=1):
        ttk.Button.__init__(self,panel,text=btn_text, width=btn_width)
        self.grid(row= row_num, column=col_num, sticky=E+N,pady=5,padx=5)
        if btn_fnc != "":
            self.bind("<Button-1>", btn_fnc)

#-- поле ввода с меткой
class Labelentry(ttk.Entry):
    def __init__(self, panel, row_num, col_num, lab_text, 
                 ent_width =10, init_val="",
                 fnc_return ='', col_span=1):
        self.var=StringVar()
        ttk.Entry.__init__(self,panel,width=ent_width, textvariable=self.var)
        self.var.set(init_val)
        if fnc_return != "":
            self.bind('<Return>', fnc_return)
            
        if len(lab_text)>0:
            self.lab=ttk.Label(pane, text=lab_text)
            self.lab.grid(row=row_num,coloun=col_num, sticky=E,padx=5)
            self.grid(row=row_num,colunm=col_num+1,columnspan=col_span,sticky=W,pady=5,padx=5)

    def get(self):
        return self.var.get()

    def set(self,new_text):
        self.var.set(new_text)
        
#-- раскрывающийся список с меткой
class Labelcombobox(ttk.Combobox):
    def __init__(self, panel, row_num, col_num, lab_text, cbx_width =20, cbx_height=6, lst_value=""):
        if len(lab_text) > 0:
            self.lab = ttk.Label(panel, text=lab_text)
            self.lab.grid(row=row_num, column= col_num, sticky= E, padx=5, columnspan=col_span)
       
        ttk.Combobox.__init__(self,panel,values=lst_values, width=cbx_width,height=cbx_height)
        self.grid(row= row_num, column=col_num+1, sticky=W,pady=5,padx=5)
        if fnc_sel != 0:
            self.bind("<<ComboboxSelected>>", fnc_sel)
    
    def get_index(self):
        try:
            return self.current()
        except:
            return -1
        
    def set_index(self, index):
        try:
            self.current(index)
            return index
        except:
            return -1
        
    def load(self, file_name, cod='utf8'):
        if len(file_name) >=1:
            self["values"]=[]
            fhn =open(file_name)
            lines=fhn.readlines()
            for line_num in range(len(lines)):
                lines[line_num]=lines[line_num].decode(cod)
            self["values"]=lines()
            fhn.close()
            self.set(self["values"][0])

#-- список с меткой
class Labellistbox(Listbox):
    def __init__(self, panel, row_num, col_num, lab_text="", lbx_width =20, lbx_height=6, lst_value=""):
        self.panel=ttk.Frame(panel)
        
        Listbox.__init__(self,self.panel, width=lbx_width,height=lbx_height)

        if len(lab_text) > 0:
            self.lab= ttk.Label(panel, text=lab_text)
            self.lab.grid(row=row_num, column= col_num, sticky= W, padx=5, columnspan=col_span)
        self.panel.grid(row=row_num+1, column= col_num, sticky= W, padx=5, columnspan=col_span)
        
        for str_lbx in lst_values:
            Listbox.insert(self, END, str_lbx)

        self.pack(side="left", fill="y")
        self.scbr = Scrollbar(self.panel, orient="vertical")
        self.scbr.pack(side="right", fill="y")
        
        self.scbr.config(command=self.yview)
        self.config(yscrollcommand=self.scbr.set)
        
        if fnc_dbl != 0:
            self.bind('<Double-Buttn-1>', fnc_dbl)

    def append(self, new_text):
        Listbox.insert(self, END, new_text)
    
    def get(self):
        try:
            return Listbox.get(self, self.curselecton()[0])
        except:
            return ""
    def get_index(self):
        try:
            return self.curselection()[0]
        except:
            return -1
    
    def set_index(self,index):
        try:
            #self.selection_clear()
            self.select_clear(0,"end")
            self.selection_set(index)
            self.see(index)
            self.activate(index)
            self.selection_anchor(index)
            return index
        except:
            return -1

    def clear(self):
            Listbox.delete(self, 0, END)
            
    def insert(self, new_text):
        sel_num = self.get_index()
        if sel_num >=0:
            Listbox.insert(self, sel_num, new_text)
        else:
            Listbox.insert(self, END, new_text)
    
    def delete(self):
        sel_num =self.get_index()
        if sel_num >= 0:
            Listbox.delete(self, sel_num)
                  
    def save(self, file_name, cod = 'utf8'):
        if len(file_name)>=1:
            fhn = open(file_name, "w")
            lst =list(Listbox.get(self, 0, END)).encode(cod)
            lst.append("")
            fhn.write("\n".join(lst))
            fhn.close()

    def Load(self, file_name, cod = 'utf8'):
        if len(file_name)>=1:
            fhn = open(file_name)
            lst_values=fhn.readlines()
            fhn.close()
            
            Listbox.delete(self,0,END)
            for str_loc in lst_values:
                Listbox.insert(self, END, str_loc.strip().decode(cod))
    
#-- текст с меткой
class Labeltext(Text):
    def __init__(self, panel, row_num, col_num, lab_text="", txt_width =20, txt_height=6, txt_value="",col_span=1,fnc_dbl=0):
        self.panel=ttk.Frame(panel)
        
        Text.__init__(self,self.panel, width=txt_width,height=txt_height,wrap='word', padx=5)

        if len(lab_text) > 0:
            self.lab= ttk.Label(panel, text=lab_text)
            self.lab.grid(row=row_num, column= col_num, sticky= W, padx=5, columnspan=col_span)
        self.panel.grid(row=row_num+1, column= col_num, sticky= W, padx=5, columnspan=col_span)
        
        Text.insert(self,END,txt_value)
        
        self.pack(side="left", fill="y")
        self.scbr = Scrollbar(self.panel, orient="vertical")
        self.scbr.pack(side="right", fill="y")
        
        self.scbr.config(command=self.yview)
        self.config(yscrollcommand=self.scbr.set, wrap = 'word')
        
        if fnc_dbl != 0:
            self.bind('<Double-Buttn-1>', fnc_dbl)
            
    def append(self, new_text):
        self.insert(IND, new_text)
        
    def clear(self):
        self.delete(1.0, END)
        
    def save(self,file_name, cod='utf8'):
        if len(file_name) >= 1:
            fhn = open(file_name, "w")
            txt =Text.get(self, 1.0, END).encode(cod)
            fhn.write(txt)
            fhn.close()
            
    def load(self,file_name,cod='utf8'):
        if len(file_name) >=1:
            fhn= open(file_name)
            txt=fhn.read().decode(cod)
            self.clear()
            self.append(txt)
            fhn.close()
            
    def get(self):
        return Text.get(self, 1.00, END)
    
    def set(self, new_tet):
        self.delete(1.0, END)
        self.insert(END, new_text)
        
    
    
        
        
#-- список многострочных полей


#class Messagelist():
#-- 
#-- 
#-- 
#--
# Out:
# Writing abgttk2.py

# %% [markdown]
# #### py074 программа на Python для исследования Atmega8
# #### py075 DBSN формирование записи
# #### py076 DBSN - структура записи
# #### py077 DBSN структура записи реального документа
# #### py078 DBSN заполняем запись данными документа
# #### py079 Сравнение питонов 2 и 3

# %% [markdown]
# #### py070 применение простых регулярных выражений
# #### py071 Питон обслуживание клавиатуры
# #### py072 Простое наследование классов ttk
# #### py073 Простейший текстовый редактор
# #### py074 программа на Python для исследования Atmega8
# #### py075 DBSN формирование записи
# #### py076 DBSN - структура записи
# #### py077 DBSN структура записи реального документа
# #### py078 DBSN заполняем запись данными документа
# #### py079 Сравнение питонов 2 и 3

# %% [markdown]
# [py001 Питон - практический старт](https://www.youtube.com/watch?v=K3hE5C2kglI&list=PLku9se_HAVOp8pSgrIWGIjHLP-EOw_ywq&index=82)
# [abglazov](http://abglazov.rfpgu.ru/)
#
# []()

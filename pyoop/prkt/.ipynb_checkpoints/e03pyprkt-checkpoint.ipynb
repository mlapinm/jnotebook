# %% [markdown]
# #### playlist youtube

# %% [markdown]
# [json](#json)

# %%
# coding: utf8
# == pars_playlist.py ==
# == select short information from Youtube playlist --
from urllib.request import urlopen
from bs4 import BeautifulSoup
import codecs
import json

print  ("pars_playlist working...")

# == get first link of playlist  ==
# url = input('input link:')
# url = "https://www.youtube.com/watch?v=ECW6DY6fH2U&list=PLku9se_HAVOryGec5hev5TeD-eTSxv7z9"
url = "https://www.youtube.com/watch?v=_8Yf0Tz-G-E&list=PLku9se_HAVOp8pSgrIWGIjHLP-EOw_ywq&index=1"
# fh = open('data.txt','w')  
url = "https://www.youtube.com/watch?v=FydiBSLOkL4&list=PLku9se_HAVOrs3p_jJzZAbV3BEODrhS3j"
url = "https://www.youtube.com/watch?v=ZbV_C4ejUQ0&list=PLZKvhpfgHOplaV28tl-MLr3xfepw3gCgA&index"
url = "https://www.youtube.com/watch?v=6uOz-v-ddm4&list=PLZKvhpfgHOplaV28tl-MLr3xfepw3gCgA&index"
url = "https://www.youtube.com/watch?v=N_1OHm3uooY&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF"
# url = "https://www.youtube.com/watch?v=G63Rle2EYOs&list=PLZKvhpfgHOpld6oLbwGIfUC4ultGjA1bz"
cur_num = 1     # index of reading page  
lo=[]
st_out=''
try:
    while True:
        los=[]
        # -- get current page --
        print (cur_num)    
        print (url)
        los.append(str(cur_num))
        los.append(str(url))
        content = urlopen( url )
        page2 = content.read()
        page = page2.decode('utf-8')

        # -- cut head
        soup = BeautifulSoup(page)
        body = soup.find('body')

        # get current title
        span = body.find(id="eow-title")
        title = span.getText()
        print (title)
        s_num = '0'+str(cur_num) if len(str(cur_num))<2 else str(cur_num)
        st_out += 'ar' + s_num + title.strip()+'\n'
        los.append(str(title))

        
        # get list of all links
        # ol = body.find(id="playlist-autoscroll-list")
        ol = body.find(id="playlist-autoscroll-list")
        lis = ol.findAll('li')

        # seek for current page
        for idx, li in enumerate(lis): # seek for picture
            li_title = li["data-video-title"]
            
            if str(li_title.strip()) == str(title.strip()):
                break
        video_id = li["data-video-id"]

        # get decription of page
        descr = body.find(id="eow-description")
        descr_text = descr.getText()
        print(descr_text)
        los.append(str(descr_text))
        lo.append(los)
        
        if idx >= len(lis) -1:  
            break

        # get next url
        idx += 1
        li = lis[ idx ]
        anc = li.find( 'a' )
        href = anc['href']
        url="https://www.youtube.com" + href

        cur_num = cur_num + 1
# == 05 end of work ==
except:
    print ("exception: ", cur_num)
    pass
finally:
#     fh.close()
    print ("ok")
#     print(lo)
    with open('e03.txt','w') as fh:
        fh.write(st_out)
        
    st = json.dumps(lo)  
    with open('e03l.txt','w') as fh:
        fh.write(st)
# Out:
# pars_playlist working...
# 1
# https://www.youtube.com/watch?v=N_1OHm3uooY&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF
#
#     Arduino Optiboot
#
# Optiboot bootloader для Arduino. Компилляция и прошивка.Ссылки в видео:https://github.com/Optiboot/optiboothttp://www.arduino.cchttp://www.engbedded.com/fusecalc
# 2
# https://www.youtube.com/watch?v=9kys_sUru2U&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=2
#
#     Arduino Moscow Metro Ticket Reader
#
# Два скетча, использующих RFID-ридер для проверки билетов транспортной системы Москвы.Второй скетч дополнительно выводит время с RTC DS1307 и температуру и влажность с барометра BMP180.Скетчи:https://drive.google.com/open?id=0B7Y...https://drive.google.com/open?id=0B7Y...Библиотеки:https://drive.google.com/open?id=0B7Y...https://drive.google.com/open?id=0B7Y...https://drive.google.com/open?id=0B7Y...
# 3
# https://www.youtube.com/watch?v=gHnmVGw96wQ&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=3
#
#     BT05A BLE as iBeacon
#
# Настройка модуля BLE BT-05A в качестве iBeacon.Инструкция для оригинального модуля HM-10 https://drive.google.com/open?id=0B7Y...Удалось прошить этот модуль полной прошивкой от HM-10 прямым подключением к модулю Ардуиной со скетчем CCLoader, но светодиод не светит, модуль отвечает на все AT-команды, но в эфире отсутствует при любых настройках.После чего удалось перешить его прошивкой от HM-11 штатной процедурой через UART. И вуаля! Модуль в эфире появился, светодиодом радостно мигает.
# 4
# https://www.youtube.com/watch?v=nj11QH9kj9E&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=4
#
#     BMP280 и BME280 баро/термо сенсоры для Arduino и ESP8266
#
# Подключение датчиков давления и температуры BMP280 и BME280 к Arduino и ESP8266 с использованием исправленных для китайских модулей библиотек от Adafruit (C).Сами подправленные библиотеки https://drive.google.com/open?id=0B7Y... и https://drive.google.com/open?id=0B7Y...
# 5
# https://www.youtube.com/watch?v=wVwR2gdduUQ&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=5
#
#     TTP223 Touch Sensor
#
# Емкостные сенсорные кнопки на TTP223 для Arduino и ESP8266."Лечение" нерабочего китайского модуля.Код скетча из видео https://drive.google.com/open?id=0B7Y...
# 6
# https://www.youtube.com/watch?v=_QHWR8PtD2E&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=6
#
#     RCWL 0516
#
# Микроволновый датчик движения RCWL-0516.Подключение к Arduino и ESP8266.Скетч: https://drive.google.com/open?id=0B7Y...PS: и да, это транзистор возле антенны, а не стаб. :[
# 7
# https://www.youtube.com/watch?v=-IfBaxwwJd8&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=7
#
#     Мультиплексор/демультиплексор на 74HC4067
#
# 16-ти канальный аналоговый мультиплексор/демультиплексор на микросхеме 74HC4067.Примеры использования для динамической индикации и одновременного ввода/вывода.Даташит:http://www.nxp.com/documents/data_she...Скетчи примеров:https://drive.google.com/open?id=0B7Y...https://drive.google.com/open?id=0B7Y...https://drive.google.com/open?id=0B7Y...
# 8
# https://www.youtube.com/watch?v=mLAuZspdqdg&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=8
#
#     Arduino OLED Oscilloscope
#
# Простой осциллограф на Arduino UNO, Nano или Pro Mini с OLED экраном.Код скетча из видео: https://drive.google.com/open?id=0B7Y...Новый усовершенствованный вариант осциллографа в видео https://www.youtube.com/watch?v=-HF5k...
# 9
# https://www.youtube.com/watch?v=tAyc4nNvVY8&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=9
#
#     Enum size
#
# Размер перечислимого типа C/C++ enum в байтах и способ его уменьшения.Скетч с заготовкой класса для регулярной проверки на совпадение даты и времени: https://drive.google.com/open?id=0B7Y...
# 10
# https://www.youtube.com/watch?v=zby4-YHot6w&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=10
#
#     TM1637
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Модуль отображения информации на 4 семисегментных индикатора и символ двоеточия на микросхеме TM1637.Даташит на TM1637: https://drive.google.com/open?id=0B7Y...Пример использования модуля: https://drive.google.com/open?id=0B7Y...Скетч NetTime для ESP8266: https://drive.google.com/open?id=0B7Y...Скетч для ESP8266 и DHT11: https://drive.google.com/open?id=0B7Y...
# 11
# https://www.youtube.com/watch?v=Q0qgrG26wJc&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=11
#
#     Arduino as I2C GPIO expander
#
# Использование Arduino UNO, Nano или Pro Mini в качестве I2C расширителя GPIO (не забудьте подтянуть к VCC через резисторы 4.7 кОм SDA и SCL на слейве и про конвертер уровней при использовании с ESP8266!).Поддерживаются функциональные аналоги стандартным методам работы с портами (pinMode, digitalWrite, digitalRead, analogWrite, analogRead). Через 5 сек. бездействия плата уйдет в сон, но проснется сразу же при очередном обращении.Скетч клиента I2C (для заливки в AVR): https://drive.google.com/open?id=0B7Y...Скетч с примером использования (пригоден для AVR и ESP8266): https://drive.google.com/open?id=0B7Y...Чуть усложнив протокол обмена с мастером, можно создать I2C "обертку" для специфических датчиков, требующих сложного подключения.PS: код клиента, пригодный для Mega (исправьте в .h файле константу последнего пина на используемую вашей платой) или дальнейшего расширения протокола: https://drive.google.com/open?id=0B7Y...
# 12
# https://www.youtube.com/watch?v=G63Rle2EYOs&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=12
#
#     STM8s Arduino-like library for IAR
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Порт Arduino для STM8s103f3 (пока без Wire и SPI).Компиллятор С++ IAR STM8 (8 kB code free): https://www.iar.com/iar-embedded-work...Драйверы для ST-Link/V2: http://www.st.com/content/st_com/en/p...Документация по STM8s103f3: http://www.st.com/content/st_com/en/p...Архив с шаблоном проекта для IAR: https://drive.google.com/open?id=0B7Y... (развернуть в "C:\Program Files (x86)\IAR Systems\Embedded Workbench 7.3\stm8\config\template\project\").Проект примера из видео: https://drive.google.com/open?id=0B7Y...Пример использования прерываний: https://drive.google.com/open?id=12xN...
# 13
# https://www.youtube.com/watch?v=jjX9M1FcnP4&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=13
#
#     Arduino Web Server
#
# Web Server Class для Ethernet Shield Arduino. Поддерживаются GET запросы с параметрами и заголовками.Пример использует AJAX для демонстрации всех входов Arduino UNO и страницу настройки параметров Ethernet, сохраняемых в EEPROM.Заранее приношу извинения за длинное и нудное видео. :)Код скетча: https://drive.google.com/open?id=0B7Y...
# 14
# https://www.youtube.com/watch?v=lpbF1d7VbOk&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=14
#
#     Arduino UNO Hybrid Web Server
#
# Веб-сервер для Arduino UNO с исходными файлами на SD карте: https://drive.google.com/open?id=0B7Y...Гибридный веб-сервер: https://drive.google.com/open?id=0B7Y...
# 15
# https://www.youtube.com/watch?v=zodwtMQEAkE&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=15
#
#     Arduino Hybrid Web Server 2
#
# Функционал скетча и html-файла из предыдущего видео о гибридном веб-сервере расширен управлением цифровыми выводами UNO.Код скетча: https://drive.google.com/open?id=0B7Y...
# 16
# https://www.youtube.com/watch?v=xN0Ch4u2vSE&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=16
#
#     Обновление Arduino IDE
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Если среда Arduino IDE сообщила вам о наличии обновлений в установленной поддержке плат - без паники, сделайте глубокий вдох, потом выдох, медленно досчитайте до десяти и посмотрите этот ролик, чтобы знать, что делать дальше... :)Архив с файлами для поддержки Optiboot: https://drive.google.com/open?id=0B7Y...Ролик о бутлоадере Optiboot: https://www.youtube.com/watch?v=N_1OH...
# 17
# https://www.youtube.com/watch?v=1Q0eV91_pFM&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=17
#
#     Oscilloscope для Atmega168
#
# Переписанный скетч простейшего осциллографа для I2C OLED экрана с использованием библиотеки U8g2.Ссылка на библиотеку: https://github.com/olikraus/u8g2Скетч из видео: https://drive.google.com/open?id=0B7Y...Актуальный вариант осциллографа в видео https://www.youtube.com/watch?v=-HF5k...
# 18
# https://www.youtube.com/watch?v=AEDNA_G81gA&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=18
#     Arduino MEGA Smart Relay
#
# Адаптация "умного реле" с ESP8266 на Arduino Mega + Ethernet Shield.Поддерживается до 48 каналов реле, включение реле через веб-интерфейс, физическими кнопками, командами по протоколу MQTT или расписанием по времени.Фреймворк реализует хранение параметров в EEPROM, веб-сервер с поддержкой GET-запросов, обновление времени с NTP сервера, работу с MQTT брокером, текстовый лог вывода в Serial.Код скетча: https://drive.google.com/open?id=0B7Y...Код скетча с поддержкой авторизации: https://drive.google.com/open?id=0B7Y...Актуальная версия скетча в ролике https://www.youtube.com/watch?v=-SM7H...
# 19
# https://www.youtube.com/watch?v=Jv--OiGP3Bc&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=19
#
#     Arduino MEGA RFID Relay
#
# "Умное реле" для Arduino MEGA и Ethernet Shield с возможностью использования RFID-ключей для управления каналами реле.Не забудьте, что RFID-ридер питается от 3.3V!!!Подключение RFID-ридера: SDA(SS) - 53, SCK - 52, MOSI - 51, MISO - 50, RST - 49 (вы можете определить дргие значения для SS и RST в коде скетча).Имя и пароль по умолчанию: MEGA и 12345678 (можете поменять в настройках сети в веб-интерфейсе).И не забывайте сохранять параметры в EEPROM после их изменения через всплывающие формы и перезагружаться, если изменения касаются реле или кнопок!Код скетча: https://drive.google.com/open?id=0B7Y...Код обновленного скетча из прошлого видео: https://drive.google.com/open?id=0B7Y...Актуальная версия скетча в ролике https://www.youtube.com/watch?v=-SM7H...
# 20
# https://www.youtube.com/watch?v=pXNF6DBsjCo&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=20
#
#     MEGA Relay3
#
# Реле для Arduino MEGA и Ethernet Shield из предыдущих роликов обзавелось поддержкой часов реального времени DS3231 и датчиков температуры DS18x20.Код скетча: https://drive.google.com/open?id=0B7Y...Актуальная версия скетча в ролике https://www.youtube.com/watch?v=-SM7H...
# 21
# https://www.youtube.com/watch?v=bZLEfLZYd-0&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=21
#
#     ESP and Buttons
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Примеры различных методов опроса кнопок.Синхронный вызов callback-функции: https://drive.google.com/open?id=0B7Y...Асинхронная обработка очереди событий от регулярного опроса кнопок по таймеру: https://drive.google.com/open?id=0B7Y...
# 22
# https://www.youtube.com/watch?v=XLL4LbLX4VQ&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=22
#
#     AVR счетчик очков
#
# Скетч для счета очков в настольных играх на 2-х игроков для Arduino UNO.Код скетча с постоянным опросом кнопок: https://drive.google.com/open?id=0B7Y...Код скетча с использованием прерываний: https://drive.google.com/open?id=0B7Y...
# 23
# https://www.youtube.com/watch?v=4hfuL8eR-Js&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=23
#
#     AVR Buttons Ticker
#
# Библиотека для обработки регулярных событий на таймере Timer2 и ее использование для организации опроса кнопочных массивов и асинхронной обработки результатов.Код скетча с примером управления тикером встроенным светодиодом: https://drive.google.com/open?id=0B7Y...Код скетча с опросом тикером кнопочного массива: https://drive.google.com/open?id=0B7Y...Даташит на ATmega 168 и 328: http://www.atmel.com/images/Atmel-827...PS: это перезалитое видео, надеюсь на этот раз Ютуб не ограничит исходное качество.
# 24
# https://www.youtube.com/watch?v=tgV1Nnjo6u8&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=24
#
#     Serial GPIO Expander
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Расширитель портов на AVR, использующий шину UART.Код базового расширителя: https://drive.google.com/open?id=0B7Y...Код примера использования базового расширителя: https://drive.google.com/open?id=0B7Y...Код дополненного поддержкой DHT11 и DS3231 расширителя: https://drive.google.com/open?id=0B7Y...Код примера использования дополненного расширителя с дисплейным модулем TM1637: https://drive.google.com/open?id=0B7Y...
# 25
# https://www.youtube.com/watch?v=x0fcQ5g5ctM&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=25
#
#     Расширитель портов для ESP8266 на STM8
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Базовый UART расширитель портов на плате STM8s103.Код для IAR: https://drive.google.com/open?id=0B7Y...Откомпиллированные файлы для заливки через STVP: https://drive.google.com/open?id=0B7Y...Код примера для ESP8266 или Arduino: https://drive.google.com/open?id=0B7Y...
# 26
# https://www.youtube.com/watch?v=MMUmjXf1dGE&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=26
#
#     TSL2561
#
# Датчик освещенности TSL2561. Поддерживает как замер полного спектра, так и ИК-диапазона. Связь с МК по I2C.Даташит на датчик: https://cdn-shop.adafruit.com/datashe...Код скетча с примером работы с прерываниями: https://drive.google.com/open?id=0B7Y...PS: приношу извинения Adafruit за издевательства над их библиотекой. :)
# 27
# https://www.youtube.com/watch?v=ymZnRGfXuzs&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=27
#
#     ADCX
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Считывание среднего значения с АЦП за N выборок в секунду с помощью скользящего среднего и таймера для Atmega168/328.Код скетча: https://drive.google.com/open?id=0B7Y...Даташит на Atmega168/328: http://www.atmel.com/images/Atmel-827...
# 28
# https://www.youtube.com/watch?v=-HF5kxF9rTk&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=28
#
#     Oled Oscilloscope Plus
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Простой осциллограф на Atmega168/328, I2C OLED экране и поворотном энкодере. Позволяет отображать уровень входного сигнала по времени от 0,9 мс. до 13,3 мс. Есть программный детектер частоты цифрового сигнала.Используется графическая библиотека u8g2 (https://github.com/olikraus/u8g2).Код скетча: https://drive.google.com/open?id=0B7Y...Скетч, использующий таймер для задания частоты опросов. Поддерживает длительность "окна" 1, 2, 5, 10, 25, 50, 100, 250, 500 мс. и 1 сек. https://drive.google.com/open?id=0B7Y...
# 29
# https://www.youtube.com/watch?v=25q0sppURuo&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=29
#
#     AVR Freq
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Определение частоты входного сигнала на Atmega168/328 с помощью таймера.Код скетча: https://drive.google.com/open?id=0B7Y...Видео про простейший осциллограф на AVR: https://www.youtube.com/watch?v=-HF5k...
# 30
# https://www.youtube.com/watch?v=ceSH7A4m05Y&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=30
#
#     Arduino Mega RFID Relay+
#
# Многоканальное "умное реле" на Arduino Mega и Ethernet Shield W5100 с поддержкой SPI RFID MFRC-522, I2C RTC DS3231, DS18x20 и управлением по Web и MQTT.Используются библиотеки из стандартного репозитория Arduino: PubSubClient, OneWire и MFRC522.Код скетча:https://github.com/MoonFox2006/MegaRF...Актуальная версия скетча в ролике https://www.youtube.com/watch?v=-SM7H...
# 31
# https://www.youtube.com/watch?v=Kf2POwbtTmQ&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=31
#
#     Arduino Mega RFID Relay++
#
# Многоканальное "умное реле" на Arduino Mega и Ethernet Shield из предыдущего ролика (https://www.youtube.com/watch?v=ceSH7...) получило поддержку раздельной пользовательской и административной авторизации и названий для датчиков DS1820.Код скетча: https://drive.google.com/open?id=0B7Y...Актуальная версия скетча в ролике https://www.youtube.com/watch?v=-SM7H...
# 32
# https://www.youtube.com/watch?v=6uOz-v-ddm4&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=32
#
#     Цикл уроков по программированию на C++ для Arduino. Часть 1.
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Вероятно безнадежная попытка в нескольких уроках научить писать скетчи для Arduino.Первая часть охватывает скалярные типы данных и основные конструкции языка.Во второй части будут рассмотрены массивы, строки и производные типы (https://www.youtube.com/watch?v=5q5Ca...).Третья часть будет посвящена ООП (https://www.youtube.com/watch?v=ZbV_C...).PS: кто найдет логическую ошибку в примере, рассказывающем о while, может собой гордиться. :)
# 33
# https://www.youtube.com/watch?v=5q5Cago_UfM&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=33
#     Цикл уроков по программированию на C++ для Arduino. Часть 2.
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Вторая часть цикла посвящена указателям, ссылкам, массивам, работе со строками, структурам, объединениям и хранению строк во флеш-памяти.Третья часть об ООП: https://www.youtube.com/watch?v=ZbV_C...Полезные ссылки из видео:https://www.arduino.cc/en/Reference/H...http://www.nongnu.org/avr-libc/user-m...http://www.nongnu.org/avr-libc/user-m...PS: автор на глупые вопросы не отвечает!!! Рога на реализацию не принимает! По албански не разумеет!
# 34
# https://www.youtube.com/watch?v=ZbV_C4ejUQ0&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=34
#
#     Цикл уроков по программированию на C++ для Arduino. Часть 3.
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Заключительная часть цикла посвящена ООП.Она (что естественно) самая сложная и длинная, рекомендую смотреть в несколько подходов (или не смотреть вообще :) ).
# 35
# https://www.youtube.com/watch?v=fm4nRmLRhXE&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=35
#
#     AVR heap mystic
#
# Пример использования динамической памяти для хранения свойств классов.И немного мистики в определении свободной динамической памяти на AVR.Код из видео: https://drive.google.com/open?id=1qSg...PS: Если некоторое время назад с AVR можно было использовать new и delete только с классами, то сейчас их можно применять для выделения и освобождения памяти с любыми указателями.
# 36
# https://www.youtube.com/watch?v=b1CzBbgMV40&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=36
#
#     Arduino ООП и зачем все это нужно
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Практический пример использования ООП (объектно-ориентированного программирования) для реализации универсального хранения параметров.Код из видео: https://drive.google.com/open?id=15IL...
# 37
# https://www.youtube.com/watch?v=p_QApn0SVWs&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=37
#
#     Сравнение с функцией millis()
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Об особенностях использования функции millis() для отсчета временных промежутков.
# 38
# https://www.youtube.com/watch?v=-SM7HBJ49pk&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=38
#
#     ping для Arduino UNO/Mega и Ethernet Shield W5100
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Реализация ping для Arduino UNO/Mega и Ethernet Shield W5100.Код примера: https://drive.google.com/open?id=1a9S...W5100 datasheet: https://drive.google.com/open?id=1yrx...W5100 errata: https://drive.google.com/open?id=1lx2...Скетч умного реле на Arduino Mega с поддержкой RFID, DS1820 и т.д. и т.п. с аппаратным ватчдогом и ватчдогом сетевого интерфейса с помощью пингов: https://drive.google.com/open?id=1QN_...
# 39
# https://www.youtube.com/watch?v=S3ezeS4gLQw&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=39
#
#     Arduino для ESP8266 на основе SDK 2.1
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Установка пакета поддержки ESP8266 для Arduino IDE с помощью Git.В этом случае будет использоваться последняя версия пакета, основанная (на момент создания ролика) на версии ESP SDK 2.1.Ссылка на гитхаб: https://github.com/esp8266/ArduinoО прошивке ESP8266: https://nodemcu.readthedocs.io/en/mas...NodeMCU flasher: https://github.com/nodemcu/nodemcu-fl...Git для Windows: http://gitforwindows.org
# 40
# https://www.youtube.com/watch?v=dU8ntuPHVT0&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=40
#
#     PoE injector
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Использование PoE (Power-over-Ethernet) инжектора для подачи питания по сетевому кабелю.
# 41
# https://www.youtube.com/watch?v=fLqwtpUNEuY&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=41
#
#     Определение версии SDK для обновления бутлоадера ESP8266
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Для выбора совместимого бутлоадера ESP8266 необходимо знать, на SDK какой версии основан пакет поддержки ESP для Arduino IDE или PlatformIO.Сама процедура обновления описана в ролике https://www.youtube.com/watch?v=LbZ1y...
# 42
# https://www.youtube.com/watch?v=OGCyKncOyNU&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=42
#
#     PlatformIO или прощай, Arduino IDE
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Универсальная среда разработки IoT приложений PlatformIO.Сайт проекта: https://platformio.org/Документация по использованию в редакторе VSCode: http://docs.platformio.org/en/latest/...Для работы системы требуется установка Python версии 2.7.x (не третьей версии!) Ссылка на скачивание змеюги (последняя на данный момент версия ветки 2.7): https://www.python.org/downloads/rele...Проект хорошо документирован, поэтому прежде чем задавать вопросы, поищите, пожалуйста, ответы самостоятельно.
# 43
# https://www.youtube.com/watch?v=4NQDQTblgWU&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=43
#
#     Размер структур и классов в программах на ESP8266
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Из-за выравнивания полей структур и классов, занимаемый вашими типами данных  размер оперативной памяти может значительно превосходить ваши ожидания.Если скорость доступа к структурам (полям классов) не является критичной, то можно заставить компиллятор упаковать тип, добавив в описание типа конструкцию__attribute__((__packed__))Пример из видео (код для PlatformIO, в случае с Arduino IDE переименовать файл src\main.cpp в StructSize_Test.ino и перенести его из подкаталога src в каталог проекта): https://drive.google.com/open?id=1UC5...
# 44
# https://www.youtube.com/watch?v=1eM6MVagCk8&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=44
#
#     Опрос кнопок через MCP23017 для ESP8266
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Класс Buttons позволяет асинхронно опрашивать кнопки, подключенные к MCP23017, формируя очередь событий. В главном цикле периодически необходимо обрабатывать очередь, чтобы она не переполнилась и не были утеряны последние события.Код скетча из видео: https://drive.google.com/open?id=1df2...
# 45
# https://www.youtube.com/watch?v=s2NXILzXCLw&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=45
#
#     DFRobot RGB LCD screen
#
# Дисплейный I2C LCD модуль фирмы DFRobot с выбором цвета шрифта.Ссылка на модуль на сайте производителя: https://www.dfrobot.com/product-1737....Ссылка на подробную информацию о модуле: https://www.dfrobot.com/wiki/index.ph...Пример кода из видео: https://drive.google.com/open?id=1Pcx...
# 46
# https://www.youtube.com/watch?v=OM0f9QZx224&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=46
#
#     ESP8266 обработка кнопок с помощью прерываний
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Скетч для PlatformIO с демонстрацией обработки кнопок с использованием прерываний. Поддерживаются короткие и длинные одновременные нажатия.Ссылка на код: https://drive.google.com/open?id=1-kQ...Вариант скетча, определяющий двойные нажатия: https://drive.google.com/open?id=1bxh...
# 47
# https://www.youtube.com/watch?v=LMlljKmjd2s&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=47
#
#     AVR 168/328 и прерывания от любого пина
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Пример использования прерываний от любых пинов Arduino UNO.Ссылка на код: https://drive.google.com/open?id=1BtW...Пример обработки кнопок через прерывания по изменению пинов: https://drive.google.com/open?id=1blI...
# 48
# https://www.youtube.com/watch?v=rreMOwEJcII&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=48
#
#     Отладка ESP32 в PlatformIO
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Отладка скетчей для ESP32 в PlatformIO, используя программатор ESP-Prog (или подобный на FT2232HL).Документация на программатор ESP-Prog: https://github.com/espressif/esp-iot-...Документация на PlatformIO Unified Debugger: https://docs.platformio.org/en/latest...Настройка драйверов FT2232HL для использования в качестве отладчика: https://community.platformio.org/t/es...Исправление скрипта builder/main.py для загрузки скетчей через программатор и OpenOCD: https://github.com/platformio/platfor...Пример отлаживаемого скетча из видео: https://drive.google.com/open?id=1Po0...
# 49
# https://www.youtube.com/watch?v=JCcZ3ExkjUE&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=49
#     Обзор DFRobot FireBeetle Covers-24x8 LED Matrix
#
# Обзор шилда FireBeetle Covers-24x8 LED Matrix от магазина DFRobot.Ссылка на продукт: https://www.dfrobot.com/product-1595....Wiki: https://www.dfrobot.com/wiki/index.ph...Даташит на контроллер HT1632C: https://cdn-shop.adafruit.com/datashe...Проект примера из видео для PlatformIO: https://drive.google.com/open?id=1Pm-...
# 50
# https://www.youtube.com/watch?v=pTfBkdvWpU0&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=50
#
#     Сон вместо задержек для AVR168/328
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...В случае периодического последовательного чтения или обработки данных имеет смысл заменить длительную задержку до следующего цикла на сон для экономии энергии.Пример проекта для Arduino UNO в среде PlatformIO с чтением I2C датчика температуры и влажности AM2320 раз в 10 секунд: https://drive.google.com/open?id=1dTl...
# 51
# https://www.youtube.com/watch?v=0LHRP6VzZX8&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=51
#
#     DFRobot FireBeetle Covers-24x8 пишет на русском языке
#
# LED экран 24x8 из обзора https://www.youtube.com/watch?v=JCcZ3... теперь может писать тексты на русском языке.Проект для PlatformIO: https://drive.google.com/open?id=1brp...Редактор символов: https://drive.google.com/open?id=1grR...
# 52
# https://www.youtube.com/watch?v=XclUKuvYbkY&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=52
#
#     За облаками небо
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Сохранение данных в облачной таблице Google Sheet, добавление данных в csv-файл на Google Drive и отправка почтового сообщения из скрипта Google Script для ESP8266.На саму таблицу или изменяемый файл на GDrive вы можете дать доступ только для чтения по ссылке.Скетч: https://drive.google.com/open?id=1BTS...Скрипт: https://drive.google.com/open?id=1aI5...Публичная ссылка на таблицу (только чтение): https://drive.google.com/open?id=1QVn...Документация на Google Apps Script: https://developers.google.com/apps-sc...Ссылка на библиотеку HTTPSRedirect от electronicsguy: https://github.com/electronicsguy/ESP...Чтобы откомпиллировать скетч для версии ESP8266 ниже 2.5.0, просто закомментирйте строку, на которую ругается компиллятор (setInsecure()).
# 53
# https://www.youtube.com/watch?v=WlznZdXKhO0&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=53
#
#     Ping для библиотеки Ethernet 2.0
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Адаптация под библиотеку Ethernet 2.0 кода для пинга:https://drive.google.com/open?id=1lXp...
# 54
# https://www.youtube.com/watch?v=I8-QpCdoZFo&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=54
#
#     Arduino оптимизация использования оперативной памяти
#
# Для желающих поддержать автора: Яндекс.Кошелек https://money.yandex.ru/to/4100147278...Примеры простейшей оптимизации использования оперативной памяти для Arduino (AVR, ESP8266, ESP32).В видео на 11-ой минуте в показанном коде ошибка: для определения длины строки, находящейся во флеше, надо использовать функцию strlen_P() вместо strlen().Спасибо внимательному зрителю.
# 55
# https://www.youtube.com/watch?v=3JeSwcDroWk&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=55
#
#     Параметры в скетче для ESP8266
#
# Пример организации хранения и редактирования параметров в скетче для ESP8266 с минимальным использованием оперативной памяти.Код проекта из видео: https://github.com/MoonFox2006/Params...PS: если при изменении набора параметров модуль перезагружается с exception 9, уберите __packed в заголовке структуры в классе Config (наименование из примера) и группируйте параметры от больших к меньшим по объему занимаемой ими памяти, чтобы уменьшить "воздух" от выравнивания на границу 4-х байт.
# 56
# https://www.youtube.com/watch?v=Kh0ffybRrMU&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=56
#
#     Mini RFID-RC522
#
# Плата Mini RFID-RC522 может читать карты "Тройка" и обладает уменьшенными размерами при копеечной цене.Ищите на просторах Али.
# 57
# https://www.youtube.com/watch?v=sHpsxMv6XQE&list=PLZKvhpfgHOpnf0AW3YNEaKWIvzFVzR0dF&index=57
#
#     RC522 I2C модуль
#
# Модуль на RC522 с интерфейсом I2C.Для работы можно использовать библиотеку https://github.com/arozcan/MFRC522-I2...Без доработок читает карту "тройка".PS: для желающих блеснуть ерундицией и сказать, что можно и SPI модуль превратить в I2C путем сверления платы в определенном месте, чтобы перебить дорожку под чипом... Ну вы поняли, надеюсь, юные фрезеровщики. :)
# ok

# %%
import json

def make_str(l):
    st=''
    for i in l:
        st+=i+'\r\n'
    return st

def make_links(l):
    st=''
    
    for i in l:
        st0 = i.replace(' ','-')
        st += f'ar{i}\r\n'
    return st

def make_heads(l,pref='ar'):
    st=''
    num=1
    for i in l:
        strnum = str(num)
        strnum = '0'+strnum if len(strnum)<2 else strnum
        st0 = f'{pref}{strnum}{i}'
        st+=f'#### {st0}  \n'
        num+=1
    return st


        
st = ''
with open('e03l.txt','r') as fh:
    st1 = fh.read()
    ll = json.loads(st1)
l = []
for i in ll:
    l.append(i[2].strip())

def make_links(l,pref='ar'):
    st=''
    num=1
    for i in l:
        strnum = str(num)
        strnum = '0'+strnum if len(strnum)<2 else strnum
        st0 = f'{pref}{strnum}{i}'
        st1 = st0.replace(' ','-')
        st += f'[{st0}](#{st1})  \n'
        num+=1
    return st
    
    
# print(make_heads(l))    
print(make_links(l))    
# print(make_str(l))
with open('e03h.txt', 'w') as fh :
    fh.write(make_heads(l))
with open('e03li.txt', 'w') as fh :
    fh.write(make_links(l))
# Out:
# [ar01Arduino Optiboot](#ar01Arduino-Optiboot)
# [ar02Arduino Moscow Metro Ticket Reader](#ar02Arduino-Moscow-Metro-Ticket-Reader)
# [ar03BT05A BLE as iBeacon](#ar03BT05A-BLE-as-iBeacon)
# [ar04BMP280 и BME280 баро/термо сенсоры для Arduino и ESP8266](#ar04BMP280-и-BME280-баро/термо-сенсоры-для-Arduino-и-ESP8266)
# [ar05TTP223 Touch Sensor](#ar05TTP223-Touch-Sensor)
# [ar06RCWL 0516](#ar06RCWL-0516)
# [ar07Мультиплексор/демультиплексор на 74HC4067](#ar07Мультиплексор/демультиплексор-на-74HC4067)
# [ar08Arduino OLED Oscilloscope](#ar08Arduino-OLED-Oscilloscope)
# [ar09Enum size](#ar09Enum-size)
# [ar10TM1637](#ar10TM1637)
# [ar11Arduino as I2C GPIO expander](#ar11Arduino-as-I2C-GPIO-expander)
# [ar12STM8s Arduino-like library for IAR](#ar12STM8s-Arduino-like-library-for-IAR)
# [ar13Arduino Web Server](#ar13Arduino-Web-Server)
# [ar14Arduino UNO Hybrid Web Server](#ar14Arduino-UNO-Hybrid-Web-Server)
# [ar15Arduino Hybrid Web Server 2](#ar15Arduino-Hybrid-Web-Server-2)
# [ar16Обновление Arduino IDE](#ar16Обновление-Arduino-IDE)
# [ar17Oscilloscope для Atmega168](#ar17Oscilloscope-для-Atmega168)
# [ar18Arduino MEGA Smart Relay](#ar18Arduino-MEGA-Smart-Relay)
# [ar19Arduino MEGA RFID Relay](#ar19Arduino-MEGA-RFID-Relay)
# [ar20MEGA Relay3](#ar20MEGA-Relay3)
# [ar21ESP and Buttons](#ar21ESP-and-Buttons)
# [ar22AVR счетчик очков](#ar22AVR-счетчик-очков)
# [ar23AVR Buttons Ticker](#ar23AVR-Buttons-Ticker)
# [ar24Serial GPIO Expander](#ar24Serial-GPIO-Expander)
# [ar25Расширитель портов для ESP8266 на STM8](#ar25Расширитель-портов-для-ESP8266-на-STM8)
# [ar26TSL2561](#ar26TSL2561)
# [ar27ADCX](#ar27ADCX)
# [ar28Oled Oscilloscope Plus](#ar28Oled-Oscilloscope-Plus)
# [ar29AVR Freq](#ar29AVR-Freq)
# [ar30Arduino Mega RFID Relay+](#ar30Arduino-Mega-RFID-Relay+)
# [ar31Arduino Mega RFID Relay++](#ar31Arduino-Mega-RFID-Relay++)
# [ar32Цикл уроков по программированию на C++ для Arduino. Часть 1.](#ar32Цикл-уроков-по-программированию-на-C++-для-Arduino.-Часть-1.)
# [ar33Цикл уроков по программированию на C++ для Arduino. Часть 2.](#ar33Цикл-уроков-по-программированию-на-C++-для-Arduino.-Часть-2.)
# [ar34Цикл уроков по программированию на C++ для Arduino. Часть 3.](#ar34Цикл-уроков-по-программированию-на-C++-для-Arduino.-Часть-3.)
# [ar35AVR heap mystic](#ar35AVR-heap-mystic)
# [ar36Arduino ООП и зачем все это нужно](#ar36Arduino-ООП-и-зачем-все-это-нужно)
# [ar37Сравнение с функцией millis()](#ar37Сравнение-с-функцией-millis())
# [ar38ping для Arduino UNO/Mega и Ethernet Shield W5100](#ar38ping-для-Arduino-UNO/Mega-и-Ethernet-Shield-W5100)
# [ar39Arduino для ESP8266 на основе SDK 2.1](#ar39Arduino-для-ESP8266-на-основе-SDK-2.1)
# [ar40PoE injector](#ar40PoE-injector)
# [ar41Определение версии SDK для обновления бутлоадера ESP8266](#ar41Определение-версии-SDK-для-обновления-бутлоадера-ESP8266)
# [ar42PlatformIO или прощай, Arduino IDE](#ar42PlatformIO-или-прощай,-Arduino-IDE)
# [ar43Размер структур и классов в программах на ESP8266](#ar43Размер-структур-и-классов-в-программах-на-ESP8266)
# [ar44Опрос кнопок через MCP23017 для ESP8266](#ar44Опрос-кнопок-через-MCP23017-для-ESP8266)
# [ar45DFRobot RGB LCD screen](#ar45DFRobot-RGB-LCD-screen)
# [ar46ESP8266 обработка кнопок с помощью прерываний](#ar46ESP8266-обработка-кнопок-с-помощью-прерываний)
# [ar47AVR 168/328 и прерывания от любого пина](#ar47AVR-168/328-и-прерывания-от-любого-пина)
# [ar48Отладка ESP32 в PlatformIO](#ar48Отладка-ESP32-в-PlatformIO)
# [ar49Обзор DFRobot FireBeetle Covers-24x8 LED Matrix](#ar49Обзор-DFRobot-FireBeetle-Covers-24x8-LED-Matrix)
# [ar50Сон вместо задержек для AVR168/328](#ar50Сон-вместо-задержек-для-AVR168/328)
# [ar51DFRobot FireBeetle Covers-24x8 пишет на русском языке](#ar51DFRobot-FireBeetle-Covers-24x8-пишет-на-русском-языке)
# [ar52За облаками небо](#ar52За-облаками-небо)
# [ar53Ping для библиотеки Ethernet 2.0](#ar53Ping-для-библиотеки-Ethernet-2.0)
# [ar54Arduino оптимизация использования оперативной памяти](#ar54Arduino-оптимизация-использования-оперативной-памяти)
# [ar55Параметры в скетче для ESP8266](#ar55Параметры-в-скетче-для-ESP8266)
# [ar56Mini RFID-RC522](#ar56Mini-RFID-RC522)
# [ar57RC522 I2C модуль](#ar57RC522-I2C-модуль)

# %%
a=1 if 3<2 else 3
print(a)
# Out:
# 3

# %% [markdown]
# #### json
# [https://python-scripts.com/json](https://python-scripts.com/json)

# %%
import json
l = [1,'ab',3]
st = json.dumps(l)
print(st)
# Out:
# [1, "ab", 3]

# %%
l=json.loads(st)
print(l)
# Out:
# [1, 'ab', 3]

# %% [markdown]
# [py060 Простая отладка сетевых приложений](#py060-Простая-отладка-сетевых-приложений)
# [py061 Сетевой вариант крестиков-ноликов на Питоне](#py061-Сетевой-вариант-крестиков-ноликов-на-Питоне)
# [py062 элементы тестирования консольной программы](#py062-элементы-тестирования-консольной-программы)
# [py063 игра Змейка](#py063-игра-Змейка)
# [py064 Python отладчик для исправления ошибок](#py064-Python-отладчик-для-исправления-ошибок)
# [py065 Python работа с сетью на канальном уровне](#py065-Python-работа-с-сетью-на-канальном-уровне)
# [py066 Пятнашки на Питоне](#py066-Пятнашки-на-Питоне)
# [py067 Питон программа управления ШИМ контроллера](#py067-Питон-программа-управления-ШИМ-контроллера)
# [py068 Питон скачиваем документы по ссылкам](#py068-Питон-скачиваем-документы-по-ссылкам)
# [py069 Формируем HTML тест из DOC файла](#py069-Формируем-HTML-тест-из-DOC-файла)

# %% [markdown]
# #### py060 Простая отладка сетевых приложений
# #### py061 Сетевой вариант крестиков-ноликов на Питоне
# #### py062 элементы тестирования консольной программы

# %%
#== 01.py 
def fn(st):
    if st[0] == 'm':
        return st*3
    else:
        return st*2

while 1:
    st = input(':')
    if st == 'x': 
        break 
    st = fn(st)
    print (st)

print ('end of work')
# Out:
# :ф
# фф
# :m
# mmm
# :x
# end of work

# %%
#== test.py   by A.B.Glazov
#== test work of consol python programm
import sys

#-- handle run error 
if len(sys.argv) <  3:
    print ('error of usage')
    print ('you must write:')
    print ('    test.py consol.py inp.txt > out.txt')
    print ('        where:')
    print ('    consol.py - name of testing module')
    print ('    inp.txt - file with the list of input strings')
    print ('    out.txt - file for writing all answers')
    sys.exit()

testing_file = sys.argv[1]
input_file   = sys.argv[2]

#-- prepare list of input strings
fh_input = open(input_file)
ls_input = fh_input.readlines()
fh_input.close()

num = len(ls_input) - 1
while  num >=0:
    if ls_input[num][0] == '#':   #-- delete comments
        res = ls_input.pop(num) 
    else:                         #-- cut end of line     
        ls_input[num] = ls_input[num].strip()
    num -= 1

#-- redefine raw_input    
in_num = 0
def input(param):
    global in_num
    in_st = ls_input[in_num]
    in_num +=1
    return in_st

#-- handle testing module
res = execfile(testing_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-946520f62056> in <module>
#      39
#      40 #-- handle testing module
# ---> 41 res = execfile(testing_file)
#
# NameError: name 'execfile' is not defined

# %% [markdown]
# #### py063 игра Змейка
# #### py064 Python отладчик для исправления ошибок
# #### py065 Python работа с сетью на канальном уровне
# #### py066 Пятнашки на Питоне
# #### py067 Питон программа управления ШИМ контроллера

# %% [markdown]
# #### py068 Питон скачиваем документы по ссылкам

# %%
from urllib.request import urlopen, urlretrieve, unquote, quote
from urllib import parse
import urllib
s="http://ef-pmr.org/uploads/law/121_zakon_n121-З-III_29-04-2002.rar"
bytes=s.encode()
urllib.parse.quote_from_bytes(bytes, safe=':/')
# Out:
# 'http://ef-pmr.org/uploads/law/121_zakon_n121-%D0%97-III_29-04-2002.rar'

# %% [markdown]
# [egass](http://ef-pmr.org/law)

# %%
# !mkdir efpmr

# %%
#скачать все документы из сайта "http://ef-pmr.org/law/"
#предварительно слздать каталог 'efpmr'
#и скопировать в него unrar.exe из "program files\winrar"

#перейти в подкаталог для скачивания файлов
import os
# os.chdir('efpmr')
print (os.getcwd())

#сформировать список всех ссылок
from urllib.request import urlopen, urlretrieve, unquote
from urllib import parse
import urllib
from bs4 import BeautifulSoup

url = "http://ef-pmr.org/law/"
      
content = urlopen( url )
page2 = content.read()
page = page2.decode('utf-8')


soup = BeautifulSoup(page)

# print(soup.prettify())

body = soup.find('body')
ref_list = body.findAll('a')

#выбрать все ссылки на документы
filref_list = []
for num in range(len(ref_list)):
    ref = ref_list[num]
    href = ref['href']
    if href[-4:] in ['docx','.pdf','.rar','.zip','.doc']:
        filref_list.append(href)

#убрать возможное дублирование
print (len(filref_list))
setref_list = set(filref_list)
filref_list = list(setref_list)
print (len(filref_list))

#функция формирования имени файла из ссылки 
def form_filename2(href):
    print(href)
    href1 = href.encode('utf-8').decode('utf-8')
    href2 = unquote(href1)
#     href3 = href2.decode('utf-8').encode('cp1251')
    href3 = href1.replace(' ','%20')
    print(href3)
    file_name = href3.split('/')[-1]
    return href3, file_name

def form_filename(href):
    print(href)
    href1 = href.encode('utf-8').decode('utf-8')

#     s="http://ef-pmr.org/uploads/law/121_zakon_n121-З-III_29-04-2002.rar"
    href2=href1.encode()
    href3 = urllib.parse.quote_from_bytes(href2, safe=':/')    
    
    
#     href2 = unquote(href1)
#     href3 = href2.decode('utf-8').encode('cp1251')
#     href3 = href1.replace(' ','%20')
    print(href3)
    file_name = href3.split('/')[-1]
    return href3, file_name

#Простое скачивание:
docref_list = [href for href in filref_list \
     if href[-4:] in ['docx','.doc','.pdf']]
print (len(docref_list))
    
for href in docref_list:
    href1, file_name = form_filename(href)
    print (file_name)
    res = urlretrieve(href1, file_name)

#Работа с RAR архивами            
rarref_list = [href for href in filref_list if href[-4:] in ['.rar']]
print (len(rarref_list))

for href in rarref_list:
    href1, file_name = form_filename(href)
    print (file_name)
    res = urlretrieve(href1, file_name)
    res = os.system('unrar.exe e '+ file_name)
    os.remove( file_name )

#Работа с ZIP архивами    
import zipfile
    
zipref_list = [href for href in filref_list if href[-4:] in ['.zip']]
print (len(zipref_list))
    
for href in zipref_list:
    href1, file_name = form_filename(href)
    print (file_name)
    res = urlretrieve(href1, file_name)
    zip_ref = zipfile.ZipFile(file_name, 'r')
    for dos_name in zip_ref.namelist():
        full_dosname = zip_ref.extract(dos_name)
        str2 = dos_name.encode('cp437')
        win_name = str2.decode('cp866')
        os.rename(dos_name, win_name)
    zip_ref.close()
    os.remove( file_name )
# Out:
# D:\mailCloud\prjother\089hosts\jnotebook\pyoop\prkt\efpmr
# 200
# 100
# 47
# http://ef-pmr.org/uploads/law/100_postanovlenie_n50_13-03-2013.docx
# http://ef-pmr.org/uploads/law/100_postanovlenie_n50_13-03-2013.docx
# 100_postanovlenie_n50_13-03-2013.docx
# http://ef-pmr.org/uploads/law/061_n34-ZID-V_27-04-2012.docx
# http://ef-pmr.org/uploads/law/061_n34-ZID-V_27-04-2012.docx
# 061_n34-ZID-V_27-04-2012.docx
# http://ef-pmr.org/uploads/law/109_postanovlenie_n168_06-07-2017.docx
# http://ef-pmr.org/uploads/law/109_postanovlenie_n168_06-07-2017.docx
# 109_postanovlenie_n168_06-07-2017.docx
# http://ef-pmr.org/uploads/law/085_zakon_n350-Z-III_4_11_2003.doc
# http://ef-pmr.org/uploads/law/085_zakon_n350-Z-III_4_11_2003.doc
# 085_zakon_n350-Z-III_4_11_2003.doc
# http://ef-pmr.org/uploads/law/123_prikaz_n19_14-04-2009.docx
# http://ef-pmr.org/uploads/law/123_prikaz_n19_14-04-2009.docx
# 123_prikaz_n19_14-04-2009.docx
# http://ef-pmr.org/uploads/law/116_postanovlenie_n50_13_03_2013.docx
# http://ef-pmr.org/uploads/law/116_postanovlenie_n50_13_03_2013.docx
# 116_postanovlenie_n50_13_03_2013.docx
# http://ef-pmr.org/uploads/law/120_prikaz_n1362_12-11-2018.pdf
# http://ef-pmr.org/uploads/law/120_prikaz_n1362_12-11-2018.pdf
# 120_prikaz_n1362_12-11-2018.pdf
# http://ef-pmr.org/uploads/law/065_zakon_nN 557-Z-IV_29-09-2011.docx
# http://ef-pmr.org/uploads/law/065_zakon_nN%20557-Z-IV_29-09-2011.docx
# 065_zakon_nN%20557-Z-IV_29-09-2011.docx
# http://ef-pmr.org/uploads/law/064_postanovlenie_n15_15-03-12.docx
# http://ef-pmr.org/uploads/law/064_postanovlenie_n15_15-03-12.docx
# 064_postanovlenie_n15_15-03-12.docx
# http://ef-pmr.org/uploads/law/112_prikaz_o_uvolnenii_v _svyazi_s_likvid.doc
# http://ef-pmr.org/uploads/law/112_prikaz_o_uvolnenii_v%20_svyazi_s_likvid.doc
# 112_prikaz_o_uvolnenii_v%20_svyazi_s_likvid.doc
# http://ef-pmr.org/uploads/law/098_postanovlenie_n22_12-02-2013.docx
# http://ef-pmr.org/uploads/law/098_postanovlenie_n22_12-02-2013.docx
# 098_postanovlenie_n22_12-02-2013.docx
# http://ef-pmr.org/uploads/law/006_zakon_o_pogrebenii_i_pohoronnom_dele.doc
# http://ef-pmr.org/uploads/law/006_zakon_o_pogrebenii_i_pohoronnom_dele.doc
# 006_zakon_o_pogrebenii_i_pohoronnom_dele.doc
# http://ef-pmr.org/uploads/law/113_min_sz_t_rasporiajenie_n_361_10-06-2014.pdf
# http://ef-pmr.org/uploads/law/113_min_sz_t_rasporiajenie_n_361_10-06-2014.pdf
# 113_min_sz_t_rasporiajenie_n_361_10-06-2014.pdf
# http://ef-pmr.org/uploads/law/005_zakon_ob_ohrane_truda.doc
# http://ef-pmr.org/uploads/law/005_zakon_ob_ohrane_truda.doc
# 005_zakon_ob_ohrane_truda.doc
# http://ef-pmr.org/uploads/law/125_prikaz_n555_18-06-2019.pdf
# http://ef-pmr.org/uploads/law/125_prikaz_n555_18-06-2019.pdf
# 125_prikaz_n555_18-06-2019.pdf
# http://ef-pmr.org/uploads/law/zakon_no14_2018-01-12.pdf
# http://ef-pmr.org/uploads/law/zakon_no14_2018-01-12.pdf
# zakon_no14_2018-01-12.pdf
# http://ef-pmr.org/uploads/law/110_prikaz_ob_utverzhdenii_edinoi_formy_blankov_dokumentov.docx
# http://ef-pmr.org/uploads/law/110_prikaz_ob_utverzhdenii_edinoi_formy_blankov_dokumentov.docx
# 110_prikaz_ob_utverzhdenii_edinoi_formy_blankov_dokumentov.docx
# http://ef-pmr.org/uploads/law/069_zakon_n90-Z-III_28_12_2001.docx
# http://ef-pmr.org/uploads/law/069_zakon_n90-Z-III_28_12_2001.docx
# 069_zakon_n90-Z-III_28_12_2001.docx
# http://ef-pmr.org/uploads/law/prikaz_pensii_s_1_ianv_2016.docx
# http://ef-pmr.org/uploads/law/prikaz_pensii_s_1_ianv_2016.docx
# prikaz_pensii_s_1_ianv_2016.docx
# http://ef-pmr.org/uploads/law/115_zakon_pmr_209_208_210.docx
# http://ef-pmr.org/uploads/law/115_zakon_pmr_209_208_210.docx
# 115_zakon_pmr_209_208_210.docx
# http://ef-pmr.org/uploads/law/063_zakon_7-10-2012.docx
# http://ef-pmr.org/uploads/law/063_zakon_7-10-2012.docx
# 063_zakon_7-10-2012.docx
# http://ef-pmr.org/uploads/law/059_zakon_n480-Z-IV_01-07-2017.doc
# http://ef-pmr.org/uploads/law/059_zakon_n480-Z-IV_01-07-2017.doc
# 059_zakon_n480-Z-IV_01-07-2017.doc
# http://ef-pmr.org/uploads/law/rasporiajenie_438.docx
# http://ef-pmr.org/uploads/law/rasporiajenie_438.docx
# rasporiajenie_438.docx
# http://ef-pmr.org/uploads/law/084_zakon_n344-Z_04_08_2017.doc
# http://ef-pmr.org/uploads/law/084_zakon_n344-Z_04_08_2017.doc
# 084_zakon_n344-Z_04_08_2017.doc
# http://ef-pmr.org/uploads/law/111_prikaz_o_trudoustr_nesovershennoletnih.doc
# http://ef-pmr.org/uploads/law/111_prikaz_o_trudoustr_nesovershennoletnih.doc
# 111_prikaz_o_trudoustr_nesovershennoletnih.doc
# http://ef-pmr.org/uploads/law/101_postanovlenie_n51_14-03-2013.docx
# http://ef-pmr.org/uploads/law/101_postanovlenie_n51_14-03-2013.docx
# 101_postanovlenie_n51_14-03-2013.docx
# http://ef-pmr.org/uploads/law/060_n97-ZI-V_11-05-2011.docx
# http://ef-pmr.org/uploads/law/060_n97-ZI-V_11-05-2011.docx
# 060_n97-ZI-V_11-05-2011.docx
# http://ef-pmr.org/uploads/law/124_prikaz_n554_18-06-2019.pdf
# http://ef-pmr.org/uploads/law/124_prikaz_n554_18-06-2019.pdf
# 124_prikaz_n554_18-06-2019.pdf
# http://ef-pmr.org/uploads/law/057_prikaz_n27_22-10-2008.doc
# http://ef-pmr.org/uploads/law/057_prikaz_n27_22-10-2008.doc
# 057_prikaz_n27_22-10-2008.doc
# http://ef-pmr.org/uploads/law/067_zakon_n238-Z-V_12-12-2011.docx
# http://ef-pmr.org/uploads/law/067_zakon_n238-Z-V_12-12-2011.docx
# 067_zakon_n238-Z-V_12-12-2011.docx
# http://ef-pmr.org/uploads/law/082_zakon_n158-Z-V_29_09_2011.docx
# http://ef-pmr.org/uploads/law/082_zakon_n158-Z-V_29_09_2011.docx
# 082_zakon_n158-Z-V_29_09_2011.docx
# http://ef-pmr.org/uploads/law/103_prikaz_26_21-02-2013.docx
# http://ef-pmr.org/uploads/law/103_prikaz_26_21-02-2013.docx
# 103_prikaz_26_21-02-2013.docx
# http://ef-pmr.org/uploads/law/083_zakon_n156-Z-V_29_09_2011.docx
# http://ef-pmr.org/uploads/law/083_zakon_n156-Z-V_29_09_2011.docx
# 083_zakon_n156-Z-V_29_09_2011.docx
# http://ef-pmr.org/uploads/law/099_prikaz_n59_07-06-2013.docx
# http://ef-pmr.org/uploads/law/099_prikaz_n59_07-06-2013.docx
# 099_prikaz_n59_07-06-2013.docx
# http://ef-pmr.org/uploads/law/118_rasporyajenie_n330p_27_05_2015.pdf
# http://ef-pmr.org/uploads/law/118_rasporyajenie_n330p_27_05_2015.pdf
# 118_rasporyajenie_n330p_27_05_2015.pdf
# http://ef-pmr.org/uploads/law/037_prikaz_n17_30-10-2018.docx
# http://ef-pmr.org/uploads/law/037_prikaz_n17_30-10-2018.docx
# 037_prikaz_n17_30-10-2018.docx
# http://ef-pmr.org/uploads/law/097_ prikaz_n726_30-07-2019.pdf
# http://ef-pmr.org/uploads/law/097_%20prikaz_n726_30-07-2019.pdf
# 097_%20prikaz_n726_30-07-2019.pdf
# http://ef-pmr.org/uploads/law/127_prikaz_n4_14-01-2013.doc
# http://ef-pmr.org/uploads/law/127_prikaz_n4_14-01-2013.doc
# 127_prikaz_n4_14-01-2013.doc
# http://ef-pmr.org/uploads/law/066_zakon_n254-Z-IV_10-12-2010.docx
# http://ef-pmr.org/uploads/law/066_zakon_n254-Z-IV_10-12-2010.docx
# 066_zakon_n254-Z-IV_10-12-2010.docx
# http://ef-pmr.org/uploads/law/108_postaonovlenie_izm_vypl_gum_pomochi_rf_13-03-2014.docx
# http://ef-pmr.org/uploads/law/108_postaonovlenie_izm_vypl_gum_pomochi_rf_13-03-2014.docx
# 108_postaonovlenie_izm_vypl_gum_pomochi_rf_13-03-2014.docx
# http://ef-pmr.org/uploads/law/zakon_no_140_11-05-2016.pdf
# http://ef-pmr.org/uploads/law/zakon_no_140_11-05-2016.pdf
# zakon_no_140_11-05-2016.pdf
# http://ef-pmr.org/uploads/law/068_zakon_n314-Z_10-07-2000.docx
# http://ef-pmr.org/uploads/law/068_zakon_n314-Z_10-07-2000.docx
# 068_zakon_n314-Z_10-07-2000.docx
# http://ef-pmr.org/uploads/law/058_prilojenie_n27_k_prikazu_n515_22-10-2008.doc
# http://ef-pmr.org/uploads/law/058_prilojenie_n27_k_prikazu_n515_22-10-2008.doc
# 058_prilojenie_n27_k_prikazu_n515_22-10-2008.doc
# http://ef-pmr.org/uploads/law/040_prikaz_n337_30-10-2019.doc
# http://ef-pmr.org/uploads/law/040_prikaz_n337_30-10-2019.doc
# 040_prikaz_n337_30-10-2019.doc
# http://ef-pmr.org/uploads/law/109_prikaz_ME_o_vedenii_trudovyh_knizhek.doc
# http://ef-pmr.org/uploads/law/109_prikaz_ME_o_vedenii_trudovyh_knizhek.doc
# 109_prikaz_ME_o_vedenii_trudovyh_knizhek.doc
# http://ef-pmr.org/uploads/law/120_prikaz_n4429_22-01-2019.pdf
# http://ef-pmr.org/uploads/law/120_prikaz_n4429_22-01-2019.pdf
# 120_prikaz_n4429_22-01-2019.pdf
# http://ef-pmr.org/uploads/law/120_prikaz_n314_27-12-2002.docx
# http://ef-pmr.org/uploads/law/120_prikaz_n314_27-12-2002.docx
# 120_prikaz_n314_27-12-2002.docx
# 11
# http://ef-pmr.org/uploads/law/055_postanovlenie_n304_11-12-2013.rar
# http://ef-pmr.org/uploads/law/055_postanovlenie_n304_11-12-2013.rar
# 055_postanovlenie_n304_11-12-2013.rar
# http://ef-pmr.org/uploads/law/115_prikaz_n243_10_03_2016.rar
# http://ef-pmr.org/uploads/law/115_prikaz_n243_10_03_2016.rar
# 115_prikaz_n243_10_03_2016.rar
# http://ef-pmr.org/uploads/law/122_postanovlenie_n42_29-02-2016.rar
# http://ef-pmr.org/uploads/law/122_postanovlenie_n42_29-02-2016.rar
# 122_postanovlenie_n42_29-02-2016.rar
# http://ef-pmr.org/uploads/law/119_prikaz_n6423_16_05_2013.rar
# http://ef-pmr.org/uploads/law/119_prikaz_n6423_16_05_2013.rar
# 119_prikaz_n6423_16_05_2013.rar
# http://ef-pmr.org/uploads/law/053_postanovlenie_n295_04-12-2013.rar
# http://ef-pmr.org/uploads/law/053_postanovlenie_n295_04-12-2013.rar
# 053_postanovlenie_n295_04-12-2013.rar
# http://ef-pmr.org/uploads/law/052_prikaz_n978_28-09-2015.rar
# http://ef-pmr.org/uploads/law/052_prikaz_n978_28-09-2015.rar
# 052_prikaz_n978_28-09-2015.rar
# http://ef-pmr.org/uploads/law/136_prikaz_n312_10-04-2019.rar
# http://ef-pmr.org/uploads/law/136_prikaz_n312_10-04-2019.rar
# 136_prikaz_n312_10-04-2019.rar
# http://ef-pmr.org/uploads/law/022_zakon_o_soczoschite_chernob.rar
# http://ef-pmr.org/uploads/law/022_zakon_o_soczoschite_chernob.rar
# 022_zakon_o_soczoschite_chernob.rar
# http://ef-pmr.org/uploads/law/054_postanovlenie_n296_04-12-2013.rar
# http://ef-pmr.org/uploads/law/054_postanovlenie_n296_04-12-2013.rar
# 054_postanovlenie_n296_04-12-2013.rar
# http://ef-pmr.org/uploads/law/121_zakon_n121-З-III_29-04-2002.rar
# http://ef-pmr.org/uploads/law/121_zakon_n121-%D0%97-III_29-04-2002.rar
# 121_zakon_n121-%D0%97-III_29-04-2002.rar
# http://ef-pmr.org/uploads/law/21_prikaz_n361_29.03.2018.rar
# http://ef-pmr.org/uploads/law/21_prikaz_n361_29.03.2018.rar
# 21_prikaz_n361_29.03.2018.rar
# 42
# http://ef-pmr.org/uploads/law/002_zakon_ob_egfss.zip
# http://ef-pmr.org/uploads/law/002_zakon_ob_egfss.zip
# 002_zakon_ob_egfss.zip
# http://ef-pmr.org/uploads/law/015_prikaz_n12_04_02_2013.zip
# http://ef-pmr.org/uploads/law/015_prikaz_n12_04_02_2013.zip
# 015_prikaz_n12_04_02_2013.zip
# http://ef-pmr.org/uploads/law/045_zakon_185-zi-v.zip
# http://ef-pmr.org/uploads/law/045_zakon_185-zi-v.zip
# 045_zakon_185-zi-v.zip
# http://ef-pmr.org/uploads/law/017_prikaz_n135_19_03_2013.zip
# http://ef-pmr.org/uploads/law/017_prikaz_n135_19_03_2013.zip
# 017_prikaz_n135_19_03_2013.zip
# http://ef-pmr.org/uploads/law/025_prikaz_n16.zip
# http://ef-pmr.org/uploads/law/025_prikaz_n16.zip
# 025_prikaz_n16.zip
# http://ef-pmr.org/uploads/law/018_rasporyajenie_n548_24_06_2013.zip
# http://ef-pmr.org/uploads/law/018_rasporyajenie_n548_24_06_2013.zip
# 018_rasporyajenie_n548_24_06_2013.zip
# http://ef-pmr.org/uploads/law/021_zakon_ob_immunoprofilaktike.zip
# http://ef-pmr.org/uploads/law/021_zakon_ob_immunoprofilaktike.zip
# 021_zakon_ob_immunoprofilaktike.zip
# http://ef-pmr.org/uploads/law/001_zakon_ob_osnovah_socstrah.zip
# http://ef-pmr.org/uploads/law/001_zakon_ob_osnovah_socstrah.zip
# 001_zakon_ob_osnovah_socstrah.zip
# http://ef-pmr.org/uploads/law/028_prikaz_n28.zip
# http://ef-pmr.org/uploads/law/028_prikaz_n28.zip
# 028_prikaz_n28.zip
# http://ef-pmr.org/uploads/law/043_zakon_233-zi-v.zip
# http://ef-pmr.org/uploads/law/043_zakon_233-zi-v.zip
# 043_zakon_233-zi-v.zip
# http://ef-pmr.org/uploads/law/047_zakon_242-zid-v.zip
# http://ef-pmr.org/uploads/law/047_zakon_242-zid-v.zip
# 047_zakon_242-zid-v.zip
# http://ef-pmr.org/uploads/law/009_postanovlenie_napravlenie_sredstv_egfss.zip
# http://ef-pmr.org/uploads/law/009_postanovlenie_napravlenie_sredstv_egfss.zip
# 009_postanovlenie_napravlenie_sredstv_egfss.zip
# http://ef-pmr.org/uploads/law/026_prikaz_n19.zip
# http://ef-pmr.org/uploads/law/026_prikaz_n19.zip
# 026_prikaz_n19.zip
# http://ef-pmr.org/uploads/law/012_prikaz_n25_21-02-2013.zip
# http://ef-pmr.org/uploads/law/012_prikaz_n25_21-02-2013.zip
# 012_prikaz_n25_21-02-2013.zip
# http://ef-pmr.org/uploads/law/041_zakon_o_pens_obespechenii.zip
# http://ef-pmr.org/uploads/law/041_zakon_o_pens_obespechenii.zip
# 041_zakon_o_pens_obespechenii.zip
# http://ef-pmr.org/uploads/law/016_prikaz_n134_18-03-2013.zip
# http://ef-pmr.org/uploads/law/016_prikaz_n134_18-03-2013.zip
# 016_prikaz_n134_18-03-2013.zip
# http://ef-pmr.org/uploads/law/013_prikaz_n13_04-02-2013.zip
# http://ef-pmr.org/uploads/law/013_prikaz_n13_04-02-2013.zip
# 013_prikaz_n13_04-02-2013.zip
# http://ef-pmr.org/uploads/law/040_zakon_132-zi-v.zip
# http://ef-pmr.org/uploads/law/040_zakon_132-zi-v.zip
# 040_zakon_132-zi-v.zip
# http://ef-pmr.org/uploads/law/051_zakon_267-zid-v.zip
# http://ef-pmr.org/uploads/law/051_zakon_267-zid-v.zip
# 051_zakon_267-zid-v.zip
# http://ef-pmr.org/uploads/law/024_prikaz_n15.zip
# http://ef-pmr.org/uploads/law/024_prikaz_n15.zip
# 024_prikaz_n15.zip
# http://ef-pmr.org/uploads/law/033_zakon_zan_nasel.zip
# http://ef-pmr.org/uploads/law/033_zakon_zan_nasel.zip
# 033_zakon_zan_nasel.zip
# http://ef-pmr.org/uploads/law/029_prikaz_n29.zip
# http://ef-pmr.org/uploads/law/029_prikaz_n29.zip
# 029_prikaz_n29.zip
# http://ef-pmr.org/uploads/law/116_zakon_rabote_s_likvidiruemymi_organizaciyami_09.01.2015.zip
# http://ef-pmr.org/uploads/law/116_zakon_rabote_s_likvidiruemymi_organizaciyami_09.01.2015.zip
# 116_zakon_rabote_s_likvidiruemymi_organizaciyami_09.01.2015.zip
# http://ef-pmr.org/uploads/law/038_prikaz_n119.zip
# http://ef-pmr.org/uploads/law/038_prikaz_n119.zip
# 038_prikaz_n119.zip
# http://ef-pmr.org/uploads/law/036_prikaz_n32.zip
# http://ef-pmr.org/uploads/law/036_prikaz_n32.zip
# 036_prikaz_n32.zip
# http://ef-pmr.org/uploads/law/011_prikaz_n9_29-01-2013.zip
# http://ef-pmr.org/uploads/law/011_prikaz_n9_29-01-2013.zip
# 011_prikaz_n9_29-01-2013.zip
# http://ef-pmr.org/uploads/law/050_postanovlenie_292.zip
# http://ef-pmr.org/uploads/law/050_postanovlenie_292.zip
# 050_postanovlenie_292.zip
# http://ef-pmr.org/uploads/law/114_prikaz_ob_utverjzdenii_form_dokumentov_persucheta_n1074_2014-11-29.zip
# http://ef-pmr.org/uploads/law/114_prikaz_ob_utverjzdenii_form_dokumentov_persucheta_n1074_2014-11-29.zip
# 114_prikaz_ob_utverjzdenii_form_dokumentov_persucheta_n1074_2014-11-29.zip
# http://ef-pmr.org/uploads/law/046_zakon_222-zi-v.zip
# http://ef-pmr.org/uploads/law/046_zakon_222-zi-v.zip
# 046_zakon_222-zi-v.zip
# http://ef-pmr.org/uploads/law/031_prikaz_n31.zip
# http://ef-pmr.org/uploads/law/031_prikaz_n31.zip
# 031_prikaz_n31.zip
# http://ef-pmr.org/uploads/law/049_zakon_245-zd-v.zip
# http://ef-pmr.org/uploads/law/049_zakon_245-zd-v.zip
# 049_zakon_245-zd-v.zip
# http://ef-pmr.org/uploads/law/035_prikaz_n142.zip
# http://ef-pmr.org/uploads/law/035_prikaz_n142.zip
# 035_prikaz_n142.zip
# http://ef-pmr.org/uploads/law/048_zakon_226-zi-v.zip
# http://ef-pmr.org/uploads/law/048_zakon_226-zi-v.zip
# 048_zakon_226-zi-v.zip
# http://ef-pmr.org/uploads/law/023_postanovlenie_n56.zip
# http://ef-pmr.org/uploads/law/023_postanovlenie_n56.zip
# 023_postanovlenie_n56.zip
# http://ef-pmr.org/uploads/law/044_zakon_246-zid-v.zip
# http://ef-pmr.org/uploads/law/044_zakon_246-zid-v.zip
# 044_zakon_246-zid-v.zip
# http://ef-pmr.org/uploads/law/008_zakon_o_posobia_po_vremennoy_netrudosposobnosti.zip
# http://ef-pmr.org/uploads/law/008_zakon_o_posobia_po_vremennoy_netrudosposobnosti.zip
# 008_zakon_o_posobia_po_vremennoy_netrudosposobnosti.zip
# http://ef-pmr.org/uploads/law/010_postanovlenie_napravlenie_rashodivanii_egfss.zip
# http://ef-pmr.org/uploads/law/010_postanovlenie_napravlenie_rashodivanii_egfss.zip
# 010_postanovlenie_napravlenie_rashodivanii_egfss.zip
# http://ef-pmr.org/uploads/law/027_prikaz_n20.zip
# http://ef-pmr.org/uploads/law/027_prikaz_n20.zip
# 027_prikaz_n20.zip
# http://ef-pmr.org/uploads/law/032_prikaz_n33.zip
# http://ef-pmr.org/uploads/law/032_prikaz_n33.zip
# 032_prikaz_n33.zip
# http://ef-pmr.org/uploads/law/030_prikaz_n30.zip
# http://ef-pmr.org/uploads/law/030_prikaz_n30.zip
# 030_prikaz_n30.zip
# http://ef-pmr.org/uploads/law/050_zakon_268-zi-v.zip
# http://ef-pmr.org/uploads/law/050_zakon_268-zi-v.zip
# 050_zakon_268-zi-v.zip
# http://ef-pmr.org/uploads/law/039_prikaz_n45.zip
# http://ef-pmr.org/uploads/law/039_prikaz_n45.zip
# 039_prikaz_n45.zip

# %% [markdown]
# #### py069 Формируем HTML тест из DOC файла

# %%
# %%writefile phys.htm
# <html>
#
# <head>
# <meta http-equiv=Content-Type content="text/html; charset=windows-1251">
# <meta name=Generator content="Microsoft Word 11 (filtered)">
# <title>Тестовые задания на внутривузовское тестирование </title>
# <style>
# <!--
#  /* Font Definitions */
#  @font-face
# 	{font-family:Tahoma;
# 	panose-1:2 11 6 4 3 5 4 4 2 4;}
# @font-face
# 	{font-family:Calibri;
# 	panose-1:2 15 5 2 2 2 4 3 2 4;}
#  /* Style Definitions */
#  p.MsoNormal, li.MsoNormal, div.MsoNormal
# 	{margin:0cm;
# 	margin-bottom:.0001pt;
# 	font-size:12.0pt;
# 	font-family:"Times New Roman";}
# h6
# 	{margin-top:12.0pt;
# 	margin-right:0cm;
# 	margin-bottom:3.0pt;
# 	margin-left:0cm;
# 	font-size:11.0pt;
# 	font-family:"Times New Roman";}
# p.MsoAcetate, li.MsoAcetate, div.MsoAcetate
# 	{margin:0cm;
# 	margin-bottom:.0001pt;
# 	font-size:8.0pt;
# 	font-family:Tahoma;}
# span.Heading6Char
# 	{font-family:"Times New Roman";
# 	color:windowtext;
# 	font-weight:bold;}
# span.BalloonTextChar
# 	{font-family:Tahoma;
# 	color:windowtext;}
# @page Section1
# 	{size:595.3pt 841.9pt;
# 	margin:2.0cm 42.5pt 2.0cm 3.0cm;}
# div.Section1
# 	{page:Section1;}
# -->
# </style>
#
# </head>
#
# <body lang=RU>
#
# <div class=Section1>
#
# <p class=MsoNormal align=center style='text-align:center'><b>Тестовые задания
# на внутривузовское тестирование </b></p>
#
# <p class=MsoNormal align=center style='margin-left:5.65pt;text-align:center;
# background:white'><b><span style='letter-spacing:-.25pt'>по дисциплине «Физика»</span></b></p>
#
# <p class=MsoNormal align=center style='text-align:center'><b>для студентов </b><b><span
# lang=EN-US>II</span><span lang=EN-US> </span>курса </b></p>
#
# <p class=MsoNormal align=center style='text-align:center'><b>направления
# подготовки <span style='letter-spacing:-.35pt'>09.03.04 «Программная инженерия»</span></b></p>
#
# <p class=MsoNormal align=center style='margin-left:5.65pt;text-align:center;
# background:white'><b><span style='letter-spacing:-.35pt'>профиля «Разработка
# программно-информационных систем»</span></b></p>
#
# <p class=MsoNormal align=center style='margin-left:5.65pt;text-align:center;
# background:white'><b><span style='letter-spacing:-.35pt'>&nbsp;</span></b></p>
#
# <p class=MsoNormal align=center style='text-align:center;text-indent:27.0pt;
# background:white'><b>&nbsp;</b></p>
#
# <p class=MsoNormal style='text-align:justify'>1.  Определите максимальную
# энергию фотона в видимой серии спектра водорода (серии Бальмера).</p>
#
# <p class=MsoNormal>а) 1,89 эВ   б) 3,41 эВ   в) 1,89 МэВ    г) 3,41 МэВ.</p>
#
# <p class=MsoNormal>    </p>
#
# <p class=MsoNormal style='text-align:justify'>2. Определите, на сколько
# изменилась энергия электрона в атоме водорода при излучении атомом фотона с
# длиной волны &#955;=4,86*10<sup>-7</sup> м.</p>
#
# <p class=MsoNormal>а) 2,56 эВ   б) 5,12 эВ      в) 1,28 эВ   г) 10,24 эВ.</p>
#
# <p class=MsoNormal>&nbsp;</p>
#
# <p class=MsoNormal>3. Определите скорость электрона на третьей орбите атома
# водорода.</p>
#
# <p class=MsoNormal>а) 1,123 Мм/с    б) 1,123 м/с     в) 0,731 Мм/с   г) 0,731
# м/с.</p>
#
# <p class=MsoNormal>&nbsp;</p>
#
# <p class=MsoNormal>4. Определите потенциал ионизации атома водорода.</p>
#
# <p class=MsoNormal>а) 10,2 В    б) 13,6 В    в)  5,1 В   г)  27,2 В.</p>
#
# <p class=MsoNormal>&nbsp;</p>
#
# <p class=MsoNormal style='text-align:justify'>5. Определите длину волны де
# Бройля для электрона, находящегося в атоме водорода на третьей боровской
# орбите.</p>
#
# <p class=MsoNormal>а) 4 нм     б) 3 нм   в) 2 нм   г) 1 нм.</p>
#
# <p class=MsoNormal>&nbsp;</p>
#
# <p class=MsoNormal style='text-align:justify'>6. Определите отношение
# неопределенностей скорости электрона, если его координата установлена с
# точностью до 10<sup>-5</sup> м, и пылинки массой 10<sup>-12</sup> кг, если ее
# координата установлена с такой же точностью.</p>
#
# <p class=MsoNormal>а) 2,2*10<sup>18</sup>   б) 2,2*10<sup>-18</sup>   в) 1,1*10<sup>-18</sup>
# г)  1,1*10<sup>18</sup>.</p>
#
# <p class=MsoNormal style='text-align:justify'>&nbsp;</p>
#
# <p class=MsoNormal style='text-align:justify'>7. Электрон с энергией 5эВ
# движется в положительном направлении оси х, встречая на своем пути
# прямоугольный потенциальный барьер высотой 10 эВ и шириной 0,1 нм. Определите
# коэффициент прозрачности потенциального барьера.</p>
#
# <p class=MsoNormal>а) 0,1  б) 0,2  в) 0,3   г) 0,4.</p>
#
# <p class=MsoNormal>&nbsp;</p>
#
# <p class=MsoNormal style='text-align:justify'>8. Определите наименьшую длину
# волны рентгеновского излучения, если рентгеновская трубка работает при
# напряжении 150 кВ.</p>
#
# <p class=MsoNormal>а) 5,63 нм    б) 8,29 пм   в)  10,25 нм   г) 2,41 нм.</p>
#
# <p class=MsoNormal>&nbsp;</p>
#
# <p class=MsoNormal style='text-align:justify'>9.  Определите число свободных
# электронов, занимающих в среднем уровень энергии, равной энергии Ферми.</p>
#
# <p class=MsoNormal>а) 4   б) 3  в) 2    г) 1</p>
#
# <p class=MsoNormal>&nbsp;</p>
#
# <p class=MsoNormal>10.  Определите массу нейтрального атома <img width=36 height=19 id="Рисунок 2" src="phys.files/image001.gif">.</p>
#
# <p class=MsoNormal>а) 8,64*10<sup>-26</sup> кг    б)   8,64*10<sup>26</sup>кг
# в) 8,64*10<sup>-23</sup>кг   г) 8,64*10<sup>23</sup>кг.</p>
#
# <p class=MsoNormal>&nbsp;</p>
#
# <p class=MsoNormal style='text-align:justify'>11. Определите, пользуясь
# таблицей Менделеева число нейтронов и протонов в атомах  урана.</p>
#
# <p class=MsoNormal>а) 146    92      б)  92  146      в) 238    92     г) 92
# 238</p>
#
# <p class=MsoNormal>&nbsp;</p>
#
# <p class=MsoNormal style='text-align:justify'>12. Определите энергию связи ядра
# атома гелия <img
# width=32 height=19 id="Рисунок 4" src="phys.files/image002.gif">. Масса
# нейтрального атома гелия равна 6,6467*10<sup>-27</sup>кг.</p>
#
# <p class=MsoNormal>а) 14,2 МэВ   б)  7,1 МэВ   в) 28,4 МэВ   г)  56,8 МэВ.</p>
#
# <p class=MsoNormal>&nbsp;</p>
#
# <p class=MsoNormal style='text-align:justify'>13. Определите, какая часть
# начального количества ядер радиоактивного изотопа распадется за время, равное
# двум периодам полураспада.</p>
#
# <p class=MsoNormal>а) 0,75    б) 0,5   в) 0,25     г) 0,4.</p>
#
# <p class=MsoNormal>&nbsp;</p>
#
# <p class=MsoNormal style='text-align:justify'>14. Активность некоторого
# радиоактивного изотопа в начальный момент времени составляла 100Бк. Определите
# активность этого изотопа по истечении промежутка времени, равного половине
# периода полураспада.</p>
#
# <p class=MsoNormal>а) 70,7 Бк   б)  25,6 Бк    в) 30,8 Бк   г) 48,9 Бк.</p>
#
# <p class=MsoNormal>&nbsp;</p>
#
# <p class=MsoNormal>15. Пользуясь таблицей Менделеева и правилами смещения,
# определите, в какой элемент превращается  после трех &#945;- и трех &#946;-
# распадов.</p>
#
# <p class=MsoNormal>а) <img
# width=43 height=19 id="Рисунок 6" src="phys.files/image003.gif">   б) <img width=43 height=19 id="Рисунок 8" src="phys.files/image004.gif">   в) <img width=42 height=19 id="Рисунок 10" src="phys.files/image005.gif">  г) <img width=44 height=19 id="Рисунок 12" src="phys.files/image006.gif"></p>
#
# <p class=MsoNormal align=center style='text-align:center;text-indent:27.0pt;
# background:white'><b>&nbsp;</b></p>
#
# </div>
#
# </body>
#
# </html>

# %%
# %%writefile test_calc.js
# function CalcMark(){
#     forms = document.querySelectorAll( '.answers' );
#     cnt_form = forms.length;
#     res = "";
#     for(num_form=0; num_form<cnt_form; num_form++){
#         form =forms[num_form];
#         sel_input = form.querySelector('input:checked');
#         if( sel_input ){
#             res += form.name + ":" + sel_input.value + ";";
#         } else {
#             res += form.name + ":0;";
#         }
#      }
#     document.formrez.test_res.value=res;
#   }
# Out:
# Writing test_calc.js

# %%
#coding: cp1251
#form_test.py
import re

#--функция обработки одного блока вопросов    
def make_form(answ_block, form_num):
    ls_answ = []
    loc_pos = answ_block.find(')')
    while loc_pos >=0:
        loc_beg = loc_pos-1
        loc_pos = answ_block.find(')', loc_pos+1)
        loc_end = loc_pos-2 if loc_pos > 0 else len(answ_block)-4
        answ = answ_block[loc_beg:loc_end]
        ls_answ.append(answ)
    form = '\n<FORM NAME ="f'+ str(form_num) + '" class = "answers">'
    for answ_num, answ in enumerate(ls_answ):
        form +='\n    <INPUT TYPE="radio" NAME="rd1" value ='+str(answ_num+1) +'>'+answ + '<br>'
    form += '\n</FORM>'
    form +='\n<hr color = blue align = center width = 50%>'
    new_block = '<p>'+form+'\n</p>'
    return new_block


#--открыть исходный файл
fh = open('phys.htm')
text = fh.read()
fh.close()

#--удалить комментарии
rex = re.compile("<!--[^>]*?>")
text1 = re.sub(rex,"", text)

#--удалить тэг стиля
rex = re.compile("<style>[^>]*?>")
text2 = re.sub(rex,"", text1)

#--упростиь тэги параграфов
rex = re.compile("<p[^>]*?>")
text3 = re.sub(rex,"<p>", text2)

#--упростиь тэги span
rex = re.compile("<span[^>]*?>")
text = re.sub(rex,"<span>", text3)

#--общий цикл обработки страницы
new_page = ''
form_num = 1
pos_beg = text.find("<p>а)")
pos_end = 0
while pos_beg >=0:
    new_page += text[pos_end:pos_beg]
    pos_end = text.find("</p>", pos_beg) + 4
    answ_block = text[pos_beg:pos_end]
    new_block = make_form(answ_block, form_num)

    #-- вставка для контроля
    if form_num == 1:
        print (answ_block)
        print (new_block)

    new_page += new_block
    pos_beg = text.find("<p>а)", pos_end)
    form_num +=1

#--дописать подвал страницы

footer ='''
\n<script src="test_calc.js"></script>

<p></p>
   <FORM NAME ="formrez">
      <P  ALIGN = CENTER >
      <INPUT TYPE="text" NAME="test_res" id="test_res" SIZE=80 VALUE=" " style="font-size:20px">
      <br>     
      <INPUT TYPE="button" VALUE="Результат" onClick="CalcMark();" style="font-size:20px">
   </FORM>\n
'''
new_page += footer
new_page += text[pos_end:]


#--записать результат в файл
fh = open('phys4.htm','w')
fh.write(new_page)
fh.close()
# Out:
# <p>а) 1,89 эВ   б) 3,41 эВ   в) 1,89 МэВ    г) 3,41 МэВ.</p>
# <p>
# <FORM NAME ="f1" class = "answers">
#     <INPUT TYPE="radio" NAME="rd1" value =1>а) 1,89 эВ  <br>
#     <INPUT TYPE="radio" NAME="rd1" value =2>б) 3,41 эВ  <br>
#     <INPUT TYPE="radio" NAME="rd1" value =3>в) 1,89 МэВ   <br>
#     <INPUT TYPE="radio" NAME="rd1" value =4>г) 3,41 МэВ.<br>
# </FORM>
# <hr color = blue align = center width = 50%>
# </p>

# %%
import re
text='''<DT><A HREF="http://www.zpmer.ru/index.php?option=com_salary&list_limitstart=140&view=firm_details_guest&employer=1183&Itemid=63" ADD_DATE="1438115355" ICON="data:image/png;base64,...">ЗПмер - зарплата в Yota, статистика зарплат по Санкт-Петербург, средняя зарплата Санкт-Петербург</A>'''
# очистить параметры тэга 
text="<p aaa>bbbb</p>"
tag = "p"
st = "<"+tag+"[^>]*?>"
rex = re.compile(st)
print(re.sub(rex, "<"+tag+">",text))
# Out:
# <p>bbbb</p>

# %%
# извлечь содержимое тега
text='''<A aaa>safsdf href = "sdfsfsfsfsfs" sfasfsaf</A>'''
tag = "A"
def tag_content(tag, text):
    st = "<"+tag+"[^>]*?>([\s\S]*?)<\/"+tag+">"
    rex = re.compile(st)
    res = re.search( rex, text)
    return res.group(1)
print(tag_content(tag, text))
# Out:
# safsdf href = "sdfsfsfsfsfs" sfasfsaf

# %%
# извлечь ссылку 
def get_a(text):
    tag = "A"
    st = "(HREF=\""+"[^\"]*?"+"\")"
    rex = re.compile(st)
    res = re.search( rex, text)
    return "<a>"+res.group(1)+"</a>"
text="safsdf HREF=\"sdfsfsfsfsfs\" sfasfsaf"
print(text)
print(get_a(text))
# Out:
# safsdf HREF="sdfsfsfsfsfs" sfasfsaf
# <a>HREF="sdfsfsfsfsfs"</a>

# %%
# извлечь ссылку 
def tag_content(tag, text):
    st = "<"+tag+"[^>]*?>([\s\S]*?)<\/"+tag+">"
    st = "<"+tag+"[^>]*?>([\s\S]*?)<\/"+tag+">"
    rex = re.compile(st)
    res = re.search( rex, text)
    return res.group(1)

def get_a(text):
    tag = "A"
    text = tag_content(tag, text)
    st = "(HREF=\""+"[^\"]*?"+"\")"
    rex = re.compile(st)
    res = re.search( rex, text)
    return "<a>"+res.group(1)+"</a>"
text='''<A aaa>safsdf HREF="sdfsfsfsfsfs" sfasfsaf</A>'''
print(get_a(text))
# Out:
# <a>HREF="sdfsfsfsfsfs"</a>

# %%
# извлечь ссылку 
t='''<A HREF="https://www.yandex.ru/" ADD_DATE="1470040980" ICON="data:image/png;base64,...">Яндекс</A>'''


def tag_content(tag, text):
    st = "<"+tag+"[^>]*?>([\s\S]*?)<\/"+tag+">"
    st = "<"+tag+"[^>]*?>([\s\S]*?)<\/"+tag+">"
    rex = re.compile(st)
    res = re.search( rex, text)
    return res.group(1)

def get_tagparams( tag, text ):
    st = "<" + tag + "([^>]*?)>"
    rex = re.compile(st)
    res = re.search( rex, text)
    return res.group(1)


def get_a(text):
    tag = "A"
    text = get_tagparams(tag, text)
    st = "(HREF=\""+"[^\"]*?"+"\")"
    rex = re.compile(st)
    res = re.search( rex, text)
    return "<a>"+res.group(1)+"</a>"
text='''<A aaa>safsdf HREF="sdfsfsfsfsfs" sfasfsaf</A>'''
print(get_a(t))
# Out:
# <a>HREF="https://www.yandex.ru/"</a>

# %% [markdown]
# #### py060 Простая отладка сетевых приложений
# #### py061 Сетевой вариант крестиков-ноликов на Питоне
# #### py062 элементы тестирования консольной программы
# #### py063 игра Змейка
# #### py064 Python отладчик для исправления ошибок
# #### py065 Python работа с сетью на канальном уровне
# #### py066 Пятнашки на Питоне
# #### py067 Питон программа управления ШИМ контроллера
# #### py068 Питон скачиваем документы по ссылкам
# #### py069 Формируем HTML тест из DOC файла

# %% [markdown]
# [abglazov](http://abglazov.rfpgu.ru/)
# [py060 Простая отладка сетевых приложений](https://www.youtube.com/watch?v=UpkYtsiYRks&list=PLku9se_HAVOp8pSgrIWGIjHLP-EOw_ywq&index=25)
# []()
# []()

# %% [markdown]
# [`=`py001 Питон - практический старт](#py001-Питон---практический-старт)
# [`=`py002 Питон - инженерный калькулятор](#py002-Питон---инженерный-калькулятор)
# [`=`py003 Питон - калькулятор комплексных чисел](#py003-Питон---калькулятор-комплексных-чисел)
# [`=`py004 Питон - решение квадратного уравнения](#py004-Питон---решение-квадратного-уравнения)
# [`=`py005 Питон расчет RC цепочки для гармонического сигнала](#py005-Питон-расчет-RC-цепочки-для-гармонического-сигнала)
# [`=`py006 Питон график функции](#py006-Питон-график-функции)
# [`=`py007 Питон простая библиотека для графиков](#py007-Питон-простая-библиотека-для-графиков)
# [`=`py008 Питон координатная сетка и интерактивность грфики](#py008-Питон-координатная-сетка-и-интерактивность-грфики)
# [`=`py009 Применение простых элементов Tkinter](#py009-Применение-простых-элементов-Tkinter)
# [`=`py010 Питон строим график произвольной функции](#py010-Питон-строим-график-произвольной-функции)
# [`=`py011 Питон создаем простой графический класс](#py011-Питон-создаем-простой-графический-класс)
# [`=`py012 Питон простое наследование классов](#py012-Питон-простое-наследование-классов)
#
#
# [`=`py013 Питон работа с различными кодировками](d13pyprk.ipynb)
# [`=`py014 Питон кодировки, часть 2 - автодекодирование](d13pyprk.ipynb)
# [`=`py015 Питон - постраничное листание текстовых списков](d13pyprk.ipynb)
# [py017 Питон проекция текстового файла на числовой массив](d13pyprk.ipynb)
# [`=`py016 Питон: кодировка среды ввода](d13pyprk.ipynb)
# [py018 Питон формирование таблицы DBSN](d13pyprk.ipynb)
# [py019 Экспорт MySQL таблицы в DBSN](d13pyprk.ipynb)
# [py020 Постраничный просмотр таблицы DBSN](d13pyprk.ipynb)
# [py021 DBSN - начало использования](d21pyprk.ipynb)
# [`=`py022 Игра угадай число](d21pyprk.ipynb)
# [`=`py023 Питон списки часть 1](d21pyprk.ipynb)
# [py024 Питон игра Быки и коровы](d21pyprk.ipynb)
# [`=`py025 Питон связь по СОМ порту](d21pyprk.ipynb)
# [`=`py026 Питон применение генераторов списков](d21pyprk.ipynb)
# [`=`py027 Обработка строк](d21pyprk.ipynb)
# [`=`py028 Питон работа с файлами](d21pyprk.ipynb)
# [`=`py029 Питон множества](d21pyprk.ipynb)
# [`=`py030 Питон словари](d30pyprk.ipynb)
# [`=`py031 Питон графические примитивы](d30pyprk.ipynb)
# [`=`py032 Обработка событий канвы](d30pyprk.ipynb)
# [`=`py033 Питон перемещение объекта по Канве](d30pyprk.ipynb)
# [`=`py034 Обработка даты и времени](d30pyprk.ipynb)
# [`=`py035 Сжатие по Хаффману](d30pyprk.ipynb)
# [`=`py036 Новогодняя елка](d30pyprk.ipynb)
# [`=`py037 Простые средства отладки программ](d30pyprk.ipynb)
# [`=`py038 игра пинг-понг](d30pyprk.ipynb)
# [`=`py039 добавляем звук](d30pyprk.ipynb)
# [`=`py040 Питон - сырое чтение дисков](d40pyprk.ipynb)
# [`=`py041 Питон сетевой обмен по UDP протоколу](d40pyprk.ipynb)
# [`=`py042 Передача файлов по сети](d40pyprk.ipynb)
# [` `py043 Питон программа управления шаговым двигателем](d40pyprk.ipynb)
# [`=`py044 Питон многопоточные клиент и сервер UDP](d40pyprk.ipynb)
# [py045 Питон система ведущий-ведомые в локальной сети](d40pyprk.ipynb)
# [`=`py046 Питон парсинг HTML страницы](d40pyprk.ipynb)
# [py047 Питон работа по Modbus RTU](d40pyprk.ipynb)
# [py048 Консольное приложение для работы по протоколу Modbus RTU](d40pyprk.ipynb)
# [`=`py049 Питон управляем Экселем](d40pyprk.ipynb)
# [`=`py050 Программа текстовой связи с микроконтроллеромpy](d50pyprk.ipynb)
# [`=`py051 Простой таймер учета времени](d50pyprk.ipynb)
# [`=`py052 Питон работа с внешними приложениями](d50pyprk.ipynb)
# [`=`py053 Питон парсим плейлист Youtube канала](d50pyprk.ipynb)
# [`=`py054 Питон применение Radiobutton и Checkbutton](d50pyprk.ipynb)
# [`=`py055 Питон используем Listbox](d50pyprk.ipynb)
# [`=`py056 Сортировка списка](d50pyprk.ipynb)
# [py057 простой чат на UDP](d50pyprk.ipynb)
# [py058 Минибэкап на Питоне](d50pyprk.ipynb)
# [`=`py059 Крестики - нолики на Питоне](d50pyprk.ipynb)
# [py060 Простая отладка сетевых приложений](d60pyprk.ipynb)
# [py061 Сетевой вариант крестиков-ноликов на Питоне](d60pyprk.ipynb)
# [py062 элементы тестирования консольной программы](d60pyprk.ipynb)
# [py063 игра Змейка](d60pyprk.ipynb)
# [py064 Python отладчик для исправления ошибок](d60pyprk.ipynb)
# [py065 Python работа с сетью на канальном уровне](d60pyprk.ipynb)
# [py066 Пятнашки на Питоне](d60pyprk.ipynb)
# [py067 Питон программа управления ШИМ контроллера](d60pyprk.ipynb)
# [`=`py068 Питон скачиваем документы по ссылкам](d60pyprk.ipynb)
# [`=`py069 Формируем HTML тест из DOC файла](d60pyprk.ipynb)
# [`=`py070 применение простых регулярных выражений](d70pyprk.ipynb)
# [py071 Питон обслуживание клавиатуры](d70pyprk.ipynb)
# [`=`py072 Простое наследование классов ttk](d70pyprk.ipynb)
# [py073 Простейший текстовый редактор](d70pyprk.ipynb)
# [py074 программа на Python для исследования Atmega8](d70pyprk.ipynb)
# [py075 DBSN формирование записи](d70pyprk.ipynb)
# [py076 DBSN - структура записи](d70pyprk.ipynb)
# [py077 DBSN структура записи реального документа](d70pyprk.ipynb)
# [py078 DBSN заполняем запись данными документа](d70pyprk.ipynb)
# [py079 Сравнение питонов 2 и 3](d70pyprk.ipynb)
# [py080 Простая программа работы с СОМ портом на Python](d80pyprk.ipynb)
# [py081 Использование TFTP на Python 3](d80pyprk.ipynb)
# [py083 Парсим простые сайты на Python3](d80pyprk.ipynb)
#
# [py001 Питон - практический старт](https://www.youtube.com/watch?v=K3hE5C2kglI&list=PLku9se_HAVOp8pSgrIWGIjHLP-EOw_ywq&index=82)
# []()
# []()

# %%
s='''
[`=`py001 Питон - практический старт](#py001-Питон---практический-старт)   
[`=`py002 Питон - инженерный калькулятор](#py002-Питон---инженерный-калькулятор)   
[`=`py003 Питон - калькулятор комплексных чисел](#py003-Питон---калькулятор-комплексных-чисел)   
[`=`py004 Питон - решение квадратного уравнения](#py004-Питон---решение-квадратного-уравнения)   
[`=`py005 Питон расчет RC цепочки для гармонического сигнала](#py005-Питон-расчет-RC-цепочки-для-гармонического-сигнала)   
[`=`py006 Питон график функции](#py006-Питон-график-функции)   
[`=`py007 Питон простая библиотека для графиков](#py007-Питон-простая-библиотека-для-графиков)   
[`=`py008 Питон координатная сетка и интерактивность грфики](#py008-Питон-координатная-сетка-и-интерактивность-грфики)   
[`=`py009 Применение простых элементов Tkinter](#py009-Применение-простых-элементов-Tkinter)   
[`=`py010 Питон строим график произвольной функции](#py010-Питон-строим-график-произвольной-функции)   
[`=`py011 Питон создаем простой графический класс](#py011-Питон-создаем-простой-графический-класс)   
[`=`py012 Питон простое наследование классов](#py012-Питон-простое-наследование-классов)   
  
   
[`=`py013 Питон работа с различными кодировками](d13pyprk.ipynb)   
[`=`py014 Питон кодировки, часть 2 - автодекодирование](d13pyprk.ipynb)   
[`=`py015 Питон - постраничное листание текстовых списков](d13pyprk.ipynb)   
[py017 Питон проекция текстового файла на числовой массив](d13pyprk.ipynb)   
[`=`py016 Питон: кодировка среды ввода](d13pyprk.ipynb)   
[py018 Питон формирование таблицы DBSN](d13pyprk.ipynb)   
[py019 Экспорт MySQL таблицы в DBSN](d13pyprk.ipynb)   
[py020 Постраничный просмотр таблицы DBSN](d13pyprk.ipynb)   
[py021 DBSN - начало использования](d21pyprk.ipynb)   
[`=`py022 Игра угадай число](d21pyprk.ipynb)   
[`=`py023 Питон списки часть 1](d21pyprk.ipynb)   
[py024 Питон игра Быки и коровы](d21pyprk.ipynb)   
[`=`py025 Питон связь по СОМ порту](d21pyprk.ipynb)   
[`=`py026 Питон применение генераторов списков](d21pyprk.ipynb)   
[`=`py027 Обработка строк](d21pyprk.ipynb)   
[`=`py028 Питон работа с файлами](d21pyprk.ipynb)   
[`=`py029 Питон множества](d21pyprk.ipynb)   
[`=`py030 Питон словари](d30pyprk.ipynb)   
[`=`py031 Питон графические примитивы](d30pyprk.ipynb)   
[`=`py032 Обработка событий канвы](d30pyprk.ipynb)   
[`=`py033 Питон перемещение объекта по Канве](d30pyprk.ipynb)   
[`=`py034 Обработка даты и времени](d30pyprk.ipynb)   
[py035 Сжатие по Хаффману](d30pyprk.ipynb)   
[`=`py036 Новогодняя елка](d30pyprk.ipynb)   
[`=`py037 Простые средства отладки программ](d30pyprk.ipynb)   
[`=`py038 игра пинг-понг](d30pyprk.ipynb)   
[`=`py039 добавляем звук](d30pyprk.ipynb)   
[`=`py040 Питон - сырое чтение дисков](d40pyprk.ipynb)   
[`=`py041 Питон сетевой обмен по UDP протоколу](d40pyprk.ipynb)   
[`=`py042 Передача файлов по сети](d40pyprk.ipynb)   
[` `py043 Питон программа управления шаговым двигателем](d40pyprk.ipynb)   
[py044 Питон многопоточные клиент и сервер UDP](d40pyprk.ipynb)   
[py045 Питон система ведущий-ведомые в локальной сети](d40pyprk.ipynb)   
[`=`py046 Питон парсинг HTML страницы](d40pyprk.ipynb)   
[py047 Питон работа по Modbus RTU](d40pyprk.ipynb)   
[py048 Консольное приложение для работы по протоколу Modbus RTU](d40pyprk.ipynb)   
[`=`py049 Питон управляем Экселем](d40pyprk.ipynb)   
[py050 Программа текстовой связи с микроконтроллеромpy](d50pyprk.ipynb)   
[`=`py051 Простой таймер учета времени](d50pyprk.ipynb)   
[`=`py052 Питон работа с внешними приложениями](d50pyprk.ipynb)   
[`=`py053 Питон парсим плейлист Youtube канала](d50pyprk.ipynb)   
[`=`py054 Питон применение Radiobutton и Checkbutton](d50pyprk.ipynb)   
[`=`py055 Питон используем Listbox](d50pyprk.ipynb)   
[`=`py056 Сортировка списка](d50pyprk.ipynb)   
[py057 простой чат на UDP](d50pyprk.ipynb)   
[py058 Минибэкап на Питоне](d50pyprk.ipynb)   
[`=`py059 Крестики - нолики на Питоне](d50pyprk.ipynb)   
[py060 Простая отладка сетевых приложений](d60pyprk.ipynb)   
[py061 Сетевой вариант крестиков-ноликов на Питоне](d60pyprk.ipynb)   
[py062 элементы тестирования консольной программы](d60pyprk.ipynb)   
[py063 игра Змейка](d60pyprk.ipynb)   
[py064 Python отладчик для исправления ошибок](d60pyprk.ipynb)   
[py065 Python работа с сетью на канальном уровне](d60pyprk.ipynb)   
[py066 Пятнашки на Питоне](d60pyprk.ipynb)   
[py067 Питон программа управления ШИМ контроллера](d60pyprk.ipynb)   
[`=`py068 Питон скачиваем документы по ссылкам](d60pyprk.ipynb)   
[`=`py069 Формируем HTML тест из DOC файла](d60pyprk.ipynb)   
[`=`py070 применение простых регулярных выражений](d70pyprk.ipynb)   
[py071 Питон обслуживание клавиатуры](d70pyprk.ipynb)   
[`=`py072 Простое наследование классов ttk](d70pyprk.ipynb)   
[py073 Простейший текстовый редактор](d70pyprk.ipynb)   
[py074 программа на Python для исследования Atmega8](d70pyprk.ipynb)   
[py075 DBSN формирование записи](d70pyprk.ipynb)   
[py076 DBSN - структура записи](d70pyprk.ipynb)   
[py077 DBSN структура записи реального документа](d70pyprk.ipynb)   
[py078 DBSN заполняем запись данными документа](d70pyprk.ipynb)   
[py079 Сравнение питонов 2 и 3](d70pyprk.ipynb)   
[py080 Простая программа работы с СОМ портом на Python](d80pyprk.ipynb)   
[py081 Использование TFTP на Python 3](d80pyprk.ipynb)   
[py083 Парсим простые сайты на Python3](d80pyprk.ipynb)   

[py001 Питон - практический старт](https://www.youtube.com/watch?v=K3hE5C2kglI&list=PLku9se_HAVOp8pSgrIWGIjHLP-EOw_ywq&index=82)  
[]()  
[]()  
'''
s.count("=")
# Out:
# 51

# %% [markdown]
# [py013 Питон работа с различными кодировками](d13pyprk.ipynb)
# [py014 Питон кодировки, часть 2 - автодекодирование](#d13pyprk.ipynb)
# [py015 Питон - постраничное листание текстовых списков](#d13pyprk.ipynb)
# [py017 Питон проекция текстового файла на числовой массив](#d13pyprk.ipynb)
# [py016 Питон: кодировка среды ввода](#d13pyprk.ipynb)
# [py018 Питон формирование таблицы DBSN](#d13pyprk.ipynb)
# [py019 Экспорт MySQL таблицы в DBSN](#d13pyprk.ipynb)
# [py020 Постраничный просмотр таблицы DBSN](#d13pyprk.ipynb)

# %% [markdown]
# #### py001 Питон - практический старт

# %%
# !python -V

# %%
x='privet'
x

# %%
print(x)

# %%
x=5
print(x)

# %%
type(x)

# %%
y=12
z=x+y
z

# %%
w = input('?')

# %%
w

# %%
#1.py
x = 'privet'
print(x)

# %%
!1.py

# %%
#2.py
def __main__():
    x = 'privet'
    print(x)
    input('?')

# %%
!2.py

# %%
def calc():
    q = input('?')
    print(q)
calc()

# %%
print(input('?'))

# %% [markdown]
# ##### py002 Питон - инженерный калькулятор

# %%
x=12
y=7.2
z='privet'
print(type(x),type(y),type(z),)

# %%
q=str(y)
r=int(y)
print(q,r)

# %%
u = 17
print(bin(u), hex(u), oct(u))

# %%
p = 0b0101
print(p)

# %%
dir(p)

# %%
help(p)

# %%
x = -7
y = abs(x)
z = 5
print(y, y&z,bin(z),bin(y))

# %%
x=39
y=5
a,b=divmod(x,y)
print('частное = ',a,'  остаток = ',b)

# %%
import math
x=3
y=math.sin(x)
print(y)

# %%
l = dir(math)
print(l)

# %%
from math import *
print(sin(3),pi,e)

# %%
from math import *
print(input('?'))

# %%
sin(radians(30))

# %% [markdown]
# #### py003 Питон - калькулятор комплексных чисел

# %%
#from math import *
print(sqrt(9))

# %%
print(sqrt(-9))

# %%
z = 5 + 7j
q = 3 + 7j
print(z, q, z+q)

# %% [markdown]
# формула Эйлера
# e**ja = cos(a) + j*sin(a)

# %%
import cmath
l = dir(cmath)
print(l)

# %%
from cmath import *
y = sqrt(-9)
z = 5 + 7j
phi = phase(z)
print(y, abs(z), phi, degrees(phi), polar(z))

# %%
print(rect(8.602325267042627, 0.9505468408120752))

# %%
from math import *
from cmath import *
print(sin(2j), cos(12.3+7j))

# %% [markdown]
# #### py004 Питон - решение квадратного уравнения
# полином n степени имеет n корней
# #coding: cp866

# %%
from cmath import *
print('решение уравнения a*x*x + b*x + c = 0')
a,b,c = 1,2,1
x1 =(-b+sqrt(b*b-4*a*c))/(2*a)
x2 =(-b-sqrt(b*b-4*a*c))/(2*a)
print(a,b,c,'  ',x1,x2)
a,b,c = 1,7,2
x1 =(-b+sqrt(b*b-4*a*c))/(2*a)
x2 =(-b-sqrt(b*b-4*a*c))/(2*a)
print(a,b,c,'  ',x1,x2)
a,b,c = 1,0,1
x1 =(-b+sqrt(b*b-4*a*c))/(2*a)
x2 =(-b-sqrt(b*b-4*a*c))/(2*a)
print(a,b,c,'  ',x1,x2)

# %%
from cmath import *
try:
    a,b,c = 0,7,2
    x1 =(-b+sqrt(b*b-4*a*c))/(2*a)
    x2 =(-b-sqrt(b*b-4*a*c))/(2*a)
    print(a,b,c,'  ',x1,x2)
except:
    print('конец работы')

# %% [markdown]
# #### py005 Питон расчет RC цепочки для гармонического сигнала

# %% [markdown]
# ![img-2019-11-23-14-27-52.png](attachment:img-2019-11-23-14-27-52.png)

# %%
from math import *
from cmath import *
V=10; R=3000; C=0.000001; f=1000; t=0
w=2*pi*f
j=1j
Vin=V*exp(j*w*t)
Zc = 1/(j*w*C)
I = Vin/(R+Zc)
Vc = I*Zc
K = Vc/Vin
print(Vin,Zc,I,Vc, K)
k,phi = polar(K)
print(k,phi,degrees(phi))

# %% [markdown]
# #### py006 Питон график функции

# %% [markdown]
# ![img-2019-11-23-20-04-11.png](attachment:img-2019-11-23-20-04-11.png)

# %%
from math import *
from tkinter import *
root = Tk()
canv = Canvas(root,width=500,height=500)
canv.pack()
x0 = 40; y0 = 240; xm = 480; ym = 20
Sm = 1.2; tm=5
def coord(x0,y0,xm,ym, fil_color):
    canv.create_line(x0-10,y0,xm+10,y0,fill=fil_color,arrow=LAST)
    canv.create_line(x0,ym-10,x0,2*y0-ym+10,fill=fil_color,arrow=BOTH)

def graph(f, fm, tm, x0, y0, xm, ym, fil_color):
    xb = x0; t=0;yb=y0+(ym-y0)*f(t)/fm
    canv.create_line(xb,yb,xb,yb,fill=fil_color)
    for x in range(x0+2, xm, 2):
        t = tm*(x-x0)/(xm-x0)
        y = y0+(ym-y0)*f(t)/fm
        canv.create_line(xb, yb, x, y, fill=fil_color)
        xb = x; yb=y
    
coord(x0,y0,xm,ym, 'blue')
graph(sin, 1.2, 7, x0, y0, xm, ym, 'black')
root.mainloop()

# %%
from math import *
from tkinter import *
root = Tk()
canv = Canvas(root,width=500,height=500)
canv.pack()
x0 = 40; y0 = 240; xm = 480; ym = 20
Sm = 1.2; tm=5; text_size=12
def coord_in(x0,y0,xm,ym, fil_color, x_label ='x',y_label='y'):
    canv.create_line(x0-10,y0,xm+10,y0,fill=fil_color,arrow=LAST)
    canv.create_line(x0,ym-10,x0,2*y0-ym+10,fill=fil_color,arrow=BOTH)
    canv.create_text(x0 + 20,ym,text=y_label, font=('Arial',text_size))
    canv.create_text(xm, y0-20, text=x_label, font=('Arial',text_size))

def graph_in(f, fm, tm, x0, y0, xm, ym, fil_color):
    xb = x0; t=0;yb=y0+(ym-y0)*f(t)/fm
    canv.create_line(xb,yb,xb,yb,fill=fil_color)
    for x in range(x0+2, xm, 2):
        t = tm*(x-x0)/(xm-x0)
        y = y0+(ym-y0)*f(t)/fm
        canv.create_line(xb, yb, x, y, fill=fil_color)
        xb = x; yb=y
        
def coord(fil_color, x_label ='x',y_label='y'):
    coord_in(x0,y0,xm,ym, fil_color, x_label,y_label)

def graph(f, fil_color):
    graph_in(f, Sm, tm, x0, y0, xm, ym, fil_color)

def text(label, t, u):
    t = float(t)
    x = t*(xm-x0)/tm + x0
    y = y0+(ym-y0)*u/Sm
    canv.create_text(x,y,text=label,font=('Arial',text_size))
    
coord('blue', 't', 'U(t)')
graph(cos, 'darkred')
text('U=cos(t)', 0.8, 1.0)
root.mainloop()

# %% [markdown]
# #### py007 Питон простая библиотека для графиков

# %%
#graph0.py
from math import *
from tkinter import *
'''
root = Tk()
canv = Canvas(root,width=500,height=500)
canv.pack()
'''
x0 = 40; y0 = 240; xm = 480; ym = 20
Sm = 1.2; tm=5; text_size=12

def coord_in(x0,y0,xm,ym, fil_color, x_label ='x',y_label='y'):
    canv.create_line(x0-10,y0,xm+10,y0,fill=fil_color,arrow=LAST)
    canv.create_line(x0,ym-10,x0,2*y0-ym+10,fill=fil_color,arrow=BOTH)
    canv.create_text(x0 + 20,ym,text=y_label, font=('Arial',text_size))
    canv.create_text(xm, y0-20, text=x_label, font=('Arial',text_size))

def graph_in(f, fm, tm, x0, y0, xm, ym, fil_color):
    xb = x0; t=0;yb=y0+(ym-y0)*f(t)/fm
    canv.create_line(xb,yb,xb,yb,fill=fil_color)
    for x in range(x0+2, xm, 2):
        t = tm*(x-x0)/(xm-x0)
        y = y0+(ym-y0)*f(t)/fm
        canv.create_line(xb, yb, x, y, fill=fil_color)
        xb = x; yb=y
        
def coord(fil_color, x_label ='x',y_label='y'):
    coord_in(x0,y0,xm,ym, fil_color, x_label,y_label)

def graph(f, fil_color):
    graph_in(f, Sm, tm, x0, y0, xm, ym, fil_color)

def text(label, t, u):
    t = float(t)
    x = t*(xm-x0)/tm + x0
    y = y0+(ym-y0)*u/Sm
    canv.create_text(x,y,text=label,font=('Arial',text_size))
'''    
coord('blue', 't', 'U(t)')
graph(cos, 'darkred')
text('U=cos(t)', 0.8, 1.0)
root.mainloop()
'''

# %%
#graph0.py
from math import *
from tkinter import *

import graph1 as gr
gr.root = Tk()
gr.canv = Canvas(gr.root,width=500,height=500)
gr.canv.pack()
gr.Sm = 1.2 
gr.tm=5
gr.coord('blue', 't', 'U(t)')
gr.graph(cos, 'darkblue')
gr.text('U=cos(t)', 0.8, 1.0)
gr.graph(sin, 'darkred')
gr.text('U=sin(t)', 2.3, 1.0)
gr.root.mainloop()

# %% [markdown]
# #### py008 Питон координатная сетка и интерактивность грфики

# %%
#graph0.py
from math import *
from tkinter import *

root = Tk()
canv = Canvas(root,width=500,height=500)
canv.pack()

x0 = 40; y0 = 240; xm = 480; ym = 20
Sm = 1.2; tm=5; text_size=12
dash_size = 4
def coord_in(x0,y0,xm,ym, fil_color, x_label ='x',y_label='y'):
    canv.create_line(x0-10,y0,xm+10,y0,fill=fil_color,arrow=LAST)
    canv.create_line(x0,ym-10,x0,2*y0-ym+10,fill=fil_color,arrow=BOTH)
    canv.create_text(x0 + 20,ym,text=y_label, font=('Arial',text_size))
    canv.create_text(xm, y0-20, text=x_label, font=('Arial',text_size))

def graph_in(f, fm, tm, x0, y0, xm, ym, fil_color):
    xb = x0; t=0;yb=y0+(ym-y0)*f(t)/fm
    canv.create_line(xb,yb,xb,yb,fill=fil_color)
    for x in range(x0+2, xm, 2):
        t = tm*(x-x0)/(xm-x0)
        y = y0+(ym-y0)*f(t)/fm
        canv.create_line(xb, yb, x, y, fill=fil_color)
        xb = x; yb=y
        
def graph(f, fil_color):
    graph_in(f, Sm, tm, x0, y0, xm, ym, fil_color)

def text(label, t, u):
    t = float(t)
    x = t*(xm-x0)/tm + x0
    y = y0+(ym-y0)*u/Sm
    canv.create_text(x,y,text=label,font=('Arial',text_size))

def coord(fil_color, x_label ='x',y_label='y',dt=0.25,dU=0.2,grid=1):
    coord_in(x0,y0,xm,ym, fil_color, x_label,y_label)

    dt = float(dt)
    if dt != 0:
        t = dt
        disp_text = 0
        while t<tm:
            x = t*(xm-x0)/tm + x0
            canv.create_line(x,y0-5,x,y0+5,fill=fil_color)
            x_lab=str(t); x_lab[0:3]
            if disp_text:
                canv.create_text(x,y0+15,text=x_lab,font=('Arial',text_size))
                if grid:
                    canv.create_line(x,2*y0-ym,x,ym,fill=fil_color, dash=dash_size)
            t += dt
            disp_text=1 if disp_text==0 else 0
    
    dU = float(dU)
    if dU != 0:
        U = dU
        disp_text = 0
        while U<Sm:
            y = y0+(ym-y0)*U/Sm
            yn = y0+(y0-ym)*U/Sm
            canv.create_line(x0-5,y,x0+5,y,fill=fil_color)
            canv.create_line(x0-5,yn,x0+5,yn,fill=fil_color)
            y_lab=str(U); y_lab[0:3]
            if disp_text:
                canv.create_text(x0-20,y,text=y_lab,font=('Arial',text_size))
                canv.create_text(x0-20,yn,text='-'+y_lab,font=('Arial',text_size))
                if grid:
                    canv.create_line(x0,y,xm,y,fill=fil_color, dash=dash_size)
                    canv.create_line(x0,yn,xm,yn,fill=fil_color, dash=dash_size)
            U += dU
            disp_text=1 if disp_text==0 else 0
    
coord('blue', 't', 'U(t)')
graph(cos, 'darkred')
text('U=cos(t)', 0.8, 1.0)
root.mainloop()

# %%
#graph0.py
from math import *
from tkinter import *

import graph1 as gr
gr.root = Tk()
gr.canv = Canvas(gr.root,width=500,height=500)
gr.canv.pack()
gr.Sm = 1.2 
gr.tm=5
gr.coord('blue', 't', 'U(t)',0.25,0.2,1)
gr.graph(cos, 'darkblue')
gr.text('U=cos(t)', 0.8, 1.0)
gr.graph(sin, 'darkred')
gr.text('U=sin(t)', 2.3, 1.0)
gr.root.mainloop()

# %%
#graph0.py
from math import *
from tkinter import *

root = Tk()
canv = Canvas(root,width=500,height=500)
canv.pack()

x0 = 40; y0 = 240; xm = 480; ym = 20
Sm = 1.2; tm=5; text_size=12
dash_size = 4
def coord_in(x0,y0,xm,ym, fil_color, x_label ='x',y_label='y'):
    canv.create_line(x0-10,y0,xm+10,y0,fill=fil_color,arrow=LAST)
    canv.create_line(x0,ym-10,x0,2*y0-ym+10,fill=fil_color,arrow=BOTH)
    canv.create_text(x0 + 20,ym,text=y_label, font=('Arial',text_size))
    canv.create_text(xm, y0-20, text=x_label, font=('Arial',text_size))

def graph_in(f, fm, tm, x0, y0, xm, ym, fil_color):
    xb = x0; t=0;yb=y0+(ym-y0)*f(t)/fm
    canv.create_line(xb,yb,xb,yb,fill=fil_color)
    for x in range(x0+2, xm, 2):
        t = tm*(x-x0)/(xm-x0)
        y = y0+(ym-y0)*f(t)/fm
        canv.create_line(xb, yb, x, y, fill=fil_color)
        xb = x; yb=y
        
def graph(f, fil_color):
    graph_in(f, Sm, tm, x0, y0, xm, ym, fil_color)

def text(label, t, u):
    t = float(t)
    x = t*(xm-x0)/tm + x0
    y = y0+(ym-y0)*u/Sm
    canv.create_text(x,y,text=label,font=('Arial',text_size))

def coord(fil_color, x_label ='x',y_label='y',dt=0.25,dU=0.2,grid=1):
    coord_in(x0,y0,xm,ym, fil_color, x_label,y_label)

    dt = float(dt)
    if dt != 0:
        t = dt
        disp_text = 0
        while t<tm:
            x = t*(xm-x0)/tm + x0
            canv.create_line(x,y0-5,x,y0+5,fill=fil_color)
            x_lab=str(t); x_lab[0:3]
            if disp_text:
                canv.create_text(x,y0+15,text=x_lab,font=('Arial',text_size))
                if grid:
                    canv.create_line(x,2*y0-ym,x,ym,fill=fil_color, dash=dash_size)
            t += dt
            disp_text=1 if disp_text==0 else 0
    
    dU = float(dU)
    if dU != 0:
        U = dU
        disp_text = 0
        while U<Sm:
            y = y0+(ym-y0)*U/Sm
            yn = y0+(y0-ym)*U/Sm
            canv.create_line(x0-5,y,x0+5,y,fill=fil_color)
            canv.create_line(x0-5,yn,x0+5,yn,fill=fil_color)
            y_lab=str(U); y_lab[0:3]
            if disp_text:
                canv.create_text(x0-20,y,text=y_lab,font=('Arial',text_size))
                canv.create_text(x0-20,yn,text='-'+y_lab,font=('Arial',text_size))
                if grid:
                    canv.create_line(x0,y,xm,y,fill=fil_color, dash=dash_size)
                    canv.create_line(x0,yn,xm,yn,fill=fil_color, dash=dash_size)
            U += dU
            disp_text=1 if disp_text==0 else 0
'''
<Button-1><Button-2><Button-3><Double-Button-1>
canv.bind('<Button-1>', proect)
'''
def proect(event):
    '''draw dash line on the canvas from the selected point
    '''
    x=event.x;y=event.y
    canv.create_line(x0, y, x, y, dash=dash_size)
    canv.create_line(x, y0, x, y, dash=dash_size)

coord('blue', 't', 'U(t)')
graph(cos, 'darkred')
text('U=cos(t)', 0.8, 1.0)
canv.bind('<Double-Button-1>', proect)

root.mainloop()

# %% [markdown]
# #### py009 Применение простых элементов Tkinter

# %%
#coding: utf-8
#graph0.py
from math import *
from tkinter import *

root = Tk()
canv = Canvas(root,width=600,height=550)
canv.pack()

x0 = 40; y0 = 240; xm = 480; ym = 20
Sm = 1.2; tm=6.5; text_size=12
dash_size = 4
def coord_in(x0,y0,xm,ym, fil_color, x_label ='x',y_label='y'):
    canv.create_line(x0-10,y0,xm+10,y0,fill=fil_color,arrow=LAST)
    canv.create_line(x0,ym-10,x0,2*y0-ym+10,fill=fil_color,arrow=BOTH)
    canv.create_text(x0 + 20,ym,text=y_label, font=('Arial',text_size))
    canv.create_text(xm, y0-20, text=x_label, font=('Arial',text_size))

def graph_in(f, fm, tm, x0, y0, xm, ym, fil_color):
    xb = x0; t=0;yb=y0+(ym-y0)*f(t)/fm
    canv.create_line(xb,yb,xb,yb,fill=fil_color)
    for x in range(x0+2, xm, 2):
        t = tm*(x-x0)/(xm-x0)
        y = y0+(ym-y0)*f(t)/fm
        canv.create_line(xb, yb, x, y, fill=fil_color)
        xb = x; yb=y
        
def graph(f, fil_color):
    graph_in(f, Sm, tm, x0, y0, xm, ym, fil_color)

def text(label, t, u):
    t = float(t)
    x = t*(xm-x0)/tm + x0
    y = y0+(ym-y0)*u/Sm
    canv.create_text(x,y,text=label,font=('Arial',text_size))

def coord(fil_color, x_label ='x',y_label='y',dt=0.25,dU=0.2,grid=1):
    coord_in(x0,y0,xm,ym, fil_color, x_label,y_label)

    dt = float(dt)
    if dt != 0:
        t = dt
        disp_text = 0
        while t<tm:
            x = t*(xm-x0)/tm + x0
            canv.create_line(x,y0-5,x,y0+5,fill=fil_color)
            x_lab=str(t); x_lab[0:3]
            if disp_text:
                canv.create_text(x,y0+15,text=x_lab,font=('Arial',text_size))
                if grid:
                    canv.create_line(x,2*y0-ym,x,ym,fill=fil_color, dash=dash_size)
            t += dt
            disp_text=1 if disp_text==0 else 0
    
    dU = float(dU)
    if dU != 0:
        U = dU
        disp_text = 0
        while U<Sm:
            y = y0+(ym-y0)*U/Sm
            yn = y0+(y0-ym)*U/Sm
            canv.create_line(x0-5,y,x0+5,y,fill=fil_color)
            canv.create_line(x0-5,yn,x0+5,yn,fill=fil_color)
            y_lab=str(U); y_lab[0:3]
            if disp_text:
                canv.create_text(x0-20,y,text=y_lab,font=('Arial',text_size))
                canv.create_text(x0-20,yn,text='-'+y_lab,font=('Arial',text_size))
                if grid:
                    canv.create_line(x0,y,xm,y,fill=fil_color, dash=dash_size)
                    canv.create_line(x0,yn,xm,yn,fill=fil_color, dash=dash_size)
            U += dU
            disp_text=1 if disp_text==0 else 0
'''
<Button-1><Button-2><Button-3><Double-Button-1>
canv.bind('<Button-1>', proect)
'''
def proect(event):
    '''draw dash line on the canvas from the selected point
    '''
    x=event.x;y=event.y
    canv.create_line(x0, y, x, y, dash=dash_size)
    canv.create_line(x, y0, x, y, dash=dash_size)

coord('blue', 't', 'U(t)')
# graph(cos, 'darkred')
# text('U=cos(t)', 0.8, 1.0)
# canv.bind('<Double-Button-1>', proect)

a=1;w=1;phi=0
def fn(t):
    return a*cos(w*t+phi)

def fn_disp():
    global a; global w; global phi
    a=ed_a.get();a=float(a)
    w=ed_w.get();w=float(w)
    phi=ed_phi.get();phi=eval(phi)
    graph(fn, 'blue')

def fn_clear():
    global a; global w; global phi
    a=ed_a.get();a=float(a)
    w=ed_w.get();w=float(w)
    phi=ed_phi.get();phi=eval(phi)
    graph(fn, 'white')
    

lb_a=Label(root, text=u" Амплитуда:")
lb_a.pack(side='left')
ed_a = Entry(root,width=4)
ed_a.pack(side='left')

lb_w=Label(root, text=u" Частота:")
lb_w.pack(side='left')
ed_w= Entry(root,width=4)
ed_w.pack(side='left')

lb_phi=Label(root, text=u" фаза:")
lb_phi.pack(side='left')
ed_phi = Entry(root,width=4)
ed_phi.pack(side='left')

bt_disp = Button(root,bg='lightgreen',text=u" A*cos(w*t+phi) ", command=fn_disp)
bt_disp.pack(side='left')

bt_clear = Button(root,bg='lightblue',text=u" Clear ", command=fn_clear)
bt_clear.pack(side='left')

root.mainloop()

# %% [markdown]
# #### py010 Питон строим график произвольной функции

# %%
#coding: utf-8
#graph0.py
from math import *
from tkinter import *
'''
root = Tk()
canv = Canvas(root,width=600,height=550)
canv.pack()
'''
x0 = 40; y0 = 240; xm = 480; ym = 20
Sm = 1.2; tm=6.5; text_size=12
dash_size = 4
def coord_in(x0,y0,xm,ym, fil_color, x_label ='x',y_label='y'):
    canv.create_line(x0-10,y0,xm+10,y0,fill=fil_color,arrow=LAST)
    canv.create_line(x0,ym-10,x0,2*y0-ym+10,fill=fil_color,arrow=BOTH)
    canv.create_text(x0 + 20,ym,text=y_label, font=('Arial',text_size))
    canv.create_text(xm, y0-20, text=x_label, font=('Arial',text_size))

def graph_in(f, fm, tm, x0, y0, xm, ym, fil_color):
    xb = x0; t=0;yb=y0+(ym-y0)*f(t)/fm
    canv.create_line(xb,yb,xb,yb,fill=fil_color)
    for x in range(x0+2, xm, 2):
        t = tm*(x-x0)/(xm-x0)
        y = y0+(ym-y0)*f(t)/fm
        canv.create_line(xb, yb, x, y, fill=fil_color)
        xb = x; yb=y
        
def graph(f, fil_color):
    graph_in(f, Sm, tm, x0, y0, xm, ym, fil_color)

def text(label, t, u):
    t = float(t)
    x = t*(xm-x0)/tm + x0
    y = y0+(ym-y0)*u/Sm
    canv.create_text(x,y,text=label,font=('Arial',text_size))

def coord(fil_color, x_label ='x',y_label='y',dt=0.25,dU=0.2,grid=1):
    coord_in(x0,y0,xm,ym, fil_color, x_label,y_label)

    dt = float(dt)
    if dt != 0:
        t = dt
        disp_text = 0
        while t<tm:
            x = t*(xm-x0)/tm + x0
            canv.create_line(x,y0-5,x,y0+5,fill=fil_color)
            x_lab=str(t); x_lab[0:3]
            if disp_text:
                canv.create_text(x,y0+15,text=x_lab,font=('Arial',text_size))
                if grid:
                    canv.create_line(x,2*y0-ym,x,ym,fill=fil_color, dash=dash_size)
            t += dt
            disp_text=1 if disp_text==0 else 0
    
    dU = float(dU)
    if dU != 0:
        U = dU
        disp_text = 0
        while U<Sm:
            y = y0+(ym-y0)*U/Sm
            yn = y0+(y0-ym)*U/Sm
            canv.create_line(x0-5,y,x0+5,y,fill=fil_color)
            canv.create_line(x0-5,yn,x0+5,yn,fill=fil_color)
            y_lab=str(U); y_lab[0:3]
            if disp_text:
                canv.create_text(x0-20,y,text=y_lab,font=('Arial',text_size))
                canv.create_text(x0-20,yn,text='-'+y_lab,font=('Arial',text_size))
                if grid:
                    canv.create_line(x0,y,xm,y,fill=fil_color, dash=dash_size)
                    canv.create_line(x0,yn,xm,yn,fill=fil_color, dash=dash_size)
            U += dU
            disp_text=1 if disp_text==0 else 0
'''
<Button-1><Button-2><Button-3><Double-Button-1>
canv.bind('<Button-1>', proect)
'''
def proect(event):
    '''draw dash line on the canvas from the selected point
    '''
    x=event.x;y=event.y
    canv.create_line(x0, y, x, y, dash=dash_size)
    canv.create_line(x, y0, x, y, dash=dash_size)

'''
coord('blue', 't', 'U(t)')
# graph(cos, 'darkred')
# text('U=cos(t)', 0.8, 1.0)
# canv.bind('<Double-Button-1>', proect)
a=1;w=1;phi=0
def fn(t):
    return a*cos(w*t+phi)

def fn_disp():
    global a; global w; global phi
    a=ed_a.get();a=float(a)
    w=ed_w.get();w=float(w)
    phi=ed_phi.get();phi=eval(phi)
    graph(fn, 'blue')

def fn_clear():
    global a; global w; global phi
    a=ed_a.get();a=float(a)
    w=ed_w.get();w=float(w)
    phi=ed_phi.get();phi=eval(phi)
    graph(fn, 'white')
    

lb_a=Label(root, text=u" Амплитуда:")
lb_a.pack(side='left')
ed_a = Entry(root,width=4)
ed_a.pack(side='left')

lb_w=Label(root, text=u" Частота:")
lb_w.pack(side='left')
ed_w= Entry(root,width=4)
ed_w.pack(side='left')

lb_phi=Label(root, text=u" фаза:")
lb_phi.pack(side='left')
ed_phi = Entry(root,width=4)
ed_phi.pack(side='left')

bt_disp = Button(root,bg='lightgreen',text=u" A*cos(w*t+phi) ", command=fn_disp)
bt_disp.pack(side='left')

bt_clear = Button(root,bg='lightblue',text=u" Clear ", command=fn_clear)
bt_clear.pack(side='left')

root.mainloop()
'''

root = Tk()
# -- панели формы для кнопок и текстовых полей
pn_control = Frame(root, height = 70, bg = 'silver')
pn_graph = Frame(root, height = 550,width = 550, bg = 'white')
# -- side-расположение, fill-заполнение, expand-расширение выделенного текста
pn_control.pack(side='top', fill='x')
pn_graph.pack(side='bottom', expand=1, fill='both')

canv = Canvas(pn_graph, height = 550, width=550)
canv.pack(fill = 'both',expand=1)

# -- заполним панель управления текстовыми полями
y_top = 10; h_top=18 # -- координаты верхнего ряда
lb_Um = Label(pn_control, text="Um:")
lb_Um.place(x=10,y=y_top, width=20,height=h_top)
ed_Um = Entry(pn_control); ed_Um.insert(END,"1.7")
#ed_um.delete(0,END); ed_Um.insert(END,"1.4")
ed_Um.place(x=40,y=y_top,width=40,height=h_top)

lb_dU = Label(pn_control, text="dU:")
lb_dU.place(x=90,y=y_top, width=20,height=h_top)
ed_dU = Entry(pn_control); ed_dU.insert(END,"0.2")
ed_dU.place(x=120,y=y_top,width=40,height=h_top)

lb_fn = Label(pn_control, text="функция:")
lb_fn.place(x=170,y=y_top, width=60,height=h_top)
ed_fn = Entry(pn_control); ed_fn.insert(END,"sin(t)")
ed_fn.place(x=240,y=y_top,width=240,height=h_top)

# -- функции
def fn(t):      # -- выводимая функция
    return eval(fnt)

def fn_prep():  # -- подготовить чистую канву с координатами
    Um = ed_Um.get(); Sm = eval(Um)
    dU = eval(ed_dU.get())
    tm = 6.5; dt=0.25
    canv.delete("all")
    canv.create_rectangle(0,0,550,550,fill="white")
    coord('black','t','U(t)',dt,dU,1)
    return

def fn_draw():    # -- нарисовать график функции
    global fnt
    fnt = ed_fn.get()
    graph(fn,'blue')
    return

def fn_clear():    # -- стереть график функции
    global fnt
    fnt = ed_fn.get()
    graph(fn,'white')
    return

# -- заполним панель управления кнопками
y_bt=40;h_bt=20;w_bt=80    # -- координаты ряда кнопок

bt_prep = Button(pn_control, text = u'подготовить', command = fn_prep)
bt_prep.place(x=40,y=y_bt,width=w_bt,height=h_bt)

bt_draw = Button(pn_control, text = u'начертить', command = fn_draw)
bt_draw.place(x=200,y=y_bt,width=w_bt,height=h_bt)

bt_clear = Button(pn_control, text = u'стереть', command = fn_clear)
bt_clear.place(x=360,y=y_bt,width=w_bt,height=h_bt)


root.mainloop()

# %% [markdown]
# ```
# sin(t*2)
# t*sin(t*2)
# t*(t-2)/4
# exp(-t)*sin(3*t)
# (cos(t)+sin(t)*1j).real
# (cos(t)+sin(t)*1j).imag
# 1.5*sin((2*t)**2)
#
# *.py --> *.pyw - без консоли
# ```

# %% [markdown]
# #### py011 Питон создаем простой графический класс

# %%
#coding: utf-8
#graph0.py
from math import *
from tkinter import *
'''
root = Tk()
canv = Canvas(root,width=600,height=550)
canv.pack()
'''
x0 = 40; y0 = 240; xm = 480; ym = 20
Sm = 1.2; tm=6.5; text_size=12
dash_size = 4
def coord_in(x0,y0,xm,ym, fil_color, x_label ='x',y_label='y'):
    canv.create_line(x0-10,y0,xm+10,y0,fill=fil_color,arrow=LAST)
    canv.create_line(x0,ym-10,x0,2*y0-ym+10,fill=fil_color,arrow=BOTH)
    canv.create_text(x0 + 20,ym,text=y_label, font=('Arial',text_size))
    canv.create_text(xm, y0-20, text=x_label, font=('Arial',text_size))

def graph_in(f, fm, tm, x0, y0, xm, ym, fil_color):
    xb = x0; t=0;yb=y0+(ym-y0)*f(t)/fm
    canv.create_line(xb,yb,xb,yb,fill=fil_color)
    for x in range(x0+2, xm, 2):
        t = tm*(x-x0)/(xm-x0)
        y = y0+(ym-y0)*f(t)/fm
        canv.create_line(xb, yb, x, y, fill=fil_color)
        xb = x; yb=y
        
def graph(f, fil_color):
    graph_in(f, Sm, tm, x0, y0, xm, ym, fil_color)

def text(label, t, u):
    t = float(t)
    x = t*(xm-x0)/tm + x0
    y = y0+(ym-y0)*u/Sm
    canv.create_text(x,y,text=label,font=('Arial',text_size))

def coord(fil_color, x_label ='x',y_label='y',dt=0.25,dU=0.2,grid=1):
    coord_in(x0,y0,xm,ym, fil_color, x_label,y_label)

    dt = float(dt)
    if dt != 0:
        t = dt
        disp_text = 0
        while t<tm:
            x = t*(xm-x0)/tm + x0
            canv.create_line(x,y0-5,x,y0+5,fill=fil_color)
            x_lab=str(t); x_lab[0:3]
            if disp_text:
                canv.create_text(x,y0+15,text=x_lab,font=('Arial',text_size))
                if grid:
                    canv.create_line(x,2*y0-ym,x,ym,fill=fil_color, dash=dash_size)
            t += dt
            disp_text=1 if disp_text==0 else 0
    
    dU = float(dU)
    if dU != 0:
        U = dU
        disp_text = 0
        while U<Sm:
            y = y0+(ym-y0)*U/Sm
            yn = y0+(y0-ym)*U/Sm
            canv.create_line(x0-5,y,x0+5,y,fill=fil_color)
            canv.create_line(x0-5,yn,x0+5,yn,fill=fil_color)
            y_lab=str(U); y_lab[0:3]
            if disp_text:
                canv.create_text(x0-20,y,text=y_lab,font=('Arial',text_size))
                canv.create_text(x0-20,yn,text='-'+y_lab,font=('Arial',text_size))
                if grid:
                    canv.create_line(x0,y,xm,y,fill=fil_color, dash=dash_size)
                    canv.create_line(x0,yn,xm,yn,fill=fil_color, dash=dash_size)
            U += dU
            disp_text=1 if disp_text==0 else 0
'''
<Button-1><Button-2><Button-3><Double-Button-1>
canv.bind('<Button-1>', proect)
'''
def proect(event):
    '''draw dash line on the canvas from the selected point
    '''
    x=event.x;y=event.y
    canv.create_line(x0, y, x, y, dash=dash_size)
    canv.create_line(x, y0, x, y, dash=dash_size)

#-- 11 -------------------

class plLabel:
    def __init__(self, panel, x, y, width, height, text):
        self.lab = Label(panel,text=text)
        self.lab.place(x=x,y=y,width=width,height=height)

class plButton:
    def __init__(self, panel, x, y, width, height, text, cmd = ''):
        self.btn = Button(panel)
        self.btn["text"]=text
        if cmd:
            self.btn["command"] = cmd
        self.btn.place(x=x,y=y,width=width,height=height)

class plEntry:
    def __init__(self, panel, x, y, width, height, text, text_w, entry_w, val=''):
        self.lab = Label(panel,text=text)
        self.lab.place(x=x,y=y,width=text_w,height=height)
        self.ent = Entry(panel)
        self.ent.place(x=x+width-entry_w,y=y,width=entry_w,height=height)
        self.set(val)
        
    def get(self):
        return self.ent.get()
    
    def set(self, text):
        self.ent.delete(0,END)
        self.ent.insert(END, text)
        
    
# -- начало
root = Tk()

# -- функции
def fn(t):      # -- выводимая функция
    return eval(fnt)

def fn_prep():  # -- подготовить чистую канву с координатами
    Um = ed_Um.get(); Sm = eval(Um)
    dU = eval(ed_dU.get())
    tm = 6.5; dt=0.25
    canv.delete("all")
    canv.create_rectangle(0,0,550,550,fill="white")
    coord('black','t','U(t)',dt,dU,1)
    return

def fn_draw():    # -- нарисовать график функции
    global fnt
    fnt = ed_fn.get()
    graph(fn,'blue')
    return

def fn_clear():    # -- стереть график функции
    global fnt
    fnt = ed_fn.get()
    graph(fn,'white')
    return



# -- панели формы для кнопок и текстовых полей
pn_control = Frame(root, height = 70, bg = 'silver')
pn_graph = Frame(root, height = 550,width = 550, bg = 'white')
# -- side-расположение, fill-заполнение, expand-расширение выделенного текста
pn_control.pack(side='top', fill='x')
pn_graph.pack(side='bottom', expand=1, fill='both')

canv = Canvas(pn_graph, height = 550, width=550)
canv.pack(fill = 'both',expand=1)

# -- заполним панель управления текстовыми полями
y_top = 10; h_top=18 # -- координаты верхнего ряда
lb_Um = plLabel(pn_control,x=10,y=y_top, width=20,height=h_top, text="Um:")
ed_Um = Entry(pn_control); ed_Um.insert(END,"1.7")
#ed_um.delete(0,END); ed_Um.insert(END,"1.4")
ed_Um.place(x=40,y=y_top,width=40,height=h_top)

# lb_dU = plLabel(pn_control, 90, y_top, 20, h_top, text="dU:")
# ed_dU = Entry(pn_control); ed_dU.insert(END,"0.2")
# ed_dU.place(x=120,y=y_top,width=40,height=h_top)
ed_dU =plEntry(pn_control, 90, y_top, 60, h_top, text="dU:",text_w=20,entry_w=40,val='0.2')


# lb_fn = plLabel(pn_control,x=170,y=y_top, width=60,height=h_top, text="функция:")
# ed_fn = Entry(pn_control); ed_fn.insert(END,"sin(t)")
# ed_fn.place(x=240,y=y_top,width=240,height=h_top)
ed_fn =plEntry(pn_control, 170, y_top, 310, h_top, text="функция:",text_w=60,entry_w=240,val='sin(t)')


# -- заполним панель управления кнопками
y_bt=40;h_bt=20;w_bt=80    # -- координаты ряда кнопок

bt_prep = plButton(pn_control,x=40,y=y_bt,width=w_bt,height=h_bt, text = u'подготовить', cmd = fn_prep)
bt_draw = plButton(pn_control,x=200,y=y_bt,width=w_bt,height=h_bt, text = u'начертить', cmd = fn_draw)
bt_clear = plButton(pn_control,x=360,y=y_bt,width=w_bt,height=h_bt, text = u'стереть', cmd = fn_clear)


root.mainloop()

# %% [markdown]
# #### py012 Питон простое наследование классов

# %%
#coding: utf-8
#graph0.py
from math import *
from tkinter import *
'''
root = Tk()
canv = Canvas(root,width=600,height=550)
canv.pack()
'''
x0 = 40; y0 = 240; xm = 480; ym = 20
Sm = 1.2; tm=6.5; text_size=12
dash_size = 4
def coord_in(x0,y0,xm,ym, fil_color, x_label ='x',y_label='y'):
    canv.create_line(x0-10,y0,xm+10,y0,fill=fil_color,arrow=LAST)
    canv.create_line(x0,ym-10,x0,2*y0-ym+10,fill=fil_color,arrow=BOTH)
    canv.create_text(x0 + 20,ym,text=y_label, font=('Arial',text_size))
    canv.create_text(xm, y0-20, text=x_label, font=('Arial',text_size))

def graph_in(f, fm, tm, x0, y0, xm, ym, fil_color):
    xb = x0; t=0;yb=y0+(ym-y0)*f(t)/fm
    canv.create_line(xb,yb,xb,yb,fill=fil_color)
    for x in range(x0+2, xm, 2):
        t = tm*(x-x0)/(xm-x0)
        y = y0+(ym-y0)*f(t)/fm
        canv.create_line(xb, yb, x, y, fill=fil_color)
        xb = x; yb=y
        
def graph(f, fil_color):
    graph_in(f, Sm, tm, x0, y0, xm, ym, fil_color)

def text(label, t, u):
    t = float(t)
    x = t*(xm-x0)/tm + x0
    y = y0+(ym-y0)*u/Sm
    canv.create_text(x,y,text=label,font=('Arial',text_size))

def coord(fil_color, x_label ='x',y_label='y',dt=0.25,dU=0.2,grid=1):
    coord_in(x0,y0,xm,ym, fil_color, x_label,y_label)

    dt = float(dt)
    if dt != 0:
        t = dt
        disp_text = 0
        while t<tm:
            x = t*(xm-x0)/tm + x0
            canv.create_line(x,y0-5,x,y0+5,fill=fil_color)
            x_lab=str(t); x_lab[0:3]
            if disp_text:
                canv.create_text(x,y0+15,text=x_lab,font=('Arial',text_size))
                if grid:
                    canv.create_line(x,2*y0-ym,x,ym,fill=fil_color, dash=dash_size)
            t += dt
            disp_text=1 if disp_text==0 else 0
    
    dU = float(dU)
    if dU != 0:
        U = dU
        disp_text = 0
        while U<Sm:
            y = y0+(ym-y0)*U/Sm
            yn = y0+(y0-ym)*U/Sm
            canv.create_line(x0-5,y,x0+5,y,fill=fil_color)
            canv.create_line(x0-5,yn,x0+5,yn,fill=fil_color)
            y_lab=str(U); y_lab[0:3]
            if disp_text:
                canv.create_text(x0-20,y,text=y_lab,font=('Arial',text_size))
                canv.create_text(x0-20,yn,text='-'+y_lab,font=('Arial',text_size))
                if grid:
                    canv.create_line(x0,y,xm,y,fill=fil_color, dash=dash_size)
                    canv.create_line(x0,yn,xm,yn,fill=fil_color, dash=dash_size)
            U += dU
            disp_text=1 if disp_text==0 else 0
'''
<Button-1><Button-2><Button-3><Double-Button-1>
canv.bind('<Button-1>', proect)
'''
def proect(event):
    '''draw dash line on the canvas from the selected point
    '''
    x=event.x;y=event.y
    canv.create_line(x0, y, x, y, dash=dash_size)
    canv.create_line(x, y0, x, y, dash=dash_size)

#-- 11 -------------------

class plLabel:
    def __init__(self, panel, x, y, width, height, text):
        self.lab = Label(panel,text=text)
        self.lab.place(x=x,y=y,width=width,height=height)

class plButton:
    def __init__(self, panel, x, y, width, height, text, cmd = ''):
        self.btn = Button(panel)
        self.btn["text"]=text
        if cmd:
            self.btn["command"] = cmd
        self.btn.place(x=x,y=y,width=width,height=height)

class plEntry:
    def __init__(self, panel, x, y, width, height, text, text_w, entry_w, val=''):
        self.lab = Label(panel,text=text)
        self.lab.place(x=x,y=y,width=text_w,height=height)
        self.ent = Entry(panel)
        self.ent.place(x=x+width-entry_w,y=y,width=entry_w,height=height)
        self.set(val)
        
    def get(self):
        return self.ent.get()
    
    def set(self, text):
        self.ent.delete(0,END)
        self.ent.insert(END, text)

# pn_control = Frame(root, height = 70, bg = 'silver')
# pn_control.pack(side='top', fill='x')
# pn_control = pkFrame(root, height = 70, bg = 'silver', side='top', fill='x')

class pkFrame(Frame):
    '''
    pkFrame is a Frame with packing 
    syntax:
        pn_my = pkFrame(panel, width, height, bg, side, fill, expand )
    where
    panel - Frame for packing, (zb = root)
    width, height - Frame size
    bg - background color
    side - side of panel for packing
    fill - fill for packing( can skip )
    expand - expand for packing( can skip )
    '''
    
    def __init__(self,panel, height, width, bg, side='', fill='', expand=1):
        Frame.__init__(self,panel,width=width,height=height,bg=bg)
        if fill:
            self.pack(side=side, fill=fill, expand = expand)
        else:
            self.pack(side=side, expand=expand)
        self.pack_propagate(0)

class pkCanvas(Canvas):
    '''
    pkCanvas is a Canvas with packing syntax:
    can_my = pkCanvas(panel, width, height) where
    panel - Frame for packing, (zb = root) width, height - Canvas size
    fill - fill for packing( can skip )
    expand - expand for packing( can skip )
    '''
    def __init__(self, panel, height, width, fill, expand):
        Canvas.__init__(self,panel,height=height, width=width)
        self.pack(fill=fill, expand=expand)

# -- начало
root = Tk()

# -- функции
def fn(t):      # -- выводимая функция
    return eval(fnt)

def fn_prep():  # -- подготовить чистую канву с координатами
    Um = ed_Um.get(); Sm = eval(Um)
    dU = eval(ed_dU.get())
    tm = 6.5; dt=0.25
    canv.delete("all")
    canv.create_rectangle(0,0,550,550,fill="white")
    coord('black','t','U(t)',dt,dU,1)
    return

def fn_draw():    # -- нарисовать график функции
    global fnt
    fnt = ed_fn.get()
    graph(fn,'blue')
    return

def fn_clear():    # -- стереть график функции
    global fnt
    fnt = ed_fn.get()
    graph(fn,'white')
    return

# -- панели формы для кнопок и текстовых полей
pn_control = pkFrame(root,width=550, height = 70, bg = 'silver', side='top', fill='x')
pn_graph=pkFrame(root,550,550,'white','bottom','both')

canv = pkCanvas(pn_graph, 550,550,'both',1)

# -- заполним панель управления текстовыми полями
y_top = 10; h_top=18 # -- координаты верхнего ряда

ed_Um =plEntry(pn_control, 10, y_top, 65, h_top, text="Um:",text_w=20,entry_w=40,val='1.7')
ed_dU =plEntry(pn_control, 90, y_top, 65, h_top, text="dU:",text_w=20,entry_w=40,val='0.2')
ed_fn =plEntry(pn_control, 170, y_top, 310, h_top, text="функция:",text_w=60,entry_w=240,val='sin(t)')


# -- заполним панель управления кнопками
y_bt=40;h_bt=20;w_bt=80    # -- координаты ряда кнопок

bt_prep = plButton(pn_control,x=40,y=y_bt,width=w_bt,height=h_bt, text = u'подготовить', cmd = fn_prep)
bt_draw = plButton(pn_control,x=200,y=y_bt,width=w_bt,height=h_bt, text = u'начертить', cmd = fn_draw)
bt_clear = plButton(pn_control,x=360,y=y_bt,width=w_bt,height=h_bt, text = u'стереть', cmd = fn_clear)


root.mainloop()

# %% [markdown]
# ================================================================

# %%
#coding: utf-8
#graph0.py
from math import *
from tkinter import *
'''
root = Tk()
canv = Canvas(root,width=600,height=550)
canv.pack()
'''
x0 = 40; y0 = 240; xm = 480; ym = 20
Sm = 1.2; tm=6.5; text_size=12
dash_size = 4
def coord_in(x0,y0,xm,ym, fil_color, x_label ='x',y_label='y'):
    canv.create_line(x0-10,y0,xm+10,y0,fill=fil_color,arrow=LAST)
    canv.create_line(x0,ym-10,x0,2*y0-ym+10,fill=fil_color,arrow=BOTH)
    canv.create_text(x0 + 20,ym,text=y_label, font=('Arial',text_size))
    canv.create_text(xm, y0-20, text=x_label, font=('Arial',text_size))

def graph_in(f, fm, tm, x0, y0, xm, ym, fil_color):
    xb = x0; t=0;yb=y0+(ym-y0)*f(t)/fm
    canv.create_line(xb,yb,xb,yb,fill=fil_color)
    for x in range(x0+2, xm, 2):
        t = tm*(x-x0)/(xm-x0)
        y = y0+(ym-y0)*f(t)/fm
        canv.create_line(xb, yb, x, y, fill=fil_color)
        xb = x; yb=y
        
def graph(f, fil_color):
    graph_in(f, Sm, tm, x0, y0, xm, ym, fil_color)

def text(label, t, u):
    t = float(t)
    x = t*(xm-x0)/tm + x0
    y = y0+(ym-y0)*u/Sm
    canv.create_text(x,y,text=label,font=('Arial',text_size))

def coord(fil_color, x_label ='x',y_label='y',dt=0.25,dU=0.2,grid=1):
    coord_in(x0,y0,xm,ym, fil_color, x_label,y_label)

    dt = float(dt)
    if dt != 0:
        t = dt
        disp_text = 0
        while t<tm:
            x = t*(xm-x0)/tm + x0
            canv.create_line(x,y0-5,x,y0+5,fill=fil_color)
            x_lab=str(t); x_lab[0:3]
            if disp_text:
                canv.create_text(x,y0+15,text=x_lab,font=('Arial',text_size))
                if grid:
                    canv.create_line(x,2*y0-ym,x,ym,fill=fil_color, dash=dash_size)
            t += dt
            disp_text=1 if disp_text==0 else 0
    
    dU = float(dU)
    if dU != 0:
        U = dU
        disp_text = 0
        while U<Sm:
            y = y0+(ym-y0)*U/Sm
            yn = y0+(y0-ym)*U/Sm
            canv.create_line(x0-5,y,x0+5,y,fill=fil_color)
            canv.create_line(x0-5,yn,x0+5,yn,fill=fil_color)
            y_lab=str(U); y_lab[0:3]
            if disp_text:
                canv.create_text(x0-20,y,text=y_lab,font=('Arial',text_size))
                canv.create_text(x0-20,yn,text='-'+y_lab,font=('Arial',text_size))
                if grid:
                    canv.create_line(x0,y,xm,y,fill=fil_color, dash=dash_size)
                    canv.create_line(x0,yn,xm,yn,fill=fil_color, dash=dash_size)
            U += dU
            disp_text=1 if disp_text==0 else 0
'''
<Button-1><Button-2><Button-3><Double-Button-1>
canv.bind('<Button-1>', proect)
'''
def proect(event):
    '''draw dash line on the canvas from the selected point
    '''
    x=event.x;y=event.y
    canv.create_line(x0, y, x, y, dash=dash_size)
    canv.create_line(x, y0, x, y, dash=dash_size)

#-- 11 -------------------

class plLabel:
    def __init__(self, panel, x, y, width, height, text):
        self.lab = Label(panel,text=text)
        self.lab.place(x=x,y=y,width=width,height=height)

class plButton:
    def __init__(self, panel, x, y, width, height, text, cmd = ''):
        self.btn = Button(panel)
        self.btn["text"]=text
        if cmd:
            self.btn["command"] = cmd
        self.btn.place(x=x,y=y,width=width,height=height)

class plEntry:
    def __init__(self, panel, x, y, width, height, text, text_w, entry_w, val=''):
        self.lab = Label(panel,text=text)
        self.lab.place(x=x,y=y,width=text_w,height=height)
        self.ent = Entry(panel)
        self.ent.place(x=x+width-entry_w,y=y,width=entry_w,height=height)
        self.set(val)
        
    def get(self):
        return self.ent.get()
    
    def set(self, text):
        self.ent.delete(0,END)
        self.ent.insert(END, text)

# pn_control = Frame(root, height = 70, bg = 'silver')
# pn_control.pack(side='top', fill='x')
# pn_control = pkFrame(root, height = 70, bg = 'silver', side='top', fill='x')

class pkFrame(Frame):
    def __init__(self,panel, height, width, bg, side='', fill='', expand=1):
        Frame.__init__(self,panel,width=width,height=height,bg=bg)
        if fill:
            self.pack(side=side, fill=fill, expand = expand)
        else:
            self.pack(side=side, expand=expand)
        self.pack_propagate(0)

# pn_graph = Frame(root, height = 550,width = 550, bg = 'white')
# pn_graph.pack(side='bottom', expand=1, fill='both')
# pn_graph=pkFrame(root,550,550,'white','bottom',1,'both')

# canv = Canvas(pn_graph, height = 550, width=550)
# canv.pack(fill = 'both',expand=1)
# canv = pkCanvas(pn_graph, 550,550,'both',1)

class pkCanvas(Canvas):
    def __init__(self, panel, height, width, fill, expand):
        Canvas.__init__(self,panel,height=height, width=width)
        self.pack(fill=fill, expand=expand)

# %%
# %save graph12.py 1

# %%
#coding: utf-8
from math import *
from tkinter import *
import graph12 as gr
# -- начало
root = Tk()

# -- функции
def fn(t):      # -- выводимая функция
    return eval(fnt)

def fn_prep():  # -- подготовить чистую канву с координатами
    Um = ed_Um.get(); Sm = eval(Um)
    dU = eval(ed_dU.get())
    tm = 6.5; dt=0.25
    gr.canv.delete("all")
    gr.canv.create_rectangle(0,0,550,550,fill="white")
    gr.coord('black','t','U(t)',dt,dU,1)
    return

def fn_draw():    # -- нарисовать график функции
    global fnt
    fnt = ed_fn.get()
    gr.graph(fn,'blue')
    return

def fn_clear():    # -- стереть график функции
    global fnt
    fnt = ed_fn.get()
    gr.graph(fn,'white')
    return

# -- панели формы для кнопок и текстовых полей
pn_control = gr.pkFrame(root,width=550, height = 70, bg = 'silver', side='top', fill='x')
pn_graph=gr.pkFrame(root,550,550,'white','bottom','both')

gr.canv = gr.pkCanvas(pn_graph, 550,550,'both',1)

# -- заполним панель управления текстовыми полями
y_top = 10; h_top=18 # -- координаты верхнего ряда

ed_Um =gr.plEntry(pn_control, 10, y_top, 65, h_top, text="Um:",text_w=20,entry_w=40,val='1.8')
ed_dU =gr.plEntry(pn_control, 90, y_top, 65, h_top, text="dU:",text_w=20,entry_w=40,val='0.25')
ed_fn =gr.plEntry(pn_control, 170, y_top, 310, h_top, text="функция:",text_w=60,entry_w=240,val='sin(t)')


# -- заполним панель управления кнопками
y_bt=40;h_bt=20;w_bt=80    # -- координаты ряда кнопок

bt_prep = gr.plButton(pn_control,x=40,y=y_bt,width=w_bt,height=h_bt, text = u'подготовить', cmd = fn_prep)
bt_draw = gr.plButton(pn_control,x=200,y=y_bt,width=w_bt,height=h_bt, text = u'начертить', cmd = fn_draw)
bt_clear = gr.plButton(pn_control,x=360,y=y_bt,width=w_bt,height=h_bt, text = u'стереть', cmd = fn_clear)


root.mainloop()

# %% [markdown]
# py001 Питон - практический старт
# py002 Питон - инженерный калькулятор
# py003 Питон - калькулятор комплексных чисел
# py004 Питон - решение квадратного уравнения
# py005 Питон расчет RC цепочки для гармонического сигнала
# py006 Питон график функции
# py007 Питон простая библиотека для графиков
# py008 Питон координатная сетка и интерактивность грфики
# py009 Применение простых элементов Tkinter
# py010 Питон строим график произвольной функции
# py011 Питон создаем простой графический класс
# py012 Питон простое наследование классов
# py013 Питон работа с различными кодировками
# py014 Питон кодировки, часть 2 - автодекодирование
# py015 Питон - постраничное листание текстовых списков
# py017 Питон проекция текстового файла на числовой массив
# py016 Питон: кодировка среды ввода
# py018 Питон формирование таблицы DBSN
# py019 Экспорт MySQL таблицы в DBSN
# py020 Постраничный просмотр таблицы DBSN
# py021 DBSN - начало использования
# py022 Игра угадай число
# py023 Питон списки часть 1
# py024 Питон игра Быки и коровы
# py025 Питон связь по СОМ порту
# py026 Питон применение генераторов списков
# py027 Обработка строк
# py028 Питон работа с файлами
# py029 Питон множества
# py030 Питон словари
# py031 Питон графические примитивы
# py032 Обработка событий канвы
# py033 Питон перемещение объекта по Канве
# py034 Обработка даты и времени
# py035 Сжатие по Хаффману
# py036 Новогодняя елка
# py037 Простые средства отладки программ
# py038 игра пинг-понг
# py039 добавляем звук
# py040 Питон - сырое чтение дисков
# py041 Питон сетевой обмен по UDP протоколу
# py042 Передача файлов по сети
# py043 Питон программа управления шаговым двигателем
# py044 Питон многопоточные клиент и сервер UDP
# py045 Питон система ведущий-ведомые в локальной сети
# py046 Питон парсинг HTML страницы
# py047 Питон работа по Modbus RTU
# py048 Консольное приложение для работы по протоколу Modbus RTU
# py049 Питон управляем Экселем
# py050 Программа текстовой связи с микроконтроллеромpy
# py051 Простой таймер учета времени
# py052 Питон работа с внешними приложениями
# py053 Питон парсим плейлист Youtube канала
# py054 Питон применение Radiobutton и Checkbutton
# py055 Питон используем Listbox
# py056 Сортировка списка
# py057 простой чат на UDP
# py058 Минибэкап на Питоне
# py059 Крестики - нолики на Питоне
# py060 Простая отладка сетевых приложений
# py061 Сетевой вариант крестиков-ноликов на Питоне
# py062 элементы тестирования консольной программы
# py063 игра Змейка
# py064 Python отладчик для исправления ошибок
# py065 Python работа с сетью на канальном уровне
# py066 Пятнашки на Питоне
# py067 Питон программа управления ШИМ контроллера
# py068 Питон скачиваем документы по ссылкам
# py069 Формируем HTML тест из DOC файла
# py070 применение простых регулярных выражений
# py071 Питон обслуживание клавиатуры
# py072 Простое наследование классов ttk
# py073 Простейший текстовый редактор
# py074 программа на Python для исследования Atmega8
# py075 DBSN формирование записи
# py076 DBSN - структура записи
# py077 DBSN структура записи реального документа
# py078 DBSN заполняем запись данными документа
# py079 Сравнение питонов 2 и 3
# py080 Простая программа работы с СОМ портом на Python
# py081 Использование TFTP на Python 3
# py083 Парсим простые сайты на Python3

# %% [markdown]
# [py001 Питон - практический старт](https://www.youtube.com/watch?v=K3hE5C2kglI&list=PLku9se_HAVOp8pSgrIWGIjHLP-EOw_ywq&index=82)
# [abglazov](http://abglazov.rfpgu.ru/)
#
# []()
# []()
# []()

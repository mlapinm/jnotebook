# %% [markdown]
# [Уроки по Java](https://www.youtube.com/watch?v=uXMTq81jG7Y&list=PL786bPIlqEjRDXpAKYbzpdTaOYsWyjtCX&index=1)
# [b01 ”рок по Java 1: ”становка Java Development Kit(b001java.ipynb)
# [b02 ”рок Java 2: ”становка и запуск первой программы в Eclipse](b001java.ipynb)
# [b03 ”рок по Java 3: ”становка и запуск первой программы под Intellij Idea](b001java.ipynb)
# [b04 ”рок по Java 4: ќќѕ - ќбъектно ориентированное программирование и разбор программы Hello World.](b001java.ipynb)
# [b05 ”рок по Java 5: как можно запустить программу без использовани¤ метода main. ”дивите своих друзей.](b001java.ipynb)
# [b06 ”рок по Java 6: “ипы данных.](b001java.ipynb)
# [b07 ”рок по Java 7: зачем нужны типы данных и где мы их можем использовать.](b001java.ipynb)
# [b08 ”рок по Java 8:  омментарии](b001java.ipynb)
# [b09 ”рок по Java 9: ѕакеты и импорты(b001java.ipynb)
# [b10 ”рок по Java 10: Ќаследование.](b001java.ipynb)
# [b11 ”рок по Java 11: ѕолиморфизм](b001java.ipynb)
# [b12 ”рок по Java 12: »нкапсул¤ци¤](b001java.ipynb)
# [b13 ”рок Java 13: идентификаторы](b001java.ipynb)
# [b14 ”рок по Java 14:  лассы абстрактные и финальные.](b001java.ipynb)
# [b15 ”рок по Java 15: интерфейсы](b001java.ipynb)
# [b16 ”рок по Java 16: ћодификаторы доступа](b001java.ipynb)
# [b17 ”рок по Java 17: ѕеременные](b001java.ipynb)
# [b18 ”рок по Java 18: ћетоды](b001java.ipynb)
# [b19 ”рок по Java 19:  онструкторы](b001java.ipynb)
# [b20 ”рок по Java 20: ћассивы - определение](b020java.ipynb)
# [b21 ”рок по Java 21: Enums - перечеслени¤](b020java.ipynb)
# [b22 ”рок Java 22: Overloading - перегрузка методов](b020java.ipynb)
# [b23 ”рок Java 23: Constructors 2 - конструкторы урок 2](b020java.ipynb)
# [b24 ”роки по Java 24: Overriding - переопределение методов](b020java.ipynb)
# [b25 ”рок Java 25:  лючевое слово static и инициализаци¤ классов](b020java.ipynb)
# [b26 ”рок Java 26: Ѕлоки инициализации](b020java.ipynb)
# [b27 ”рок по Java 27: инициализаци¤ массивов](b020java.ipynb)
# [b28 ”рок по Java 28: ќбертки](b020java.ipynb)
# [b29 ”рок по Java 29: перегрузка методов 2](b020java.ipynb)
# [b30 ”рок по Java 30: ”становка JDK 8 на Linux Mint](b020java.ipynb)
# [b31 ”рок по Java 31: ”становка eclipse под Linux mint](b020java.ipynb)
# [b32 ”рок по Java 32: установка и запуск первой программы под intellij idea под linux mint](b020java.ipynb)
# [b33 ”рок по Java 33: ”становка Oracle JDK на Linux mint 18 через ppa](b020java.ipynb)
# [b34 ”рок по Java 34: Garbage Collector](b020java.ipynb)
# [b35 ”рок по Java 35: операторы Java](b020java.ipynb)
# [b36 ”рок по Java 36: метод main и передаваемые в него параметры](b020java.ipynb)
# [b37 ”рок по Java 37: ќператор ветвлени¤ if и else](b020java.ipynb)
# [b38 ”рок по Java 38: ћало кто знает как устроен оператор ветвлени¤ switch](b020java.ipynb)
# [b39 ”рок по Java 39: ÷иклы while и do while](b020java.ipynb)
# [b40 ”рок по Java 40: ÷икл For](b040java.ipynb)
# [b41 ”рок по Java 41: ”лучшенный цикл For](b040java.ipynb)
# [b42 ”рок по Java 42: Exceptions - исключени¤](b040java.ipynb)
# [b43 ”рок по Java 43: ћеханизм Assertions](b040java.ipynb)
# [b44 ”рок по Java 44: StringBuilder](b040java.ipynb)
# [b45 ”рок по Java 45: –абота с файлами и директори¤ми в Java](b040java.ipynb)
# [b46 ”рок по Java 46: —ериализаци¤](b040java.ipynb)
# [b47 ”рок по Java 47: —ериализаци¤ наследуемых объектов](b040java.ipynb)
# [b48 ”рок по Java 48: ƒаты, календари и врем¤.](b040java.ipynb)
# [b49 ”рок по Java 49: Equals and HashCode](b040java.ipynb)
# [b50 ”рок по Java 50:  оллекции](b040java.ipynb)
# [b51 ”рок по Java 51: —ортировка коллекций и интерфейсы - Comparable и Comparator](b040java.ipynb)
# [b52 ”рок по Java 52: —писки - List](b040java.ipynb)
# [b53 ”рок по Java 53: ќчереди - Queue](b040java.ipynb)
# [b54 ”рок по Java 54: Maps](b040java.ipynb)
# [b55 ”рок по Java 55: Sets](b040java.ipynb)
# [b56 ”рок по Java 56: Generics - обобщени¤](b040java.ipynb)
# [b57 ”рок по Java 57: Inner Classes - ¬нутренние классы](b040java.ipynb)
# [b58 ”рок по Java 58: јнонимные классы](b040java.ipynb)
# [b59 ”рок по Java 59:  лонирование объектов](b040java.ipynb)
# [b60 ”рок по Java 60: Reflection - рефлекси¤](b060java.ipynb)
# [b61 ”рок по Java 61:  акие технологии надо знать что бы стать Java программистом](b060java.ipynb)
# [b62 ”рок по Java 62: „то нужно знать перед собеседованием.](b060java.ipynb)
# [b63 ”рок по Java 63:  ак компилировать и запускать классы через коммандную строку, плюс classpath](b060java.ipynb)
# [b64 ”рок по Java 64: —оздание и подключение Jar файлов](b060java.ipynb)
# [b65 ”рок по Java 65: „тение из консоли.](b060java.ipynb)
# [b66 »гра престолов JS и Java. „асть 1](b060java.ipynb)
# [b67 »гра престолов JS и Java. „асть 2](b060java.ipynb)
# [b68 ”рок по Java 66: ћногопоточность 1: —оздание потоков](b060java.ipynb)
# [b69 ”рок по Java 67: ћногопоточность 2: жизненый цикл потоков](b060java.ipynb)
# [b70 ”рок по Java 68: ћногопоточность 3: —инхронизаци¤](b060java.ipynb)
# [b71 ”рок по Java 69: ћногопоточность 4: синхронизаци¤ статический методов](b060java.ipynb)
# [b72 ”рок по Java 70: ћногопоточность 5: volatile](b060java.ipynb)
# [b73 ”рок по Java 71: ћногопоточность 6: атомарные переменные](b060java.ipynb)
# [b74 ”рок по Java 72: ћногопоточность 7: —инхронизированные коллекции](b060java.ipynb)
# [b75 ”рок по Java 73: ћногопоточность 8: Deadlock](b060java.ipynb)
# [b76 ”рок по Java 74: ћногопоточность 9: Wait and notify](b060java.ipynb)
# [b77 ”рок по Java 75: ћногопоточность 10: Wait and Notify пример](b060java.ipynb)
# [b78 ”рок по Java 76: ћногопоточность 11: ReentrantLock](b060java.ipynb)
# [b79 ”рок по Java 77: ћногопоточность 12: TryLock](b060java.ipynb)
# [b80 ”рок по Java 78 : ћногопоточность13: Conditions](b080java.ipynb)
# [b81 ”рок по Java 79: ћногопоточность 14: Callable and Futures](b080java.ipynb)
# [b82 ”рок по Java 80: ћногопоточность 15: Executors](b080java.ipynb)
# [b83 ”рок по Java 81: ћногопоточность 16: ScheduledExcecuterService](b080java.ipynb)
# [b84 ”рок по Java 82: ћногопоточность 17: семофоры - Semofors](b080java.ipynb)
# [b85 ”рок по Java 83: ћногопоточность 18: CountDownLatch](b080java.ipynb)
# [b86 ”рок по Java 84: ћногопоточность 19: Exchenger](b080java.ipynb)
# [b87 ”рок по Java 85: ћногопоточность 20: CyclicBarier](b080java.ipynb)
# [b88 ”рок по Java 86: ћногопоточность 21: Phaser](b080java.ipynb)
# [b89 ”рок по Java 87: ћногопоточность 22: BlockingQueue](b080java.ipynb)
# [b90 ”рок по Java 88: ћногопоточность 23: ThreadFactory](b080java.ipynb)
# [b91 ”рок по Java 89: ћногопоточность 24: ForkJoinFramework](b080java.ipynb)
# [b92 ”рок по Java 90: ћногопоточность 25: ThreadLocalRandom And TimeUnit](b080java.ipynb)
# [b93 ”рок по Java 91: Dynamic Proxy - динамические прокси.](b080java.ipynb)
# [b94 ”рок по Java 92:  акие книги надо читать что бы стать Java программистом.](b080java.ipynb)
# [b95 ”рок по Java 93: я буду выкладывать код на GitHub.](b080java.ipynb)
# [b96 ”рок по Java 94: —колько зарабатывают Java программисты в ”краине](b080java.ipynb)
# [b97 ”рок по Java 95: как получить максимальную зарплату, при устройстве на работу программистом.](b080java.ipynb)
# [b98 ”рок по Java 96: Swing 1: HelloWorld](b080java.ipynb)
# [b99 ”рок по Java 97: Swing 2: JComponent](b080java.ipynb)
# [b100 ”рок по Java 98: Swing 3: ActionListener](b100java.ipynb)
# [b101 ”рок по Java 99: Swing 4: EventHandler](b100java.ipynb)
# [b102 ”рок по Java 100: Swing 5: LookAndFeel](b100java.ipynb)
# [b103 ”рок по Java 101: Swing 6: WindowListener](b100java.ipynb)
# [b104 ”рок по Java 102: Swing 7: Actions](b100java.ipynb)
# [b105 ”рок по Java 103: Swing 8: KeyStroke](b100java.ipynb)
# [b106 ”рок по Java 104: Swing 9: MouseListener](b100java.ipynb)
# [b107 ”рок по Java 105: Swing 10: “екстовые пол¤ JTextField, JPasswordField, JTextArea, ScrollPane](b100java.ipynb)
# [b108 ”рок по Java 106: Swing 11:  омпоненты выбора RadioButton, RadioGroup, ComponentBox, Border](b100java.ipynb)
# [b109 ”рок по Java 107: Swing 12: Sliders](b100java.ipynb)
# [b110 ”рок по Java 108: Swing 13: Menu](b100java.ipynb)
# [b111 ”рок по Java 109: Swing 14: PopupMenu](b100java.ipynb)
# [b112 ”рок по Java 110: Swing 15: ToolBar](b100java.ipynb)
# [b113 ”рок по Java 111: Swing 16: Layout](b100java.ipynb)
# [b114 ”рок по Java 112: Swing 17: BorderGrid Layout](b100java.ipynb)
# [b115 ”рок по Java 113: Swing 18: GridBagLayout](b100java.ipynb)
# [b116 ”рок по Java 114: Swing 19: No Layout](b100java.ipynb)
# [b117 ”рок по Java 115: Swing 20: Custom Layout](b100java.ipynb)
# [b118 ”рок по Java 116: Swing 21: Focus](b100java.ipynb)
# [b119 ”рок по Java 117: Swing 22: Dialogs](b100java.ipynb)
# [b100 ”рок по Java 98: Swing 3: ActionListener](b120java.ipynb)
# [b101 ”рок по Java 99: Swing 4: EventHandler](b120java.ipynb)
# [b102 ”рок по Java 100: Swing 5: LookAndFeel](b120java.ipynb)
# [b103 ”рок по Java 101: Swing 6: WindowListener](b120java.ipynb)
# [b104 ”рок по Java 102: Swing 7: Actions](b120java.ipynb)
# [b105 ”рок по Java 103: Swing 8: KeyStroke](b120java.ipynb)
# [b106 ”рок по Java 104: Swing 9: MouseListener](b120java.ipynb)
# [b107 ”рок по Java 105: Swing 10: “екстовые пол¤ JTextField, JPasswordField, JTextArea, ScrollPane](b120java.ipynb)
# [b108 ”рок по Java 106: Swing 11:  омпоненты выбора RadioButton, RadioGroup, ComponentBox, Border](b120java.ipynb)
# [b109 ”рок по Java 107: Swing 12: Sliders](b120java.ipynb)
# [b110 ”рок по Java 108: Swing 13: Menu](b120java.ipynb)
# [b111 ”рок по Java 109: Swing 14: PopupMenu](b120java.ipynb)
# [b112 ”рок по Java 110: Swing 15: ToolBar](b120java.ipynb)
# [b113 ”рок по Java 111: Swing 16: Layout](b120java.ipynb)
# [b114 ”рок по Java 112: Swing 17: BorderGrid Layout](b120java.ipynb)
# [b115 ”рок по Java 113: Swing 18: GridBagLayout](b120java.ipynb)
# [b116 ”рок по Java 114: Swing 19: No Layout](b120java.ipynb)
# [b117 ”рок по Java 115: Swing 20: Custom Layout](b120java.ipynb)
# [b118 ”рок по Java 116: Swing 21: Focus](b120java.ipynb)
# [b119 ”рок по Java 117: Swing 22: Dialogs](b120java.ipynb)
# [b140 ”рок Java 138: AWT 18: «аставка - Splash screen](b140java.ipynb)
# [b141 ”рок Java 139: AWT 19: «апуск других приложений на ¬ашем компьютере из Java](b140java.ipynb)
# [b142 ”рок Java 140: AWT 20: SystemTray](b140java.ipynb)
# [b143 ”рок Java 141: ”становка JDK на MacOs Sierra](b140java.ipynb)
# [b144 ”рок Java 142: ”становка и запуск Eclipse на MacOs](b140java.ipynb)
# [b145 ”рок Java 143: ”становка и запуска Intellij idea на MacOs Sierra](b140java.ipynb)
# [b146 ”рок Java 144: ¬ыполн¤емый Jar архивы](b140java.ipynb)
# [b147 ”рок Java 145: јплеты](b140java.ipynb)
# [b148 ”рок Java 146: Java WebStart](b140java.ipynb)
# [b149 ”рок Java 147: Properties](b140java.ipynb)
# [b150 ”рок Java 148: Preferences](b140java.ipynb)
# [b151 ”роки Java 149: Ћогирование - loggers](b140java.ipynb)
# [b152 ”рок Java 150: Debugging tips and tricks](b140java.ipynb)
# [b153 ”рок Java 151: Debugging Swing](b140java.ipynb)
# [b154 ”рок Java 152: Robot](b140java.ipynb)
# [b155 ”рок Java 153:  ак ¤ устроилс¤ на работу в —Ўј](b140java.ipynb)
# [b156 ”рок Java 154: Javadoc](b140java.ipynb)
# [b157 ”рок Java 155: Overloading подробнее](b140java.ipynb)
# [b158 ”рок Java 156: переопределение equals](b140java.ipynb)
# [b159 ”рок Java 157: instanceof null](b140java.ipynb)
# [b160 ”рок Java 158: ѕочему нет множественного наследовани¤ в java](b160java.ipynb)
# [b161 ”рок Java 159: —татическа¤ инициализаци¤](b160java.ipynb)
# [b162 ”рок Java 160: Final](b160java.ipynb)
# [b163 ”рок Java 161: Enum подробнее](b160java.ipynb)
# [b164 ”рок Java 162: Static Inner Classes](b160java.ipynb)
# [b165 ”рок Java 163: Inner classes](b160java.ipynb)
# [b166 ”рок Java 164: Local classes](b160java.ipynb)
# [b167 ”рок Java 165: »нтерфейсы подробнее](b160java.ipynb)
# [b168 ”рок Java 166 Try с ресурсами и AutoClosable](b160java.ipynb)
# [b169 ”рок Java 167: ќтношени¤ между классами is A и Has A](b160java.ipynb)
# [b170 ”рок Java 168: Cohesion и Coupling](b160java.ipynb)
# [b171 ”рок Java 169: –абота с файлами и стримы](b160java.ipynb)
# [b172 ”рок Java 170:  лассы Path и Files введенные в Java 7](b160java.ipynb)
# [b173 ”рок Java 171: Scanner и PrintWriter](b160java.ipynb)
# [b174 ”рок Java 172: Xml 1: Dom подход](b160java.ipynb)
# [b175 ”рок Java 173: Xml 2: Sax подход](b160java.ipynb)
# [b176 ”рок Java 174: Xml 3: —оздание xml, DOM поход](b160java.ipynb)
# [b177 ”рок Java 175: XML 4: —оздание XML, SAX подход](b160java.ipynb)
# [b178 ”рок Java 176: Xml 5: XPath и работа с XML](b160java.ipynb)
# [b179 ”рок Java 177: —ети 1:  ак работает сеть](b160java.ipynb)
# [b180 ”рок Java 178: —ети 2: Sockets client side - —океты на стороне клиента](b180java.ipynb)
# [b181 ”рок Java 179: —ети 3: Sockets server side - —океты со стороны сервера.](b180java.ipynb)
# [b182 ”рок Java 180: ѕротокол HTTP и как получить HTML](b180java.ipynb)
# [b183 ”рок Java 181:  ак отправить email](b180java.ipynb)
# [b184 ”рок Java 182: ”становка Intellij Idea Ultimate](b180java.ipynb)
# [b185 ”рок Java 183: JDBC 1: „то такое –ел¤ционна¤ база данных и SQL](b180java.ipynb)
# [b186 ”рок Java 184: JDBC 2: ”становка MySql на Windows 10](b180java.ipynb)
# [b187 ”рок Java 185: JDBC 3: ”становка MySql на Linux mint](b180java.ipynb)
# [b188 ”рок Java 186: JDBC 4:  ак подключитьс¤ к MySql из Intellij Idea](b180java.ipynb)
# [b189 ”рок Java 187: JDBC 5: ѕодключение к базе данных, на примере MySql](b180java.ipynb)
# [b190 ”рок Java 188: JDBC 6: ¬ыполнение SQL комманд](b180java.ipynb)
# [b191 ”рок Java 189: JDBC 7: SQL Injection и PreparementStatement](b180java.ipynb)
# [b192 ”рок Java 190: JDBC 8 : BLOB - Binary large objects](b180java.ipynb)
# [b193 ”рок Java 191: JDBC 9: ƒаты и SQL последовательности](b180java.ipynb)
# [b194 ”рок Java 192: JDBC 10: ’ранимые процедуры](b180java.ipynb)
# [b195 ”рок Java 193: JDBC 11: ћножественные результаты](b180java.ipynb)
# [b196 ”рок Java 194: JDBC 12: Scrollable RowSet](b180java.ipynb)
# [b197 ”рок Java 195: JDBC 13: Update ResultSet](b180java.ipynb)
# [b198 ”рок Java 196: JDBC 14:  эширование результата запроса - CachedRowSet](b180java.ipynb)
# [b199 ”рок Java 197: JDBC 15: Metadata](b180java.ipynb)
# [b200 ”рок Java 198: JDBC 16: “ранзакции - transactions](b200java.ipynb)
# [b201 ”рок Java 199: JDBC 17:  ак накатить SQL группой - SQL Batch](b200java.ipynb)
# [b202 ”рок Java 200: JDBC 18: ”ровни изол¤ции транзакций](b200java.ipynb)
# [b203 Java 9: ”рок 1: ”становка JDK](b200java.ipynb)
# [b204 Java 9: ”рок 2: JShell](b200java.ipynb)
# [b205 Java 9: ”рок 3: ProcessHandle](b200java.ipynb)
# [b206 Java 9: ”рок 4: ѕриватные методы в интерфейсах](b200java.ipynb)
# [b207 Java 9: ”рок 5: Collections](b200java.ipynb)
# [b208 Java 9: ”рок 6: StackWalker](b200java.ipynb)
# [b209 Java 9: ”рок 7: ћодули - Modules](b200java.ipynb)
# [b210 Java 9: ”рок 8: »зменени¤ в try с ресурсами](b200java.ipynb)
# [b211 ”рок Java 201: JMX на стороне сервера](b200java.ipynb)
# [b212 ”рок Java 202: JMX Notification](b200java.ipynb)
# [b213 ”рок Java 203: JMX на стороне клиента](b200java.ipynb)
# [b214 ”рок Java 204: —равнени¤ строк](b200java.ipynb)
# [b215 ”рок Java 205: ‘орматирование строк](b200java.ipynb)
# [b216 ”рок Java 206: Ћокаль - locale](b200java.ipynb)
# [b217 ”рок Java 207: Ћокализаци¤ или интернационализаци¤](b200java.ipynb)
# [b218 ”рок Java 208: Java Beans](b200java.ipynb)
# [b219 ”рок Java 209: «агрузчик классов](b200java.ipynb)
# [b220 ”рок Java 210: Byte code verifier](b220java.ipynb)
# [b221 ”рок Java 211: Security Manager](b220java.ipynb)
# [b222 ”рок Java 212: Security Manager аунтентификаци¤ пользовател¤](b220java.ipynb)
# [b223 ”рок Java 213: –абота с шифрованием MD5 и SHA-1](b220java.ipynb)
# [b224 ”рок Java 214: —ертификаци¤ - Certification](b220java.ipynb)
# [b225 ”рок Java 215: Ўифрование AES](b220java.ipynb)
# [b226 ”рок Java 216: Ўифрование RSA](b220java.ipynb)
# [b227 ”рок Java 217: «апуск JavaScript](b220java.ipynb)
# [b228 ”рок Java 218:  омпил¤ци¤ Java в рантайме](b220java.ipynb)
# [b229 ”рок Java 219: јннотации - Annotations](b220java.ipynb)
# [b230 ”рок Java 220: ѕример работы с аннотаци¤ми](b220java.ipynb)
# [b231 ”рок Java 221: RMI](b220java.ipynb)
# [b232 ”рок Java 222: «апуск "native" кода](b220java.ipynb)
# [b233 ”рок Java 223: JNDI](b220java.ipynb)
# [b234 ”рок Java 224: JAXB](b220java.ipynb)
# [b235 ”рок Java 225: FX 1: HelloWorld](b220java.ipynb)
# [b236 ”рок Java 226: FX 2: Java Packager](b220java.ipynb)
# [b237 ”рок Java 227: FX 3: Shapes](b220java.ipynb)
# [b238 ”рок Java 228: FX 4: Canvas](b220java.ipynb)
# [b239 ”рок Java 229: FX 5: Properties и binding](b220java.ipynb)
# [b240 ”рок Java 230: FX 6: Layout](b240java.ipynb)
# [b241 ”рок Java 231: FX 7: UI Controls](b240java.ipynb)
# [b242 ”рок Java 232: FX 8:  астомный контрол Control](b240java.ipynb)
# [b243 ”рок Java 233: FX 9:  ќбработка событий](b240java.ipynb)
# [b244 ”рок Java 234: FX 10: –абота с изображени¤ми](b240java.ipynb)
# [b245 ”рок по Java 235: FX 11: јнимаци¤](b240java.ipynb)
# [b246 ”рок Java 236: FX 12: Scene Builder](b240java.ipynb)
# [b247 ”рок Java 237: FX 13: CSS](b240java.ipynb)
# [b248 ”рок Java 238: FX 14: FXML](b240java.ipynb)
# [b249 ”рок Java 239: FX 15: Media](b240java.ipynb)
# [b250 ”рок Java 240: FX 16: ќтображение HTML и JavaScript в WebView](b240java.ipynb)
# [b251 ”рок Java 241: FX 17: √рафики - Charts](b240java.ipynb)
# [b252 ”рок Java 242: FX 18: –абота с 3D](b240java.ipynb)
# [b253 ”рок Java 243: FX 19: Collections](b240java.ipynb)
# [b254 ”рок Java 244: FX 20: Concurency](b240java.ipynb)
# [b255 ”рок Java 245: FX 21: Swing и Fx](b240java.ipynb)
# [b256 ”рок 246: RegEx 1: „то такое регул¤рные выражени¤](b240java.ipynb)
# [b257 ”рок 247: RegEx 2: Ѕуквальные выражени¤](b240java.ipynb)
# [b258 ”рок 248: RegEx 3: Ќаборы символов](b240java.ipynb)
# [b259 ”рок 249: RegEx 4: “очка](b240java.ipynb)
# [b260 ”рок 250: RegEx 5: границы слов](b260java.ipynb)
# [b261 ”рок 251: RegEx 6: Ќачало и конец строки](b260java.ipynb)
# [b262 ”рок 252: RegEx 7: Pipeline](b260java.ipynb)
# [b263 ”рок 253: RegEx 8: Optional Items или знак вопроса](b260java.ipynb)
# [b264 ”рок 254: RegExp 9: —имволы звездочка и плюс](b260java.ipynb)
# [b265 ”рок 255: RegExp 10: √руппы](b260java.ipynb)
# [b266 ”рок 256: RegExp 11: »менованные группы](b260java.ipynb)
# [b267 ”рок 257: RegExp 12: Unicode](b260java.ipynb)
# [b268 ”рок 258: RegExp 13: –ежимы регул¤рных выражений](b260java.ipynb)
# [b269 ”рок 259: RegExp 14: Possesive Quantifier](b260java.ipynb)
# [b270 ”рок 260: RegExp 15: Atomic Groups](b260java.ipynb)
# [b271 ”рок 261: RegExp 16: LookAround](b260java.ipynb)
# [b272 ”рок 262: RegExp 17: ћножественные требовани¤](b260java.ipynb)
# [b273 ”рок 263: RegExp 18: If Then Else](b260java.ipynb)
# [b274 ”рок 264: RegExp 19: Posix символы](b260java.ipynb)
# [b275 ”рок 265: RegExp 20:  оментарии](b260java.ipynb)
# [b276 ”рок 266: RegExp 21: ѕримеры](b260java.ipynb)
# [b276 ”рок 266: RegExp 21: ѕримеры](b260java.ipynb)
# [b277 ”рок 267: RegExp 22: ƒомашнее задание и ответы на ƒ/«](b260java.ipynb)
# [b278 ”рок Java 268: Patterns 1: „то такое паттерны](b260java.ipynb)
# [b279 ”рок Java 269: Patterns 2: Factory](b260java.ipynb)
# [b280 ”рок Java 270: Patterns 3: Abstract Factory](b280java.ipynb)
# [b281 ”рок Java 271: Patterns 4: Factory Method](b280java.ipynb)
# [b282 ”рок Java 272: Patterns 5: Singelton](b280java.ipynb)
# [b283 ”рок Java 273: Patterns 6: Builder](b280java.ipynb)
# [b284 ”рок Java 274: Patterns 7: Prototype](b280java.ipynb)
# [b285 ”рок Java 275: Patterns 8: Object Pool](b280java.ipynb)
# [b286 ”рок Java 276: Patterns 9: Adapter](b280java.ipynb)
# [b287 ”рок Java 277: Patterns 10: Bridge](b280java.ipynb)
# [b288 ”рок Java 278: Patterns 11: Filter](b280java.ipynb)
# [b289 ”рок Java 279: Patterns 12: Composite](b280java.ipynb)
# [b290 ”рок Java 280: Pattern 13: Decorator](b280java.ipynb)
# [b291 ”рок Java 281: Patterns 14: Facade](b280java.ipynb)
# [b292 ”рок Java 282: Pat 15: FlyWeight](b280java.ipynb)
# [b293 ”рок Java 283: Patterns 16: Proxy](b280java.ipynb)
# [b294 ”рок Java 284: Patterns 17: Chain Of Responsibility](b280java.ipynb)
# [b295 ”рок Java 285: Patterns 18: Command](b280java.ipynb)
# [b296 ”рок Java 286: Patterns 19: Interpreter](b280java.ipynb)
# [b297 ”рок Java 287: Patterns 20: Iterator](b280java.ipynb)
# [b298 ”рок Java 288: Patterns 21: Mediator](b280java.ipynb)
# [b299 ”рок Java 289: Patterns 22: Momento](b280java.ipynb)
# [b300 ”рок Java 290: Patterns 23: Observable](b300java.ipynb)
# [b301 ”рок Java 291: Patterns 24: State](b300java.ipynb)
# [b302 ”рок Java 292: Patterns 25: Null Object](b300java.ipynb)
# [b303 ”рок Java 293: Patterns 26: Strategy](b300java.ipynb)
# [b304 ”рок Java 294: Patterns 27: Template](b300java.ipynb)
# [b305 ”рок Java 295: Patterns 28: Visitor](b300java.ipynb)
# [b306 ”рок Java 296: Patterns 29: MVC](b300java.ipynb)
# [b307 ”рок Java 297: Patterns 30: Business Delegate](b300java.ipynb)
# [b308 ”рок Java 298: Patterns 31: Composite Entity](b300java.ipynb)
# [b309 ”рок Java 299: Patterns 32: DAO](b300java.ipynb)
# [b310 ”рок Java 300: Patterns 33: Front Controller](b300java.ipynb)
# [b311 ”рок Java 301: Patterns 34: Intercepting Filter](b300java.ipynb)
# [b312 ”рок Java 302: Patternts 35: Service Locator](b300java.ipynb)
# [b313 ”рок Java 303: Patterns 36: Transfer Object](b300java.ipynb)
# [b314 ”рок Java 304: Solid 1: „то такое SOLID](b300java.ipynb)
# [b315 ”рок Java 305: SOLID 2: Single Responsibility](b300java.ipynb)
# [b316 ”рок Java 306: SOLID 3: Open Close principle](b300java.ipynb)
# [b317 ”рок Java 307: SOLID 4: Liskov principle](b300java.ipynb)
# [b318 ”рок Java 308: SOLID 5: Interface Sugregation](b300java.ipynb)
# [b319 ”рок Java 309: SOLID 6: Dependency Inversion](b300java.ipynb)
# [b320 ”рок Java 310: Generics 1: „то такое дженерики](b320java.ipynb)
# [b321 ”рок Java 311: Generic 2: Ќаследование Generics](b320java.ipynb)
# [b322 ”рок Java 312: Generic 3: Generic методы](b320java.ipynb)
# [b323 ”рок Java 313: Generic 4: Bounds](b320java.ipynb)
# [b324 ”рок Java 314: Generic 5: Whild Card](b320java.ipynb)
# [b325 ”рок Java 315: Generic 6: ќбобщеный и не обобщенный код](b320java.ipynb)
# [b326 ”рок Java 316: ArrayList и LinkedList](b320java.ipynb)
# [b327 ”рок Java 317: Stack Queue Dequeue](b320java.ipynb)
# [b328 ”рок Java 318: Binary Search](b320java.ipynb)
# [b329 ”рок Java 319: выбрасывание ошибок методами](b320java.ipynb)
# [b330 ”рок Java 320: Ёксепшены и Pipeline оператор](b320java.ipynb)
# [b331 ”рок Java 321:  ак AutoClosable работает](b320java.ipynb)
# [b332 ”рок Java 322: Assertions](b320java.ipynb)
# [b333 ”рок Java 323: Immutable классы](b320java.ipynb)
# [b334 ”рок Java 324: ReadWrite Lock](b320java.ipynb)
# [b335 ”рок Java 325: Java 8 p1: „то такое функциональное программирование](b320java.ipynb)
# [b336 ”рок 326: Java 8 p2: Ћ¤мбда](b320java.ipynb)
# [b337 ”рок 327: Java 8 p3: функциональные интерфейсы](b320java.ipynb)
# [b338 ”рок 328: Java 8 p4: Streams](b320java.ipynb)
# [b339 ”рок 329: Java 8 p5: default и static методы](b320java.ipynb)
# [b340 ”рок 330: Java 8 p6: Optional](b320java.ipynb)
# [b341 ”рок Java 331: Java 8 p7: Method References](b320java.ipynb)
# [b342 ”рок Java 332: Java 8 p8: Collector](b320java.ipynb)
# [b343 ”рок 333: Java 8 p9: Parallel](b320java.ipynb)
# [b344 ”рок 334: Java 8 p10: LocalDate](b320java.ipynb)
# [b345 ”рок 335: Java 8 p11:  ак работают л¤мбда выражени¤](b320java.ipynb)
# [b346 ”рок 336: ѕереопределение Equals и HashCode](b320java.ipynb)
# [b347 ”рок Java 337: Clonnable подробнее](b320java.ipynb)
# [b348 ”рок Java 338: ѕул оберток над примитивами.](b320java.ipynb)
# [b349 ”рок Java 339:  оллекции](b320java.ipynb)
# [b350 ”рок Java 340: List](b320java.ipynb)
# [b351 ”рок Java 341: Set](b320java.ipynb)
# [b352 ”рок Java 342: Queue](b320java.ipynb)
# [b353 ”рок Java 343: Maps](b320java.ipynb)
# [b354 ”рок Java 344: —ложность алгоритмов поиска по коллекции](b320java.ipynb)
# [b355 ”рок Java 345: Concurrency package](b320java.ipynb)
# [b356 ”рок Java 346: Volatile и happens before](b320java.ipynb)
# [b357 ”рок Java 347: проблема double check](b320java.ipynb)
# [b358 ”рок Java 348: “ипы reference](b320java.ipynb)
# [b359 ”рок Java 349: ћодель пам¤ти Java и алогоритмы работы сборщиков муссора](b320java.ipynb)
# [b360 ”рок Java 350:  ак обычную строку поместить в пул](b360java.ipynb)
# [b361 ”рок Java 351: –азмещение обектов вне хипа](b360java.ipynb)
# [b362 ”рок Java 352: –асспределение нагрузки](b360java.ipynb)
# [b363 ”рок Java 353: Immutable коллекции](b360java.ipynb)
# [b364 ”рок Java 354: ¬ысоконагруженна¤ архитектура](b360java.ipynb)
# [b365 ”рок Java 355: Ўардинг и репликаци¤](b360java.ipynb)
# [b366 ”рок Java 356: —оздание индексов в базе данных](b360java.ipynb)
# [b367 ”рок Java 357: ѕочему синхронизаци¤ это плохо](b360java.ipynb)
# [b368 ”рок Java 358: GRASP паттерны](b360java.ipynb)
# [b369 ”рок Java 359: Cap теорема](b360java.ipynb)
# [b370 ”рок Java 360: Externalizer](b360java.ipynb)
# [b371 ”рок Java 361: Imutable классы](b360java.ipynb)
# [b372 ”рок Java 362:  ак обнаружить DeadLock](b360java.ipynb)
# [b373 ”рок Java 363: ThreadLocal](b360java.ipynb)
# [b374 ”рок Java 364:  ак изучить Indellij idea](b360java.ipynb)
# [b375 ”рок Java 365: Best practice](b360java.ipynb)
# [b376 ”рок Java 366: Best practice 2: Static factory](b360java.ipynb)
# [b377 ”рок Java 367: Best practice 3: Singleton](b360java.ipynb)
# [b378 ”рок Java 368: Best practice 4:  Unnecesary objects](b360java.ipynb)
# [b379 ”рок Java 369: Best practice 5: ѕочему нельз¤ использовать finalize?](b360java.ipynb)
# [b380 ”рок Java 370: Best practice 6: ѕереопределение equals](b360java.ipynb)
# [b381 ”рок Java 371: Best practice 7: ѕереопределение HashCode](b360java.ipynb)
# [b382 ”рок Java 372: Best practice 8: ѕереопределение clone](b360java.ipynb)
# [b383 ”рок Java 373: Best practice 9: ToString](b360java.ipynb)
# [b384 ”рок Java 374: Best practice 10: ћинимизируйте accessability](b360java.ipynb)
# [b385 ”рок Java 375: Best practice 11:  ак создавать immutable классы](b360java.ipynb)
# [b386 ”рок Java 376: Best practice 12: „ем композици¤ лучше наследовани¤?](b360java.ipynb)
# [b387 ”рок Java 377: Best practice 13: ƒизайн класса дл¤ наследовани¤](b360java.ipynb)
# [b388 ”рок Java 378: Best practice 14: „ем интерфейсы лучше абстрактных классов?](b360java.ipynb)
# [b389 ”рок Java 379: Best practice 15: Ќе используйте row типы](b360java.ipynb)
# [b390 ”рок Java 380: Best practice 16: SuppressWarnings](b360java.ipynb)
# [b391 ”рок Java 381: Best practice 17: „ем List лучше массивов?](b360java.ipynb)
# [b392 ”рок Java 382: Best practice 18: Wild cards](b360java.ipynb)
# [b393 ”рок Java 383: Best practice 19: „ем Enum лучше констант](b360java.ipynb)
# [b394 ”рок Java 384: Best practice 20: ѕочему нужно использовать @Override](b360java.ipynb)
# [b395 ”рок Java 385: Best practice 21: Immutable objects](b360java.ipynb)
# [b396 ”рок Java 386: Best practice 22: ¬алидаци¤ параметров](b360java.ipynb)
# [b397 ”рок Java 387: Best practice 23: —оздание сигнатуры метод](b360java.ipynb)
# [b398 ”рок Java 388: Best practice 24: Overloading](b360java.ipynb)
# [b399 ”рок Java 389: Best practice 25: ¬озвращение коллекций методам](b360java.ipynb)
# [b400 ”рок Java 390: Best practice 26: ћинимизаци¤ скоупа и циклы](b360java.ipynb)
# [b401 ”рок Java 391: Best practice 27: ѕочему нельз¤ использовать float и double дл¤ точных вычислений?](b360java.ipynb)
# [b402 ”рок Java 392: Best practice 28: ѕочему нужно использовать примитивы вместо оберток?](b360java.ipynb)
# [b403 ”рок Java 393: Best practice 29: ѕочему нужно обращатьс¤ к объектам через интерфейс?](b360java.ipynb)
# [b404 ”рок Java 394: Best practice 30: Ќе оптимизируйте](b360java.ipynb)
# [b405 ”рок Java 395: Best practice 31:  акой вид исключений использовать?](b360java.ipynb)
# [b406 ”рок Java 396: Best practice 32: »спользуйте стандартные исключени¤](b360java.ipynb)
# [b407 ”рок Java 397: Best practice 33: јтомарность исключений](b360java.ipynb)
# [b408 ”рок Java 398: Best practice 34: –абота с исключени¤ми](b360java.ipynb)
# [b409 ”рок Java 399: Best practice 35: —инхронизируйте доступ к мутабельной информации](b360java.ipynb)
# [b410 ”рок Java 400: Best practice 36: ¬ызов "Alien" методов из синхронизированного контекста](b360java.ipynb)
# [b411 ”рок Java 401: Best practice 37: »спользование wait и notify](b360java.ipynb)
# [b412 ”рок Java 402: Best practice 38: ƒокументируйте потокобезопасность ¬аших методов](b360java.ipynb)
# [b413 ”рок Java 403: Best practice 39: –абота с многопоточностью](b360java.ipynb)
# [b414 ”рок Java 404: Best practice 40: —ериализаци¤](b360java.ipynb)
# [b415 ”рок Java 405:  онец!!!](b360java.ipynb)

# %% [markdown]
# #### b01 ”рок по Java 1: ”становка Java Development Kit(JDK), компил¤ци¤ и запуск первой программы.
# #### b02 ”рок Java 2: ”становка и запуск первой программы в Eclipse
# #### b03 ”рок по Java 3: ”становка и запуск первой программы под Intellij Idea
# #### b04 ”рок по Java 4: ќќѕ - ќбъектно ориентированное программирование и разбор программы Hello World.
# #### b05 ”рок по Java 5: как можно запустить программу без использовани¤ метода main. ”дивите своих друзей.
# #### b06 ”рок по Java 6: “ипы данных.
# #### b07 ”рок по Java 7: зачем нужны типы данных и где мы их можем использовать.
# #### b08 ”рок по Java 8: комментарии
# #### b09 ”рок по Java 9: ѕакеты и импорты(Packages and Import)
# #### b10 ”рок по Java 10: Ќаследование.
# #### b11 ”рок по Java 11: ѕолиморфизм
# #### b12 ”рок по Java 12: »нкапсул¤ци¤
# #### b13 ”рок Java 13: идентификаторы
# #### b14 ”рок по Java 14: классы абстрактные и финальные.
# #### b15 ”рок по Java 15: интерфейсы
# #### b16 ”рок по Java 16: ћодификаторы доступа
# #### b17 ”рок по Java 17: ѕеременные
# #### b18 ”рок по Java 18: ћетоды
# #### b19 ”рок по Java 19:  онструкторы
# #### b20 ”рок по Java 20: ћассивы - определение
# #### b21 ”рок по Java 21: Enums - перечеслени¤
# #### b22 ”рок Java 22: Overloading - перегрузка методов
# #### b23 ”рок Java 23: Constructors 2 - конструкторы урок 2
# #### b24 ”роки по Java 24: Overriding - переопределение методов
# #### b25 ”рок Java 25:  лючевое слово static и инициализаци¤ классов
# #### b26 ”рок Java 26: Ѕлоки инициализации
# #### b27 ”рок по Java 27: инициализаци¤ массивов
# #### b28 ”рок по Java 28: ќбертки
# #### b29 ”рок по Java 29: перегрузка методов 2
# #### b30 ”рок по Java 30: ”становка JDK 8 на Linux Mint
# #### b31 ”рок по Java 31: ”становка eclipse под Linux mint
# #### b32 ”рок по Java 32: установка и запуск первой программы под intellij idea под linux mint
# #### b33 ”рок по Java 33: ”становка Oracle JDK на Linux mint 18 через ppa
# #### b34 ”рок по Java 34: Garbage Collector
# #### b35 ”рок по Java 35: операторы Java
# #### b36 ”рок по Java 36: метод main и передаваемые в него параметры
# #### b37 ”рок по Java 37: ќператор ветвлени¤ if и else
# #### b38 ”рок по Java 38: ћало кто знает как устроен оператор ветвлени¤ switch
# #### b39 ”рок по Java 39: ÷иклы while и do while
# #### b40 ”рок по Java 40: ÷икл For
# #### b41 ”рок по Java 41: ”лучшенный цикл For
# #### b42 ”рок по Java 42: Exceptions - исключени¤
# #### b43 ”рок по Java 43: ћеханизм Assertions
# #### b44 ”рок по Java 44: StringBuilder
# #### b45 ”рок по Java 45: –абота с файлами и директори¤ми в Java
# #### b46 ”рок по Java 46: —ериализаци¤
# #### b47 ”рок по Java 47: —ериализаци¤ наследуемых объектов
# #### b48 ”рок по Java 48: ƒаты, календари и врем¤.
# #### b49 ”рок по Java 49: Equals and HashCode
# #### b50 урок по Java 50: коллекции
# #### b51 ”рок по Java 51: —ортировка коллекций и интерфейсы - Comparable и Comparator
# #### b52 ”рок по Java 52: —писки - List
# #### b53 ”рок по Java 53: ќчереди - Queue
# #### b54 ”рок по Java 54: Maps
# #### b55 ”рок по Java 55: Sets
# #### b56 ”рок по Java 56: Generics - обобщени¤
# #### b57 ”рок по Java 57: Inner Classes - ¬нутренние классы
# #### b58 ”рок по Java 58: јнонимные классы
# #### b59 ”рок по Java 59: клонирование объектов
# #### b60 ”рок по Java 60: Reflection - рефлекси¤
# #### b61 ”рок по Java 61:  акие технологии надо знать что бы стать Java программистом
# #### b62 ”рок по Java 62: „то нужно знать перед собеседованием.
# #### b63 ”рок по Java 63:  ак компилировать и запускать классы через коммандную строку, плюс classpath
# #### b64 ”рок по Java 64: —оздание и подключение Jar файлов
# #### b65 ”рок по Java 65: „тение из консоли.
# #### b66 »гра престолов JS и Java. „асть 1
# #### b67 »гра престолов JS и Java. „асть 2
# #### b68 ”рок по Java 66: ћногопоточность 1: —оздание потоков
# #### b69 ”рок по Java 67: ћногопоточность 2: жизненый цикл потоков
# #### b70 ”рок по Java 68: ћногопоточность 3: —инхронизаци¤
# #### b71 ”рок по Java 69: ћногопоточность 4: синхронизаци¤ статический методов
# #### b72 ”рок по Java 70: ћногопоточность 5: volatile
# #### b73 ”рок по Java 71: ћногопоточность 6: атомарные переменные
# #### b74 ”рок по Java 72: ћногопоточность 7: —инхронизированные коллекции
# #### b75 ”рок по Java 73: ћногопоточность 8: Deadlock
# #### b76 ”рок по Java 74: ћногопоточность 9: Wait and notify
# #### b77 ”рок по Java 75: ћногопоточность 10: Wait and Notify пример
# #### b78 ”рок по Java 76: ћногопоточность 11: ReentrantLock
# #### b79 ”рок по Java 77: ћногопоточность 12: TryLock
# #### b80 ”рок по Java 78 : ћногопоточность13: Conditions
# #### b81 ”рок по Java 79: ћногопоточность 14: Callable and Futures
# #### b82 ”рок по Java 80: ћногопоточность 15: Executors
# #### b83 ”рок по Java 81: ћногопоточность 16: ScheduledExcecuterService
# #### b84 ”рок по Java 82: ћногопоточность 17: семофоры - Semofors
# #### b85 ”рок по Java 83: ћногопоточность 18: CountDownLatch
# #### b86 ”рок по Java 84: ћногопоточность 19: Exchenger
# #### b87 ”рок по Java 85: ћногопоточность 20: CyclicBarier
# #### b88 ”рок по Java 86: ћногопоточность 21: Phaser
# #### b89 ”рок по Java 87: ћногопоточность 22: BlockingQueue
# #### b90 ”рок по Java 88: ћногопоточность 23: ThreadFactory
# #### b91 ”рок по Java 89: ћногопоточность 24: ForkJoinFramework
# #### b92 ”рок по Java 90: ћногопоточность 25: ThreadLocalRandom And TimeUnit
# #### b93 ”рок по Java 91: Dynamic Proxy - динамические прокси.
# #### b94 ”рок по Java 92:  акие книги надо читать что бы стать Java программистом.
# #### b95 ”рок по Java 93: я буду выкладывать код на GitHub.
# #### b96 ”рок по Java 94: —колько зарабатывают Java программисты в ”краине
# #### b97 ”рок по Java 95: как получить максимальную зарплату, при устройстве на работу программистом.
# #### b98 ”рок по Java 96: Swing 1: HelloWorld
# #### b99 ”рок по Java 97: Swing 2: JComponent
# #### b100 ”рок по Java 98: Swing 3: ActionListener
# #### b101 ”рок по Java 99: Swing 4: EventHandler
# #### b102 ”рок по Java 100: Swing 5: LookAndFeel
# #### b103 ”рок по Java 101: Swing 6: WindowListener
# #### b104 ”рок по Java 102: Swing 7: Actions
# #### b105 ”рок по Java 103: Swing 8: KeyStroke
# #### b106 ”рок по Java 104: Swing 9: MouseListener
# #### b107 ”рок по Java 105: Swing 10: “екстовые пол¤ JTextField, JPasswordField, JTextArea, ScrollPane
# #### b108 ”рок по Java 106: Swing 11:  омпоненты выбора RadioButton, RadioGroup, ComponentBox, Border
# #### b109 ”рок по Java 107: Swing 12: Sliders
# #### b110 ”рок по Java 108: Swing 13: Menu
# #### b111 ”рок по Java 109: Swing 14: PopupMenu
# #### b112 ”рок по Java 110: Swing 15: ToolBar
# #### b113 ”рок по Java 111: Swing 16: Layout
# #### b114 ”рок по Java 112: Swing 17: BorderGrid Layout
# #### b115 ”рок по Java 113: Swing 18: GridBagLayout
# #### b116 ”рок по Java 114: Swing 19: No Layout
# #### b117 ”рок по Java 115: Swing 20: Custom Layout
# #### b118 ”рок по Java 116: Swing 21: Focus
# #### b119 ”рок по Java 117: Swing 22: Dialogs
# #### b120 ”рок по Java 118: Swing 23: Custom dialog
# #### b121 ”рок по Java 119: Swing 24: File Dialog
# #### b122 ”рок по Java 120: Swing 25: ColorDialog
# #### b123 ”рок по Java 121: AWT 1: Shapes
# #### b124 ”рок по Java 122: AWT 2: Areas - обрезание фигур.
# #### b125 ”рок по Java 123: AWT 3: Stroke - изминение толщины и стил¤ линий
# #### b126 ”рок по Java 124: AWT 4: Paint изменение цвета, политры и градиента фигур
# #### b127 ”рок по Java 125: AWT 5: Transformation - трансформаци¤ фигур
# #### b128 ”рок по Java 126: AWT 6: Clip - ќбрезание фигур
# #### b129 ”рок по Java 127: AWT 7: Transparency - прозрачность фигур
# #### b130 ”рок по Java 128: AWT 8: —корость и качество отрисовки фигур
# #### b131 ”рок Java 129: AWT 9: „тение и запись изображений
# #### b132 ”рок Java 130: AWT 10: –абота с изображени¤ми
# #### b133 ”рок по Java 131: AWT 11: Image filter фильтры дл¤ изображений
# #### b134 ”рок по Java 132: AWT 12: ѕечать Grapics2d объектов
# #### b135 ”рок Java 133: AWT 13: ѕечать документов
# #### b136 ”рок по Java 134: AWT 14: Print PostScript
# #### b137 ”рок Java 135: AWT 15: –абота с буфером обмена, основы, копирование строк
# #### b138 ”рок Java 136: AWT 16: Ѕуфер обмена, копирование картинок
# #### b139 ”рок Java 137: AWT 17: DragAndDrop
# #### b140 ”рок Java 138: AWT 18: «аставка - Splash screen
# #### b141 ”рок Java 139: AWT 19: «апуск других приложений на ¬ашем компьютере из Java
# #### b142 ”рок Java 140: AWT 20: SystemTray
# #### b143 ”рок Java 141: ”становка JDK на MacOs Sierra
# #### b144 ”рок Java 142: ”становка и запуск Eclipse на MacOs
# #### b145 ”рок Java 143: ”становка и запуска Intellij idea на MacOs Sierra
# #### b146 ”рок Java 144: ¬ыполн¤емый Jar архивы
# #### b147 ”рок Java 145: јплеты
# #### b148 ”рок Java 146: Java WebStart
# #### b149 ”рок Java 147: Properties
# #### b150 ”рок Java 148: Preferences
# #### b151 ”роки Java 149: Ћогирование - loggers
# #### b152 ”рок Java 150: Debugging tips and tricks
# #### b153 ”рок Java 151: Debugging Swing
# #### b154 ”рок Java 152: Robot
# #### b155 ”рок Java 153:  ак ¤ устроилс¤ на работу в —Ўј
# #### b156 ”рок Java 154: Javadoc
# #### b157 ”рок Java 155: Overloading подробнее
# #### b158 ”рок Java 156: переопределение equals
# #### b159 ”рок Java 157: instanceof null
# #### b160 ”рок Java 158: ѕочему нет множественного наследовани¤ в java
# #### b161 ”рок Java 159: —татическа¤ инициализаци¤
# #### b162 ”рок Java 160: Final
# #### b163 ”рок Java 161: Enum подробнее
# #### b164 ”рок Java 162: Static Inner Classes
# #### b165 ”рок Java 163: Inner classes
# #### b166 ”рок Java 164: Local classes
# #### b167 ”рок Java 165: »нтерфейсы подробнее
# #### b168 ”рок Java 166 Try с ресурсами и AutoClosable
# #### b169 ”рок Java 167: ќтношени¤ между классами is A и Has A
# #### b170 ”рок Java 168: Cohesion и Coupling
# #### b171 ”рок Java 169: –абота с файлами и стримы
# #### b172 ”рок Java 170:  лассы Path и Files введенные в Java 7
# #### b173 ”рок Java 171: Scanner и PrintWriter
# #### b174 ”рок Java 172: Xml 1: Dom подход
# #### b175 ”рок Java 173: Xml 2: Sax подход
# #### b176 ”рок Java 174: Xml 3: —оздание xml, DOM поход
# #### b177 ”рок Java 175: XML 4: —оздание XML, SAX подход
# #### b178 ”рок Java 176: Xml 5: XPath и работа с XML
# #### b179 ”рок Java 177: —ети 1:  ак работает сеть
# #### b180 ”рок Java 178: —ети 2: Sockets client side - —океты на стороне клиента
# #### b181 ”рок Java 179: —ети 3: Sockets server side - —океты со стороны сервера.
# #### b182 ”рок Java 180: ѕротокол HTTP и как получить HTML
# #### b183 ”рок Java 181:  ак отправить email
# #### b184 ”рок Java 182: ”становка Intellij Idea Ultimate
# #### b185 ”рок Java 183: JDBC 1: „то такое –ел¤ционна¤ база данных и SQL
# #### b186 ”рок Java 184: JDBC 2: ”становка MySql на Windows 10
# #### b187 ”рок Java 185: JDBC 3: ”становка MySql на Linux mint
# #### b188 ”рок Java 186: JDBC 4:  ак подключитьс¤ к MySql из Intellij Idea
# #### b189 ”рок Java 187: JDBC 5: ѕодключение к базе данных, на примере MySql
# #### b190 ”рок Java 188: JDBC 6: ¬ыполнение SQL комманд
# #### b191 ”рок Java 189: JDBC 7: SQL Injection и PreparementStatement
# #### b192 ”рок Java 190: JDBC 8 : BLOB - Binary large objects
# #### b193 ”рок Java 191: JDBC 9: ƒаты и SQL последовательности
# #### b194 ”рок Java 192: JDBC 10: ’ранимые процедуры
# #### b195 ”рок Java 193: JDBC 11: ћножественные результаты
# #### b196 ”рок Java 194: JDBC 12: Scrollable RowSet
# #### b197 ”рок Java 195: JDBC 13: Update ResultSet
# #### b198 ”рок Java 196: JDBC 14:  эширование результата запроса - CachedRowSet
# #### b199 ”рок Java 197: JDBC 15: Metadata
# #### b200 ”рок Java 198: JDBC 16: “ранзакции - transactions
# #### b201 ”рок Java 199: JDBC 17:  ак накатить SQL группой - SQL Batch
# #### b202 ”рок Java 200: JDBC 18: ”ровни изол¤ции транзакций
# #### b203 Java 9: ”рок 1: ”становка JDK
# #### b204 Java 9: ”рок 2: JShell
# #### b205 Java 9: ”рок 3: ProcessHandle
# #### b206 Java 9: ”рок 4: ѕриватные методы в интерфейсах
# #### b207 Java 9: ”рок 5: Collections
# #### b208 Java 9: ”рок 6: StackWalker
# #### b209 Java 9: ”рок 7: ћодули - Modules
# #### b210 Java 9: ”рок 8: »зменени¤ в try с ресурсами
# #### b211 ”рок Java 201: JMX на стороне сервера
# #### b212 ”рок Java 202: JMX Notification
# #### b213 ”рок Java 203: JMX на стороне клиента
# #### b214 ”рок Java 204: —равнени¤ строк
# #### b215 ”рок Java 205: ‘орматирование строк
# #### b216 ”рок Java 206: Ћокаль - locale
# #### b217 ”рок Java 207: Ћокализаци¤ или интернационализаци¤
# #### b218 ”рок Java 208: Java Beans
# #### b219 ”рок Java 209: «агрузчик классов
# #### b220 ”рок Java 210: Byte code verifier
# #### b221 ”рок Java 211: Security Manager
# #### b222 ”рок Java 212: Security Manager аунтентификаци¤ пользовател¤
# #### b223 ”рок Java 213: –абота с шифрованием MD5 и SHA-1
# #### b224 ”рок Java 214: —ертификаци¤ - Certification
# #### b225 ”рок Java 215: Ўифрование AES
# #### b226 ”рок Java 216: Ўифрование RSA
# #### b227 ”рок Java 217: «апуск JavaScript
# #### b228 ”рок Java 218:  омпил¤ци¤ Java в рантайме
# #### b229 ”рок Java 219: јннотации - Annotations
# #### b230 ”рок Java 220: ѕример работы с аннотаци¤ми
# #### b231 ”рок Java 221: RMI
# #### b232 ”рок Java 222: «апуск "native" кода
# #### b233 ”рок Java 223: JNDI
# #### b234 ”рок Java 224: JAXB
# #### b235 ”рок Java 225: FX 1: HelloWorld
# #### b236 ”рок Java 226: FX 2: Java Packager
# #### b237 ”рок Java 227: FX 3: Shapes
# #### b238 ”рок Java 228: FX 4: Canvas
# #### b239 ”рок Java 229: FX 5: Properties и binding
# #### b240 ”рок Java 230: FX 6: Layout
# #### b241 ”рок Java 231: FX 7: UI Controls
# #### b242 ”рок Java 232: FX 8:  астомный контрол Control
# #### b243 ”рок Java 233: FX 9:  ќбработка событий
# #### b244 ”рок Java 234: FX 10: –абота с изображени¤ми
# #### b245 ”рок по Java 235: FX 11: јнимаци¤
# #### b246 ”рок Java 236: FX 12: Scene Builder
# #### b247 ”рок Java 237: FX 13: CSS
# #### b248 ”рок Java 238: FX 14: FXML
# #### b249 ”рок Java 239: FX 15: Media
# #### b250 ”рок Java 240: FX 16: ќтображение HTML и JavaScript в WebView
# #### b251 ”рок Java 241: FX 17: √рафики - Charts
# #### b252 ”рок Java 242: FX 18: –абота с 3D
# #### b253 ”рок Java 243: FX 19: Collections
# #### b254 ”рок Java 244: FX 20: Concurency
# #### b255 ”рок Java 245: FX 21: Swing и Fx
# #### b256 ”рок 246: RegEx 1: „то такое регул¤рные выражени¤
# #### b257 ”рок 247: RegEx 2: Ѕуквальные выражени¤
# #### b258 ”рок 248: RegEx 3: Ќаборы символов
# #### b259 ”рок 249: RegEx 4: “очка

# %% [markdown]
# #### b260 ”рок 250: RegEx 5: границы слов
# #### b261 ”рок 251: RegEx 6: Ќачало и конец строки
# #### b262 ”рок 252: RegEx 7: Pipeline
# #### b263 ”рок 253: RegEx 8: Optional Items или знак вопроса
# #### b264 ”рок 254: RegExp 9: —имволы звездочка и плюс
# #### b265 ”рок 255: RegExp 10: √руппы
# #### b266 ”рок 256: RegExp 11: »менованные группы
# #### b267 ”рок 257: RegExp 12: Unicode
# #### b268 ”рок 258: RegExp 13: –ежимы регул¤рных выражений
# #### b269 ”рок 259: RegExp 14: Possesive Quantifier
# #### b270 ”рок 260: RegExp 15: Atomic Groups
# #### b271 ”рок 261: RegExp 16: LookAround
# #### b272 ”рок 262: RegExp 17: ћножественные требовани¤
# #### b273 ”рок 263: RegExp 18: If Then Else
# #### b274 ”рок 264: RegExp 19: Posix символы
# #### b275 ”рок 265: RegExp 20:  оментарии
# #### b276 ”рок 266: RegExp 21: ѕримеры
# #### b277 ”рок 267: RegExp 22: ƒомашнее задание и ответы на ƒ/«
# #### b278 ”рок Java 268: Patterns 1: „то такое паттерны
# #### b279 ”рок Java 269: Patterns 2: Factory
# #### b280 ”рок Java 270: Patterns 3: Abstract Factory
# #### b281 ”рок Java 271: Patterns 4: Factory Method
# #### b282 ”рок Java 272: Patterns 5: Singelton
# #### b283 ”рок Java 273: Patterns 6: Builder
# #### b284 ”рок Java 274: Patterns 7: Prototype
# #### b285 ”рок Java 275: Patterns 8: Object Pool
# #### b286 ”рок Java 276: Patterns 9: Adapter
# #### b287 ”рок Java 277: Patterns 10: Bridge
# #### b288 ”рок Java 278: Patterns 11: Filter
# #### b289 ”рок Java 279: Patterns 12: Composite
# #### b290 ”рок Java 280: Pattern 13: Decorator
# #### b291 ”рок Java 281: Patterns 14: Facade
# #### b292 ”рок Java 282: Pat 15: FlyWeight
# #### b293 ”рок Java 283: Patterns 16: Proxy
# #### b294 ”рок Java 284: Patterns 17: Chain Of Responsibility
# #### b295 ”рок Java 285: Patterns 18: Command
# #### b296 ”рок Java 286: Patterns 19: Interpreter
# #### b297 ”рок Java 287: Patterns 20: Iterator
# #### b298 ”рок Java 288: Patterns 21: Mediator
# #### b299 ”рок Java 289: Patterns 22: Momento
# #### b300 ”рок Java 290: Patterns 23: Observable
# #### b301 ”рок Java 291: Patterns 24: State
# #### b302 ”рок Java 292: Patterns 25: Null Object
# #### b303 ”рок Java 293: Patterns 26: Strategy
# #### b304 ”рок Java 294: Patterns 27: Template
# #### b305 ”рок Java 295: Patterns 28: Visitor
# #### b306 ”рок Java 296: Patterns 29: MVC
# #### b307 ”рок Java 297: Patterns 30: Business Delegate
# #### b308 ”рок Java 298: Patterns 31: Composite Entity
# #### b309 ”рок Java 299: Patterns 32: DAO
# #### b310 ”рок Java 300: Patterns 33: Front Controller
# #### b311 ”рок Java 301: Patterns 34: Intercepting Filter
# #### b312 ”рок Java 302: Patternts 35: Service Locator
# #### b313 ”рок Java 303: Patterns 36: Transfer Object
# #### b314 ”рок Java 304: Solid 1: „то такое SOLID
# #### b315 ”рок Java 305: SOLID 2: Single Responsibility
# #### b316 ”рок Java 306: SOLID 3: Open Close principle
# #### b317 ”рок Java 307: SOLID 4: Liskov principle
# #### b318 ”рок Java 308: SOLID 5: Interface Sugregation
# #### b319 ”рок Java 309: SOLID 6: Dependency Inversion
# #### b320 ”рок Java 310: Generics 1: „то такое дженерики
# #### b321 ”рок Java 311: Generic 2: Ќаследование Generics
# #### b322 ”рок Java 312: Generic 3: Generic методы
# #### b323 ”рок Java 313: Generic 4: Bounds
# #### b324 ”рок Java 314: Generic 5: Whild Card
# #### b325 ”рок Java 315: Generic 6: ќбобщеный и не обобщенный код
# #### b326 ”рок Java 316: ArrayList и LinkedList
# #### b327 ”рок Java 317: Stack Queue Dequeue
# #### b328 ”рок Java 318: Binary Search
# #### b329 ”рок Java 319: выбрасывание ошибок методами
# #### b330 ”рок Java 320: Ёксепшены и Pipeline оператор
# #### b331 ”рок Java 321:  ак AutoClosable работает
# #### b332 ”рок Java 322: Assertions
# #### b333 ”рок Java 323: Immutable классы
# #### b334 ”рок Java 324: ReadWrite Lock
# #### b335 ”рок Java 325: Java 8 p1: „то такое функциональное программирование
# #### b336 ”рок 326: Java 8 p2: Ћ¤мбда
# #### b337 ”рок 327: Java 8 p3: функциональные интерфейсы
# #### b338 ”рок 328: Java 8 p4: Streams
# #### b339 ”рок 329: Java 8 p5: default и static методы
# #### b340 ”рок 330: Java 8 p6: Optional
# #### b341 ”рок Java 331: Java 8 p7: Method References
# #### b342 ”рок Java 332: Java 8 p8: Collector
# #### b343 ”рок 333: Java 8 p9: Parallel
# #### b344 ”рок 334: Java 8 p10: LocalDate
# #### b345 ”рок 335: Java 8 p11:  ак работают л¤мбда выражени¤
# #### b346 ”рок 336: ѕереопределение Equals и HashCode
# #### b347 ”рок Java 337: Clonnable подробнее
# #### b348 ”рок Java 338: ѕул оберток над примитивами.
# #### b349 ”рок Java 339:  оллекции
# #### b350 ”рок Java 340: List
# #### b351 ”рок Java 341: Set
# #### b352 ”рок Java 342: Queue
# #### b353 ”рок Java 343: Maps
# #### b354 ”рок Java 344: —ложность алгоритмов поиска по коллекции
# #### b355 ”рок Java 345: Concurrency package
# #### b356 ”рок Java 346: Volatile и happens before
# #### b357 ”рок Java 347: проблема double check
# #### b358 ”рок Java 348: “ипы reference
# #### b359 ”рок Java 349: ћодель пам¤ти Java и алогоритмы работы сборщиков муссора
# #### b360 ”рок Java 350:  ак обычную строку поместить в пул
# #### b361 ”рок Java 351: –азмещение обектов вне хипа
# #### b362 ”рок Java 352: –асспределение нагрузки
# #### b363 ”рок Java 353: Immutable коллекции
# #### b364 ”рок Java 354: ¬ысоконагруженна¤ архитектура
# #### b365 ”рок Java 355: Ўардинг и репликаци¤
# #### b366 ”рок Java 356: —оздание индексов в базе данных
# #### b367 ”рок Java 357: ѕочему синхронизаци¤ это плохо
# #### b368 ”рок Java 358: GRASP паттерны
# #### b369 ”рок Java 359: Cap теорема
# #### b370 ”рок Java 360: Externalizer
# #### b371 ”рок Java 361: Imutable классы
# #### b372 ”рок Java 362:  ак обнаружить DeadLock
# #### b373 ”рок Java 363: ThreadLocal
# #### b374 ”рок Java 364:  ак изучить Indellij idea
# #### b375 ”рок Java 365: Best practice
# #### b376 ”рок Java 366: Best practice 2: Static factory
# #### b377 ”рок Java 367: Best practice 3: Singleton
# #### b378 ”рок Java 368: Best practice 4:  Unnecesary objects
# #### b379 ”рок Java 369: Best practice 5: ѕочему нельз¤ использовать finalize?
# #### b380 ”рок Java 370: Best practice 6: ѕереопределение equals
# #### b381 ”рок Java 371: Best practice 7: ѕереопределение HashCode
# #### b382 ”рок Java 372: Best practice 8: ѕереопределение clone
# #### b383 ”рок Java 373: Best practice 9: ToString
# #### b384 ”рок Java 374: Best practice 10: ћинимизируйте accessability
# #### b385 ”рок Java 375: Best practice 11:  ак создавать immutable классы
# #### b386 ”рок Java 376: Best practice 12: „ем композици¤ лучше наследовани¤?
# #### b387 ”рок Java 377: Best practice 13: ƒизайн класса дл¤ наследовани¤
# #### b388 ”рок Java 378: Best practice 14: „ем интерфейсы лучше абстрактных классов?
# #### b389 ”рок Java 379: Best practice 15: Ќе используйте row типы
# #### b390 ”рок Java 380: Best practice 16: SuppressWarnings
# #### b391 ”рок Java 381: Best practice 17: „ем List лучше массивов?
# #### b392 ”рок Java 382: Best practice 18: Wild cards
# #### b393 ”рок Java 383: Best practice 19: „ем Enum лучше констант
# #### b394 ”рок Java 384: Best practice 20: ѕочему нужно использовать @Override
# #### b395 ”рок Java 385: Best practice 21: Immutable objects
# #### b396 ”рок Java 386: Best practice 22: ¬алидаци¤ параметров
# #### b397 ”рок Java 387: Best practice 23: —оздание сигнатуры метод
# #### b398 ”рок Java 388: Best practice 24: Overloading
# #### b399 ”рок Java 389: Best practice 25: ¬озвращение коллекций методам
# #### b400 ”рок Java 390: Best practice 26: ћинимизаци¤ скоупа и циклы
# #### b401 ”рок Java 391: Best practice 27: ѕочему нельз¤ использовать float и double дл¤ точных вычислений?
# #### b402 ”рок Java 392: Best practice 28: ѕочему нужно использовать примитивы вместо оберток?
# #### b403 ”рок Java 393: Best practice 29: ѕочему нужно обращатьс¤ к объектам через интерфейс?
# #### b404 ”рок Java 394: Best practice 30: Ќе оптимизируйте
# #### b405 ”рок Java 395: Best practice 31:  акой вид исключений использовать?
# #### b406 ”рок Java 396: Best practice 32: »спользуйте стандартные исключени¤
# #### b407 ”рок Java 397: Best practice 33: јтомарность исключений
# #### b408 ”рок Java 398: Best practice 34: –абота с исключени¤ми
# #### b409 ”рок Java 399: Best practice 35: —инхронизируйте доступ к мутабельной информации
# #### b410 ”рок Java 400: Best practice 36: ¬ызов "Alien" методов из синхронизированного контекста
# #### b411 ”рок Java 401: Best practice 37: »спользование wait и notify
# #### b412 ”рок Java 402: Best practice 38: ƒокументируйте потокобезопасность ¬аших методов
# #### b413 ”рок Java 403: Best practice 39: –абота с многопоточностью
# #### b414 ”рок Java 404: Best practice 40: —ериализаци¤
# #### b415 ”рок Java 405:  онец!!!

# %% [markdown]
# []()
# []()
# []()
# []()
# []()
# ```
#
# ```
